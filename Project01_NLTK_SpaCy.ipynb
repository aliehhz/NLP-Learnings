# %% [markdown]
# <a href="https://colab.research.google.com/github/aliehhz/NLP-Learnings/blob/main/Project01_NLTK_SpaCy_RezaShokrzad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📜 Project: Job Description Analyzer – Extracting Required Skills from Job Postings

# %% [markdown]
# ## 📌 Objective
# Use spaCy’s Named Entity Recognition (NER) and NLTK preprocessing to extract and categorize required skills from job descriptions. The goal is to identify trends in job requirements and analyze the most in-demand skills across industries.

# %% [markdown]
# ## 🛠️ Project Steps & Instructions

# %%
#📥 Download the Dataset
# !wget https://raw.githubusercontent.com/binoydutt/Resume-Job-Description-Matching/refs/heads/master/data.csv
# Out:
# --2025-03-28 02:35:13--  https://raw.githubusercontent.com/binoydutt/Resume-Job-Description-Matching/refs/heads/master/data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 646072 (631K) [text/plain]
# Saving to: ‘data.csv.2’
#
# data.csv.2          100%[===================>] 630.93K  --.-KB/s    in 0.04s
#
# 2025-03-28 02:35:13 (16.2 MB/s) - ‘data.csv.2’ saved [646072/646072]

# %% [markdown]
# ### Step 1: Load the Dataset
# #### 📌 Dataset: A provided CSV file containing job descriptions from different industries (IT, Healthcare, Finance, Marketing, etc.).
#
# 1. Download the dataset (link below).
# 2. Load it into Python using Pandas.
# 3. View the first few rows to understand its structure.

# %%
# your code here
import pandas as pd
df = pd.read_csv('data.csv')
print("Shape of dataset:", df.shape)
df.head()
# Out:
# Shape of dataset: (157, 10)
#    Unnamed: 0                          company  \
# 0           1          Visual BI Solutions Inc
# 1           2                       Jobvertise
# 2           3           Santander Consumer USA
# 3           4   Federal Reserve Bank of Dallas
# 4           5                           Aviall
#
#                                             position  \
# 0  Graduate Intern (Summer 2017) - SAP BI / Big D...
# 1                          Digital Marketing Manager
# 2    Manager, Pricing Management Information Systems
# 3               Treasury Services Analyst Internship
# 4                              Intern, Sales Analyst
#
#                                                  url     location  \
# 0  https://www.glassdoor.com/partner/jobListing.h...    Plano, TX
# 1  https://www.glassdoor.com/partner/jobListing.h...   Dallas, TX
# 2  https://www.glassdoor.com/partner/jobListing.h...   Dallas, TX
# 3  https://www.glassdoor.com/partner/jobListing.h...   Dallas, TX
# 4  https://www.glassdoor.com/partner/jobListing.h...   Dallas, TX
#
#        headquaters                employees founded  \
# 0        Plano, TX      51 to 200 employees    2010
# 1  Berlin, Germany        1 to 50 employees    2011
# 2       Dallas, TX  5001 to 10000 employees    1995
# 3       Dallas, TX   1001 to 5000 employees    1914
# 4       Dallas, TX   1001 to 5000 employees  Boeing
#
#                          industry  \
# 0          Information Technology
# 1                         Unknown
# 2                         Finance
# 3                         Finance
# 4  Subsidiary or Business Segment
#
#                                      Job Description
# 0   Location: Plano, TX or Oklahoma City, OK Dura...
# 1   The Digital Marketing Manager is the front li...
# 2   Summary of Responsibilities:The Manager Prici...
# 3   ORGANIZATIONAL SUMMARY:   As part of the nati...
# 4     Aviall is the world's largest provider of n...

# %% [markdown]
# ### Step 2: Preprocessing the Job Descriptions
# #### 📌 Goal: Clean the text by removing stopwords, punctuation, and unnecessary characters.
#
# 1. Use NLTK to tokenize the descriptions.
# 2. Remove stopwords and special characters.
# 3. Convert text to lowercase for consistency.

# %%
# your code here
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


job_des = {}
for i in range(df.shape[0]):
  job_des[i] = word_tokenize(df['Job Description'][i])
  job_des[i] = [word.lower() for word in job_des[i] if word.lower() not in stopwords.words('english')  and word.isalnum()]


for key, value in job_des.items():
    print(key, ":", value)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0 : ['location', 'plano', 'tx', 'oklahoma', 'city', 'ok', 'duration', 'internship', 'summer', '2017', 'term', 'job', 'summary', 'visual', 'bi', 'solutions', 'inc', 'seeking', 'graduate', 'interns', 'strong', 'bi', 'big', 'data', 'analytics', 'solutions', 'sap', 'bw', 'sap', 'hana', 'oracle', 'ms', 'sql', 'edw', 'bods', 'sas', 'big', 'data', 'visualization', 'tools', 'join', 'college', 'recruiting', 'hiring', 'program', 'role', 'would', 'building', 'bi', 'analytics', 'big', 'data', 'solutions', 'would', 'consumed', 'leaders', 'executives', 'fortune', '500', 'organizations', 'strong', 'sense', 'business', 'analysis', 'etl', 'data', 'modeling', 'data', 'warehousing', 'visualization', 'reporting', 'advanced', 'analytics', 'data', 'interpretation', 'key', 'attributes', 'look', 'market', 'leader', 'sap', 'bi', 'analytics', 'visual', 'bi', 'selective', 'student', 'hiring', 'candidates', 'portfolio', 'project', 'blogs', 'preferred', 'work', 'experience', 'academic', 'gpa', 'scores', 'asked', 'hone', 'bi', 'analytics', 'expertise', 'internship', 'working', 'best', 'customers', 'bi', 'talent', 'world', 'years', 'bi', 'edw', 'etl', 'big', 'data', 'development', 'relevant', 'work', 'experience', 'preferred', 'bi', 'consider', 'projects', 'showcase', 'experience', 'areas', 'sap', 'hana', 'sap', 'bw', 'sap', 'bods', 'big', 'data', 'frameworks', 'candidates', 'reporting', 'web', 'development', 'skills', 'also', 'considerebenefits', 'forefront', 'learning', 'innovation', '24x7', 'access', 'visual', 'bi', 'labs', 'learning', 'environment', 'hosts', 'innovations', 'bi', 'excellent', 'training', 'development', 'opportunities', 'internship', '10', '12', 'weeks', 'paid', 'internship', 'opportunities', 'secure', 'roles', 'bi', 'analytics', 'visual', 'bi']
# 1 : ['digital', 'marketing', 'manager', 'front', 'line', 'patient', 'consumer', 'audience', 'engagement', 'eyecare', 'services', 'partners', 'affiliates', 'leading', 'defining', 'digital', 'marketing', 'mix', 'emphasis', 'social', 'media', 'web', 'email', 'content', 'marketing', 'digital', 'marketing', 'manager', 'work', 'closely', 'cross', 'functional', 'teams', 'plan', 'execute', 'high', 'impact', 'marketing', 'strategies', 'designed', 'drive', 'functions', 'execute', 'digital', 'brand', 'presence', 'social', 'media', 'web', 'email', 'strategies', 'implementing', 'best', 'practices', 'utilizing', 'data', 'insights', 'continued', 'evolution', 'understand', 'digital', 'platforms', 'upcoming', 'trends', 'ability', 'foster', 'tangible', 'action', 'brand', 'leverage', 'brand', 'insight', 'engage', 'foster', 'stronger', 'consumer', 'engagement', 'across', 'digital', 'platforms', 'lead', 'project', 'based', 'marketing', 'initiatives', 'influencer', 'engagement', 'campaigns', 'manage', 'communications', 'internal', 'teams', 'brands', 'partners', 'oversee', 'practice', 'website', 'redesign', 'introduce', 'patient', 'communication', 'software', 'solution', 'reach', 'introduce', 'assist', 'internet', 'marketing', 'packages', 'glacial', 'manage', 'content', 'corporate', 'web', 'site', 'manage', 'digital', 'organic', 'paid', 'channels', 'track', 'analyze', 'digital', 'marketing', 'efforts', 'create', 'marketing', 'collateral', 'needed', 'corporate', 'practices', 'trade', 'show', 'banners', 'email', 'blasts', 'flyers', 'posters', 'ads', 'concepts', 'radio', 'seasonal', 'campaigns', 'specialty', 'services', 'lasik', 'cosmetic', 'piols', 'kamra', 'cataracts', 'flex', 'spending', 'back', 'school', 'exams', 'glasses', 'requirements', 'bachelors', 'degree', 'years', 'related', 'work', 'experience', 'digital', 'marketing', 'content', 'marketing', 'social', 'media', 'copy', 'writing', 'required', 'role', 'requires', 'excellent', 'collaborative', 'organizational', 'creative', 'skills', 'ability', 'build', 'strategy', 'execute', 'across', 'multiple', 'digital', 'disciplines', 'strong', 'experience', 'digital', 'content', 'across', 'platforms', 'clear', 'understanding', 'content', 'conceptualized', 'created', 'promoted', 'experience', 'working', 'digital', 'media', 'based', 'data', 'analytics', 'turn', 'insights', 'actions', 'strong', 'understanding', 'digital', 'marketing', 'across', 'disciplines', 'including', 'social', 'search', 'email', 'websites', 'content', 'experience', 'managing', 'maintaining', 'content', 'driven', 'websites', 'email', 'social', 'media', 'channels', 'strong', 'writer', 'capable', 'internalizing', 'articulating', 'brand', 'voice', 'clearly', 'present', 'ideas', 'points', 'view', 'internal', 'teams']
# 2 : ['summary', 'responsibilities', 'manager', 'pricing', 'mis', 'responsible', 'assisting', 'pricing', 'strategy', 'profitability', 'teams', 'within', 'decision', 'sciences', 'execution', 'information', 'gathering', 'reporting', 'manager', 'pricing', 'mis', 'responsible', 'managing', 'development', 'production', 'pricing', 'reporting', 'supervising', 'analysts', 'responsible', 'converting', 'existing', 'daily', 'weekly', 'monthly', 'reports', 'efficient', 'delivery', 'tools', 'includes', 'data', 'visualization', 'supervision', 'portion', 'pricing', 'mis', 'team', 'require', 'leadership', 'direction', 'timely', 'internal', 'regulatory', 'ongoing', 'reporting', 'support', 'pricing', 'strategy', 'profitability', 'segments', 'within', 'decision', 'sciences', 'consistency', 'quality', 'information', 'reports', 'along', 'repository', 'management', 'job', 'functions', 'responsible', 'assisting', 'decision', 'sciences', 'team', 'design', 'development', 'implementation', 'production', 'pricing', 'reporting', 'needs', 'ongoing', 'environmentadditionally', 'responsible', 'managing', 'automation', 'implementation', 'process', 'new', 'reports', 'appropriate', 'converting', 'existing', 'business', 'usual', 'reports', 'automated', 'delivery', 'working', 'information', 'technology', 'organization', 'assigned', 'consultants', 'existing', 'staff', 'develop', 'governance', 'process', 'converting', 'appropriate', 'reports', 'efficient', 'data', 'visualization', 'adopt', 'develop', 'best', 'practices', 'report', 'templates', 'toolsestablish', 'manage', 'pricing', 'governance', 'team', 'drive', 'location', 'sharepoint', 'sites', 'repository', 'documentsassure', 'clear', 'concise', 'objective', 'reportingidentify', 'escalate', 'issues', 'observations', 'ariseother', 'functions', 'maintain', 'ongoing', 'relationships', 'management', 'throughout', 'organization', 'effectively', 'manage', 'motivate', 'teamcomplete', 'additional', 'work', 'within', 'specified', 'timescales', 'line', 'departmental', 'standardsresponsible', 'aspects', 'team', 'members', 'life', 'cycle', 'including', 'recruitment', 'performance', 'management', 'development', 'coachingensure', 'tasks', 'carried', 'high', 'degree', 'support', 'junior', 'analysts', 'interns', 'relative', 'production', 'reporting', 'bachelors', 'degree', 'computer', 'mis', 'related', 'field', 'equivalent', 'combination', 'education', 'experience', '1', 'three', '3', 'years', 'previous', 'management', 'experience', 'required', '3', 'years', 'specific', 'auto', 'industry', 'experience', 'working', 'reporting', 'candidates', 'meet', 'stated', 'requirements', 'management', 'experience', 'otherwise', 'qualified', 'may', 'selected', 'role', 'contingent', 'upon', 'completion', 'prescribed', 'training', 'years', 'progressively', 'responsible', 'experience', 'within', 'financial', 'services', 'management', 'mis', 'within', 'financial', 'services', 'institution', 'requiredexpertise', 'pc', 'software', 'applications', 'sql', 'sas', 'excel', 'word', 'powerpoint', 'access', 'dashboardsexperience', 'tableau', 'similar', 'data', 'visualization', 'tools', 'plusdetailed', 'knowledge', 'information', 'reporting', 'structures', 'extraction', 'transformation', 'loading', 'etls', 'data', 'management', 'data', 'warehouse', 'data', 'validation', 'models', 'etc', 'knowledge', 'financial', 'statements', 'accounting', 'principles', 'credit', 'policy', 'applicable', 'laws', 'industry', 'data', 'information', 'integrity', 'accurate', 'reportingexcellent', 'analytical', 'technical', 'problem', 'solving', 'skills', 'strong', 'attention', 'detailability', 'effectively', 'explain', 'others', 'understand', 'approach', 'complicated', 'issuesexceptional', 'verbal', 'written', 'communication', 'collaboration', 'time', 'management', 'skillspossess', 'strong', 'leadership', 'skills', 'focus', 'development', 'mentorshipability', 'adapt', 'various', 'work', 'environments', 'project', 'schedulesability', 'work', 'effectively', 'team', 'environment', ...
# 3 : ['organizational', 'summary', 'part', 'nation', 'central', 'bank', 'federal', 'reserve', 'bank', 'dallas', 'committed', 'strengthening', 'economy', 'communities', 'fed', 'opportunity', 'become', 'part', 'important', 'public', 'service', 'institution', 'whose', 'work', 'touches', 'lives', 'across', 'globe', 'big', 'job', 'need', 'talented', 'professionals', 'care', 'making', 'difference', 'position', 'summary', 'treasury', 'services', 'intern', 'federal', 'reserve', 'bank', 'dallas', 'treasury', 'services', 'department', 'regularly', 'apply', 'analytical', 'problem', 'solving', 'written', 'interpersonal', 'skills', 'opportunity', 'expand', 'knowledge', 'project', 'operations', 'management', 'process', 'improvement', 'learn', 'various', 'areas', 'team', 'environment', 'responsibilities', 'organize', 'department', 'training', 'data', 'usable', 'outline', 'electronic', 'handbook', 'examine', 'unstructured', 'data', 'identify', 'deleted', 'retained', 'assist', 'physical', 'inventory', 'organization', 'storage', 'areas', 'analyze', 'process', 'patching', 'computers', 'maintain', 'security', 'controls', 'automate', 'reporting', 'vendor', 'scorecards', 'utilize', 'creativity', 'designing', 'marketing', 'materials', 'work', 'ad', 'hoc', 'assignments', 'requested', 'participate', 'meetings', 'trainings', 'assigned', 'education', 'experience', 'strong', 'writing', 'skills', 'including', 'ability', 'write', 'clearly', 'correctly', 'concisely', 'ability', 'analyze', 'problems', 'inquiries', 'ability', 'prioritize', 'tasks', 'projects', 'meet', 'business', 'needs', 'logical', 'sequence', 'ability', 'maintain', 'flexibility', 'adapt', 'changes', 'business', 'environment', 'ability', 'work', 'general', 'guidance', 'broad', 'assignments', 'ability', 'take', 'direction', 'easily', 'interpret', 'directives', 'execute', 'efficient', 'manner', 'highly', 'organized', 'detail', 'oriented', 'adheres', 'high', 'standard', 'core', 'values', 'ethics', 'align', 'organization', 'maintains', 'high', 'integrity', 'trust', 'strong', 'interpersonal', 'oral', 'communication', 'skills', 'including', 'speaking', 'clearly', 'confidently', 'communicating', 'levels', 'stakeholders', 'support', 'staff', 'senior', 'level', 'executives', 'proficient', 'use', 'personal', 'computers', 'various', 'software', 'packages', 'including', 'ms', 'sharepoint', 'word', 'excel', 'powerpoint', 'currently', 'enrolled', 'college', 'seeking', 'qualifying', 'degree', 'bachelor', 'degree', 'business', 'administration', 'related', 'field', 'prior', 'knowledge', 'principles', 'practices', 'business', 'operations', 'management', 'project', 'management', 'coursework', 'practical', 'experience', 'work', 'hours', 'conditions', '40', 'hours', 'monday', 'friday', 'pm', 'overtime', 'may', 'required', 'needed', 'basis', 'security', 'sensitive', 'position', 'federal', 'law', 'position', 'requires', 'candidates', 'citizen', 'proud', 'equal', 'opportunity', 'employer']
# 4 : ['aviall', 'world', 'largest', 'provider', 'new', 'aviation', 'parts', 'related', 'aftermarket', 'services', 'aviall', 'markets', 'distributes', 'products', '240', 'manufacturers', 'offers', 'approximately', 'catalog', 'items', '40', 'customer', 'service', 'centers', 'located', 'north', 'america', 'europe', 'aviall', 'prides', 'culture', 'throughout', 'organization', 'offer', 'environment', 'diverse', 'challenging', 'supportive', 'provides', 'experience', 'responsibilities', 'serves', 'springboard', 'successful', 'career', 'also', 'proud', 'consistently', 'receive', 'outstanding', 'awards', 'diversity', 'recruitment', 'efforts', 'including', 'top', '100', 'come', 'join', 'talented', 'world', 'class', 'team', 'thrive', 'dynamic', 'supportive', 'culture', 'position', 'summary', 'aviall', 'exciting', 'position', 'sales', 'intern', 'corporate', 'headquarters', 'located', 'dallas', 'tx', 'sales', 'intern', 'assist', 'department', 'various', 'information', 'technology', 'initiatives', 'may', 'include', 'limited', 'data', 'analytics', 'logistics', 'pricing', 'reporting', 'skillset', 'focus', 'efficiency', 'opportunity', 'scenarios', 'within', 'group', 'additionally', 'internship', 'provides', 'opportunity', 'build', 'relationships', 'develop', 'business', 'acumen', 'networking', 'aviall', 'interns', 'across', 'enterprise', 'interaction', 'various', 'aviall', 'leaders', 'expected', 'starting', 'date', 'position', 'may', '15', '2017', 'job', 'requirements', 'qualifications', 'completed', 'first', 'semester', 'junior', 'year', 'first', 'semester', 'master', 'program', 'may', '15', '2017', 'overall', 'gpa', 'good', 'presentation', 'speaking', 'organizational', 'problem', 'solving', 'skills', 'thorough', 'attention', 'detail', 'capability', 'meet', 'deadlines', 'ability', 'adapt', 'change', 'willingness', 'flexible', 'global', 'team', 'environment', 'excellent', 'written', 'communication', 'skills', 'ability', 'document', 'technical', 'information', 'easy', 'understand', 'straightforward', 'manner', 'aviall', 'equal', 'opportunity', 'employer', 'employment', 'decisions', 'made', 'without', 'regard', 'race', 'color', 'religion', 'sex', 'sexual', 'orientation', 'gender', 'identity', 'national', 'origin', 'disability', 'veteran', 'status', 'characteristics', 'protected', 'law', 'education', 'college', 'coursework', 'completed']
# 5 : ['organizational', 'summary', 'part', 'nation', 'central', 'bank', 'federal', 'reserve', 'bank', 'dallas', 'committed', 'strengthening', 'economy', 'communities', 'fed', 'opportunity', 'become', 'part', 'important', 'public', 'service', 'institution', 'whose', 'work', 'touches', 'lives', 'across', 'globe', 'big', 'job', 'need', 'talented', 'professionals', 'care', 'making', 'difference', 'position', 'summary', 'human', 'resources', 'analyst', 'intern', 'assist', 'hr', 'department', 'building', 'human', 'capital', 'data', 'analytics', 'practices', 'ensuring', 'aspects', 'human', 'resources', 'represented', 'role', 'intern', 'opportunity', 'partner', 'compensation', 'payroll', 'hris', 'recruiting', 'onboarding', 'build', 'implement', 'tools', 'processes', 'help', 'department', 'successfully', 'solve', 'challenges', 'responsibilities', 'conduct', 'research', 'industry', 'benchmark', 'hr', 'metrics', 'develop', 'metrics', 'hr', 'include', 'limited', 'turnover', 'compensation', 'recruitment', 'diversity', 'work', 'closely', 'key', 'hr', 'units', 'business', 'areas', 'develop', 'additional', 'reports', 'part', 'internal', 'projects', 'include', 'comprehensive', 'analysis', 'trends', 'kpi', 'metrics', 'predictive', 'analytics', 'partner', 'hris', 'research', 'best', 'delivery', 'methods', 'reports', 'forms', 'documents', 'etc', 'create', 'samples', 'user', 'approval', 'education', 'experience', 'years', 'experience', 'analysis', 'reporting', 'role', 'knowledge', 'ms', 'excel', 'including', 'ability', 'utilize', 'following', 'functions', 'concatenating', 'formulas', 'conditional', 'formatting', 'pivot', 'tables', 'proactive', 'solutions', 'oriented', 'business', 'professional', 'ability', 'interface', 'levels', 'management', 'across', 'business', 'units', 'functions', 'ability', 'handle', 'sensitive', 'information', 'highest', 'degree', 'integrity', 'confidentiality', 'junior', 'higher', 'pursuing', 'degree', 'human', 'resources', 'business', 'related', 'field', 'work', 'hours', 'conditions', '40', 'hours', 'monday', 'friday', 'business', 'hours', '8am', '5pm', 'proud', 'equal', 'opportunity', 'employer']
# 6 : ['atos', 'leader', 'digital', 'services', 'annual', 'revenue', '12', 'billion', 'employees', '72', 'countries', 'serving', 'global', 'client', 'base', 'atos', 'offers', 'consulting', 'systems', 'integration', 'managed', 'services', 'bpo', 'cloud', 'big', 'data', 'solutions', 'deep', 'technology', 'expertise', 'industry', 'knowledge', 'atos', 'works', 'clients', 'across', 'many', 'business', 'sectors', 'defense', 'financial', 'services', 'health', 'manufacturing', 'media', 'utilities', 'public', 'sector', 'retail', 'telecommunications', 'focused', 'business', 'technology', 'powers', 'progress', 'helps', 'organizations', 'create', 'firm', 'future', 'addition', 'atos', 'worldwide', 'information', 'technology', 'partner', 'olympic', 'paralympic', 'games', 'operates', 'brands', 'atos', 'bull', 'canopy', 'unify', 'worldline', 'atos', 'offers', 'broad', 'professional', 'perspective', 'opportunity', 'build', 'rewarding', 'career', 'across', 'either', 'technical', 'business', 'paths', 'worldwide', 'presence', 'broad', 'range', 'professional', 'services', 'atos', 'provides', 'training', 'programs', 'across', 'competencies', 'markets', 'worldwide', 'employees', 'stages', 'career', 'addition', 'offer', 'programs', 'focused', 'engaging', 'developing', 'people', 'beginning', 'career', 'internships', 'graduate', 'opportunities', 'information', 'please', 'see', 'atos', 'corporate', 'web', 'site', 'atos', 'eeo', 'employer', 'providing', 'employment', 'opportunity', 'regardless', 'race', 'color', 'religion', 'sex', 'age', 'national', 'origin', 'veteran', 'status', 'disability', 'factors', 'protected', 'law', 'summer', 'intern', 'position', 'highly', 'motivated', 'independent', 'intern', 'join', 'outsourcing', 'presales', 'team', 'intern', 'responsible', 'designing', 'developing', 'reports', 'interactive', 'dashboards', 'utilized', 'organization', 'successful', 'candidate', 'proven', 'abilities', 'motivation', 'strong', 'data', 'analytics', 'knowledge', 'exceptional', 'problem', 'solving', 'skills', 'attention', 'work', 'teams', 'gather', 'analyze', 'document', 'reporting', 'requirements', 'meet', 'business', 'translate', 'business', 'requirements', 'specifications', 'used', 'implement', 'required', 'reports', 'interactive', 'dashboards', 'created', 'potentially', 'multiple', 'data', 'design', 'develop', 'deploy', 'tableau', 'interactive', 'validation', 'testing', 'critical', 'business', 'closely', 'monitor', 'check', 'accuracy', 'completeness', 'data', 'tableau', 'perform', 'optimization', 'tableau', 'reports', 'minimum', 'qualifications', 'excellent', 'communication', 'skills', 'written', 'oral', 'comfortable', 'ambiguity', 'change', 'working', 'agile', 'manner', 'ideal', 'candidate', 'must', 'professional', 'work', 'independently', 'must', 'outstanding', 'organizational', 'verbal', 'written', 'skills', 'proficiency', 'microsoft', 'office', 'suite', 'required', 'including', 'strong', 'excel', 'skills', 'familiarity', 'microsoft', 'access', 'sharepoint', 'preferred', 'qualifications', 'sql', 'database', 'experience', 'knowledge', 'business', 'intelligence', 'analytics', 'tools', 'like', 'business', 'objects', 'tableau', 'similar', 'data', 'mining', 'service', 'ability', 'write', 'variables', 'understand', 'scripts', 'data', 'mining', 'statistics', 'analytical', 'modeling', 'must', 'currently', 'enrolled', 'college', 'technical', 'institute', 'graduated', 'within', '6', 'months', 'high', 'degree', 'interest', 'internships', 'intended', 'positions', 'limited', 'duration', 'maximum', 'duration', 'ten', 'months', '1560', 'hours', 'per', 'year', 'max', 'effective', 'communication', 'interpersonal', 'skills', 'written', 'verbal', 'ability', 'work', 'team', 'background', 'checks', 'required', 'interns']
# 7 : ['job', 'details', 'intern', 'business', 'analytics', 'us', 'texas', 'dallas', 'us', 'texas', 'usa', 'apply', 'job', 'reference', '231127', 'country', 'usa', 'region', 'us', 'texas', 'city', 'us', 'texas', 'dallas', 'position', 'type', 'student', 'job', 'area', 'job', 'type', 'part', 'time', '50', 'company', 'atos', 'company', 'information', 'atos', 'leader', 'digital', 'services', 'annual', 'revenue', '12', 'billion', 'employees', '72', 'countries', 'serving', 'global', 'client', 'base', 'atos', 'offers', 'consulting', 'systems', 'integration', 'managed', 'services', 'bpo', 'cloud', 'big', 'data', 'solutions', 'deep', 'technology', 'expertise', 'industry', 'knowledge', 'atos', 'works', 'clients', 'across', 'many', 'business', 'sectors', 'defense', 'financial', 'services', 'health', 'manufacturing', 'media', 'utilities', 'public', 'sector', 'retail', 'telecommunications', 'focused', 'business', 'technology', 'powers', 'progress', 'helps', 'organizations', 'create', 'firm', 'future', 'addition', 'atos', 'worldwide', 'information', 'technology', 'partner', 'olympic', 'paralympic', 'games', 'operates', 'brands', 'atos', 'bull', 'canopy', 'unify', 'worldline', 'atos', 'offers', 'broad', 'professional', 'perspective', 'opportunity', 'build', 'rewarding', 'career', 'across', 'either', 'technical', 'business', 'paths', 'worldwide', 'presence', 'broad', 'range', 'professional', 'services', 'atos', 'provides', 'training', 'programs', 'across', 'competencies', 'markets', 'worldwide', 'employees', 'stages', 'career', 'addition', 'offer', 'programs', 'focused', 'engaging', 'developing', 'people', 'beginning', 'career', 'internships', 'graduate', 'opportunities', 'information', 'please', 'see', 'atos', 'corporate', 'web', 'site', 'atos', 'eeo', 'employer', 'providing', 'employment', 'opportunity', 'regardless', 'race', 'color', 'religion', 'sex', 'age', 'national', 'origin', 'veteran', 'status', 'disability', 'factors', 'protected', 'law', 'job', 'description', 'summer', 'intern', 'position', 'highly', 'motivated', 'independent', 'intern', 'join', 'outsourcing', 'presales', 'team', 'intern', 'responsible', 'designing', 'developing', 'reports', 'interactive', 'dashboards', 'utilized', 'organization', 'successful', 'candidate', 'proven', 'abilities', 'motivation', 'strong', 'data', 'analytics', 'knowledge', 'exceptional', 'problem', 'solving', 'skills', 'attention', 'work', 'teams', 'gather', 'analyze', 'document', 'reporting', 'requirements', 'meet', 'business', 'translate', 'business', 'requirements', 'specifications', 'used', 'implement', 'required', 'reports', 'interactive', 'dashboards', 'created', 'potentially', 'multiple', 'data', 'design', 'develop', 'deploy', 'tableau', 'interactive', 'validation', 'testing', 'critical', 'business', 'closely', 'monitor', 'check', 'accuracy', 'completeness', 'data', 'tableau', 'perform', 'optimization', 'tableau', 'reports', 'job', 'requirements', 'minimum', 'qualifications', 'excellent', 'communication', 'skills', 'written', 'oral', 'comfortable', 'ambiguity', 'change', 'working', 'agile', 'manner', 'ideal', 'candidate', 'must', 'professional', 'work', 'independently', 'must', 'outstanding', 'organizational', 'verbal', 'written', 'skills', 'proficiency', 'microsoft', 'office', 'suite', 'required', 'including', 'strong', 'excel', 'skills', 'familiarity', 'microsoft', 'access', 'sharepoint', 'preferred', 'qualifications', 'sql', 'database', 'experience', 'knowledge', 'business', 'intelligence', 'analytics', 'tools', 'like', 'business', 'objects', 'tableau', 'similar', 'data', 'mining', 'service', 'ability', 'write', 'variables', 'understand', 'scripts', 'data', 'mining', 'statistics', 'analytical', 'modeling', 'additional', 'information', 'must', 'currently', 'enrolled', 'college', 'technical', 'institute', 'graduated', 'within', '6', 'months', 'high', 'degree', 'interest', 'internships', 'intended', 'positions', 'limited', 'duration', 'maximum', 'duration', 'ten', 'months', '1560', 'hours', 'per' ...
# 8 : ['job', 'descriptions', 'downtown', 'agency', 'looking', 'rockstar', 'digital', 'marketing', 'intern', 'working', 'alongside', 'team', 'second', 'none', 'latest', 'greatest', 'marketing', 'trends', 'digital', 'world', 'familiar', 'industry', 'paid', 'owned', 'earned', 'media', 'concepts', 'understanding', 'digital', 'marketing', 'data', 'used', 'drive', 'channel', 'familiar', 'reporting', 'excel', 'hacks', 'would', 'also', 'beneficial', 'born', 'superpowers', 'heard', 'professors', 'colleagues', 'discussing', 'booming', 'trend', 'looking', 'join', 'us', 'work', 'closely', 'digital', 'marketing', 'team', 'coordinate', 'account', 'managers', 'web', 'developers', 'creative', 'strategy', 'would', 'include', 'keyword', 'research', 'content', 'production', 'optimization', 'data', 'analysis', 'quality', 'assurance', 'testing', 'opportunity', 'identification', 'troubleshooting', 'technical', 'execute', 'tactical', 'seo', 'ppc', 'part', 'client', 'meetings', 'discussing', 'facets', 'digital', 'marketing', 'present', 'internal', 'monthly', 'reports', 'leverage', 'data', 'demonstrate', 'impact', 'company', 'digital', 'marketing', 'services', 'design', 'test', 'analyze', 'optimize', 'scale', 'seo', 'ppc', 'content', 'marketing', 'alongside', 'social', 'media', 'channels', 'work', 'together', 'experience', 'knowledge', 'seo', 'search', 'engine', 'optimization', 'knowledge', 'ppc', 'click', 'oriented', 'excel', 'wizard', 'problem', 'solving', 'ability', 'work', 'independently', 'small', 'written', 'verbal', 'communication', 'understanding', 'html', 'css', 'java', 'script', 'databases', 'general', 'website', 'content', 'strategy', 'creation', 'marketing', 'cms', 'crm', 'experience', 'great', 'digital', 'marketingfrom', '70kft']
# 9 : ['job', 'title', 'data', 'analyst', 'intern', 'job', 'summary', 'data', 'analyst', 'partner', 'business', 'understand', 'business', 'needs', 'facilitate', 'flow', 'data', 'stearns', 'loan', 'origination', 'system', 'business', 'intelligence', 'system', 'addition', 'responsible', 'maintaining', 'integrity', 'data', 'well', 'documenting', 'appropriate', 'use', 'data', 'across', 'corporation', 'analyst', 'primary', 'responsibility', 'filing', 'quarterly', 'mortgage', 'call', 'compliance', 'reports', 'multiple', 'entities', 'using', 'cognos', 'database', 'work', 'closely', 'management', 'evaluate', 'business', 'requirements', 'support', 'delivery', 'effective', 'business', 'intelligence', 'reporting', 'solutions', 'job', 'functions', 'analyze', 'transactional', 'level', 'data', 'excel', 'access', 'check', 'data', 'gaps', 'issues', 'could', 'include', 'limited', 'missing', 'data', 'duplication', 'data', 'incorrect', 'irrelevant', 'business', 'inquiries', 'related', 'data', 'entered', 'loan', 'origination', 'systemaudit', 'reports', 'accuracy', 'consistency', 'completeness', 'interface', 'report', 'users', 'ensure', 'reports', 'meet', 'business', 'needs', 'perform', 'data', 'quality', 'management', 'activities', 'including', 'data', 'profiling', 'data', 'validation', 'assessing', 'data', 'relevancy', 'improve', 'information', 'analyze', 'relevant', 'source', 'data', 'work', 'appropriate', 'personnel', 'address', 'unexpected', 'data', 'content', 'anomalies', 'support', 'business', 'requirements', 'thorough', 'data', 'analysis', 'maintain', 'documentation', 'processes', 'reports', 'applications', 'proceduresserve', 'group', 'sme', 'metadata', 'including', 'definitions', 'business', 'data', 'quality', 'rules', 'sourcing', 'business', 'definitions', 'documents', 'collect', 'analyze', 'information', 'preparation', 'setting', 'format', 'load', 'data', 'maintain', 'reporting', 'requirements', 'quarterly', 'filing', 'mortgage', 'call', 'report', 'state', 'regulatory', 'records', 'data', 'supplied', 'regulators', 'job', 'requirements', 'proficiency', 'excel', 'ms', 'sqlbachelor', 'degree', 'computer', 'science', 'related', 'fieldstrong', 'attention', 'detail', 'ability', 'manipulate', 'large', 'pools', 'data', 'accuratelyexperience', 'using', 'ibm', 'cognos', 'microsoft', 'access', 'plus']
# 10 : ['passionate', 'change', 'real', 'world', 'application', 'ready', 'take', 'academic', 'education', 'next', 'level', 'join', 'business', 'technology', 'analyst', 'summer', 'scholar', 'program', 'learn', 'bridge', 'theoretical', 'practical', 'immersive', 'fast', 'paced', 'work', 'environment', 'summer', 'scholars', 'leverage', 'strategic', 'thinking', 'foundational', 'business', 'technology', 'skills', 'advise', 'clients', 'cut', 'complexity', 'inspire', 'decisions', 'collaborative', 'team', 'setting', 'work', 'doas', 'business', 'technology', 'analyst', 'summer', 'scholar', 'opportunities', 'make', 'impact', 'broad', 'range', 'transformative', 'projects', 'clients', 'support', 'delivery', 'various', 'types', 'client', 'deliverables', 'range', 'information', 'management', 'solutions', 'implementations', 'large', 'scale', 'technology', 'platforms', 'supporting', 'development', 'advisory', 'materials', 'technical', 'architecture', 'operating', 'models', 'please', 'see', 'technology', 'service', 'offerings', 'learn', 'work', 'every', 'day', 'help', 'solve', 'client', 'challenging', 'problems', 'capitalize', 'cross', 'industry', 'presence', 'find', 'niche', 'begin', 'building', 'individual', 'career', 'consulting', 'dynamic', 'evolving', 'look', 'people', 'perform', 'certain', 'areas', 'grow', 'related', 'skills', 'deliver', 'exceptional', 'results', 'clients', 'recognize', 'unique', 'skills', 'experiences', 'interests', 'divide', 'broad', 'scope', 'bta', 'intern', 'role', 'segments', 'order', 'best', 'align', 'bta', 'intern', 'focus', 'area', 'segments', 'function', 'subgroups', 'interns', 'analysts', 'leverage', 'network', 'enhance', 'professional', 'development', 'setting', 'people', 'success', 'highest', 'currently', 'recruiting', 'business', 'technology', 'analyst', 'summer', 'scholars', 'whose', 'skills', 'interests', 'align', 'one', 'following', 'areas', 'technology', 'design', 'development', 'analyst', 'skilled', 'programming', 'prepared', 'jump', 'technical', 'role', 'top', 'performer', 'computer', 'science', 'software', 'engineering', 'mis', 'proficient', 'one', 'programming', 'languages', 'additional', 'experience', 'interest', 'areas', 'app', 'development', 'user', 'design', 'server', 'side', 'development', 'os', 'languages', 'windows', 'linux', 'potential', 'project', 'roles', 'may', 'solution', 'architect', 'analyst', 'software', 'developer', 'database', 'administrator', 'qa', 'data', 'analytics', 'analyst', 'knowledgeable', 'interest', 'across', 'wide', 'range', 'analytics', 'data', 'transformation', 'tools', 'able', 'transform', 'client', 'data', 'meaningful', 'actionable', 'insights', 'comfortable', 'emerging', 'trends', 'discipline', 'versatile', 'technically', 'functionally', 'potential', 'project', 'roles', 'may', 'big', 'data', 'developer', 'data', 'scientist', 'data', 'management', 'data', 'visualization', 'engineer', 'data', 'transformation', 'analytics', 'organization', 'assessment', 'teamour', 'technology', 'consulting', 'team', 'plays', 'major', 'role', 'directly', 'embedding', 'technology', 'insights', 'clients', 'organizational', 'goals', 'deloitte', 'technology', 'consultants', 'create', 'solutions', 'within', 'organization', 'operating', 'model', 'accounting', 'people', 'intellectual', 'capital', 'technology', 'processes', 'engagement', 'teams', 'deloitte', 'drive', 'value', 'clients', 'also', 'understand', 'importance', 'developing', 'resources', 'contributing', 'communities', 'work', 'make', 'business', 'take', 'issue', 'impact', 'within', 'beyond', 'client', 'setting', 'learn', 'technology', 'consulting', 'junior', 'standing', 'academic', 'program', 'target', 'graduation', 'date', 'december', '2017', 'june', 'undergraduate', 'following', 'related', 'majors', 'technology', 'science', 'computer', 'science', 'computer', 'information', 'systems', 'management', 'information', 'systems', 'network', 'data', 'analytics', 'matho', 'business', 'accounting', 'analytics', 'business', 'economics', 'finance', ...
# 11 : ['experience', 'connections', 'intern', 'seasoned', 'healthcare', 'technology', 'professionals', 'expand', 'knowledge', 'base', 'spend', '12', 'weeks', 'make', 'lifetime', 'difference', 'interacting', 'data', 'scientist', 'intern', 'work', 'data', 'analytics', 'team', 'looking', 'individual', 'pursing', 'degree', 'information', 'technology', 'computer', 'engineering', 'computer', 'science', 'related', 'major', 'summary', 'duties', 'intern', 'expect', 'perform', 'working', 'mentor', 'summer', 'role', 'take', 'one', 'existing', 'business', 'processes', 'apply', 'data', 'science', 'techniques', 'machine', 'learning', 'either', 'match', 'improve', 'current', 'performance', 'intern', 'need', 'collaborate', 'stakeholders', 'understand', 'process', 'desired', 'improvements', 'heavy', 'data', 'engineering', 'work', 'already', 'done', 'job', 'require', 'data', 'wrangling', 'feature', 'engineering', 'prepare', 'machine', 'learning', 'model', 'selected', 'rationale', 'decision', 'model', 'need', 'explained', 'business', 'stakeholders', 'pythonsqldata', 'wranglingfeature', 'engineeringmachine', 'learningmodel', 'evaluationdata', 'visualization']
# 12 : ['requisition', 'number', 'post', 'date', 'title', 'digital', 'marketing', 'intern', 'city', 'dfw', 'airport', 'state', 'tx', 'job', 'group', 'marketing', 'description', 'marketing', 'grapevine', 'texas', 'http', 'dex', 'media', 'looking', 'marketing', 'interns', 'dex', 'media', 'summer', 'intern', 'program', '3', 'month', 'paid', 'internship', 'open', 'junior', 'senior', 'graduate', 'program', 'students', 'digitally', 'savvy', 'talented', 'organized', 'love', 'creativity', 'marketing', 'smart', 'enough', 'know', 'know', 'eager', 'listen', 'learn', 'grow', 'driven', 'ambitious', 'innovative', 'enjoy', 'part', 'team', 'marketing', 'assignments', 'available', 'grapevine', 'tx', 'location', 'corporate', 'communications', 'communications', 'writing', 'social', 'media', 'marketing', 'communications', 'branding', 'reading', 'video', 'production', 'email', 'development', 'html', 'graphic', 'design', 'indesign', 'photoshop', 'customer', 'relationship', 'management', 'crm', 'driving', 'client', 'engagement', 'app', 'messaging', 'ab', 'testing', 'drive', 'end', 'user', 'engagement', 'digital', 'marketing', 'digital', 'product', 'marketing', 'content', 'writer', 'data', 'analyst', 'web', 'developer', 'journalist', 'writer', 'digital', 'mobile', 'internet', 'marketing', 'analyst', 'utilize', 'database', 'knowledge', 'programming', 'skills', 'data', 'manipulation', 'query', 'tools', 'produce', 'actionable', 'data', 'used', 'support', 'marketing', 'sales', 'consult', 'internal', 'teams', 'define', 'requirements', 'timelines', 'ensure', 'timely', 'accurate', 'delivery', 'data', 'elements', 'tools', 'required', 'projects', 'initiatives', 'summarize', 'communicate', 'progress', 'processes', 'insights', 'recommendations', 'via', 'summary', 'documents', 'presentations', 'support', 'management', 'requirements', 'year', 'experience', 'junior', 'senior', 'graduate', 'students', 'available', 'work', 'june', 'hours', 'monday', 'friday', 'grapevine', 'tx', 'location', 'students', 'pursuing', 'degree', 'marketing', 'digital', 'marketing', 'marketing', 'analytics', 'journalism', 'social', 'media', 'communications', 'advertising', 'journalism', 'pr', 'english', 'related', 'field', 'basic', 'knowledge', 'relational', 'databases', 'ms', 'access', 'oracle', 'sql', 'server', 'sql', 'marketing', 'analyst', 'position', 'students', 'must', 'demonstrated', 'leadership', 'throughout', 'college', 'career', 'must', 'organized', 'must', 'proficient', 'skills', 'using', 'social', 'media', 'microsoft', 'office', 'suite', 'knowledge', 'adobe', 'suite', 'helpful', 'video', 'production', 'editing', 'experience', 'preferred', 'applies', 'video', 'assignment', 'strong', 'eye', 'details', 'understanding', 'marketing', 'strategies', 'digital', 'advertising', 'branding', 'industry', 'trends', 'good', 'presentation', 'skills', 'excellent', 'oral', 'written', 'communication', 'skills', 'must', 'exhibit', 'excellent', 'writing', 'interpersonal', 'skills', 'dex', 'media', 'dedicated', 'working', 'local', 'businesses', 'provide', 'powerful', 'marketing', 'solutions', 'marketing', 'solutions', 'leader', 'trusted', 'local', 'business', 'clients', 'nationwide', 'committed', 'helping', 'clients', 'create', 'grow', 'customer', 'relationships', 'providing', 'custom', 'mix', 'marketing', 'solutions', 'include', 'websites', 'print', 'mobile', 'social', 'media', 'search', 'engine', 'marketing', 'passion', 'delivering', 'highest', 'quality', 'solutions', 'best', 'value', 'help', 'businesses', 'sizes', 'meet', 'goals', 'http', 'dex', 'media', 'equal', 'opportunity', 'employer']
# 13 : ['position', 'qualifications', 'clerical', 'internship', 'paid', 'summer', '2017', 'brinks', 'coppell', 'texas', '75019', '15', '17', 'hour', 'temporary', 'internship40', 'day', 'week', 'preferred', 'overview', 'internships', 'week', 'summer', 'program', 'starting', 'june', 'allows', 'college', 'seniors', 'perusing', 'mba', 'opportunity', 'develop', 'skills', 'exposure', 'learn', 'drive', 'new', 'revenue', 'large', 'business', 'seek', 'provide', 'rewarding', 'opportunity', 'interns', 'develop', 'technical', 'management', 'leadership', 'skills', 'outside', 'interns', 'encouraged', 'develop', 'administrative', 'analytical', 'technical', 'writing', 'skills', 'supporting', 'global', 'team', 'new', 'project', 'proposals', 'marketing', 'pursuits', 'production', 'analysis', 'presentation', 'manage', 'calendar', 'scheduling', 'meeting', 'assist', 'data', 'entry', 'system', 'files', 'compose', 'transmit', 'routine', 'coordinate', 'arrange', 'meetings', 'prepare', 'agendas', 'prepare', 'prepare', 'outgoing', 'mail', 'correspondence', 'including', 'manage', 'office', 'inventory', 'organize', 'maintain', 'file', 'assist', 'various', 'projects', 'assignedqualifications', 'candidate', 'must', 'college', 'senior', 'pursuing', 'bachelor', 'degree', 'business', 'student', 'must', 'good', 'academic', 'standing', 'overall', 'gpa', 'prior', 'related', 'business', 'marketing', 'experience', 'strong', 'communication', 'skills', 'proven', 'time', 'ability', 'adapt', 'various', 'situations', 'work', 'fast', 'paced', 'environment', 'flexible', 'demonstrate', 'leadership', 'take', 'lead', 'little', 'guidance', 'work', 'builds', 'rapport', 'interact', 'professionally', 'various', 'business', 'partners', 'critical', 'thinking', 'creative', 'program', 'solving', 'strong', 'partnership', 'working', 'knowledge', 'microsoft', 'outlook', 'excel', 'particular', 'emphasis', 'list', 'lead', 'brink', 'sbrink', 'global', 'leader', 'security', 'logistics', 'services', 'trusted', 'banks', 'financial', 'institutions', 'businesses', 'public', 'private', 'sectors', 'deliver', 'currency', 'world', 'businesses', 'communities', 'needed', 'trusted', 'valued', 'makes', 'us', 'proud', 'brink', 'proud', 'equal', 'opportunity', 'employer', 'discriminate', 'employee', 'applicant', 'employment', 'race', 'color', 'sex', 'age', 'national', 'origin', 'religion', 'sexual', 'orientation', 'gender', 'identity', 'status', 'veteran', 'basis', 'disability', 'federal', 'state', 'local', 'protected', 'class']
# 14 : ['aviall', 'world', 'largest', 'provider', 'new', 'aviation', 'parts', 'related', 'aftermarket', 'services', 'aviall', 'markets', 'distributes', 'products', '240', 'manufacturers', 'offers', 'approximately', 'catalog', 'items', '40', 'customer', 'service', 'centers', 'located', 'north', 'america', 'europe', 'aviall', 'prides', 'culture', 'throughout', 'organization', 'offer', 'environment', 'diverse', 'challenging', 'supportive', 'provides', 'experience', 'responsibilities', 'serves', 'springboard', 'successful', 'career', 'also', 'proud', 'consistently', 'receive', 'outstanding', 'awards', 'diversity', 'recruitment', 'efforts', 'including', 'top', '100', 'come', 'join', 'talented', 'world', 'class', 'team', 'thrive', 'dynamic', 'supportive', 'culture', 'position', 'summary', 'aviall', 'exciting', 'position', 'business', 'strategy', 'intern', 'corporate', 'headquarters', 'located', 'dallas', 'tx', 'business', 'strategy', 'intern', 'opportunity', 'focus', 'key', 'project', 'series', 'projects', 'support', 'strategic', 'initiatives', 'additionally', 'internship', 'provides', 'opportunity', 'build', 'relationships', 'develop', 'business', 'acumen', 'networking', 'aviall', 'interns', 'across', 'enterprise', 'interaction', 'various', 'aviall', 'leaders', 'expected', 'starting', 'date', 'position', 'may', '15', '2017', 'responsibilities', 'assists', 'preparation', 'analyses', 'one', 'following', 'areas', 'planning', 'forecasting', 'planning', 'product', 'performance', 'campaign', 'performance', 'process', 'performance', 'financial', 'impact', 'analysis', 'member', 'behavior', 'analysis', 'participates', 'providing', 'input', 'definition', 'business', 'problems', 'opportunities', 'development', 'data', 'analytical', 'requirements', 'assists', 'data', 'aggregation', 'representation', 'provides', 'input', 'articulate', 'key', 'messages', 'performs', 'financial', 'forecasting', 'competitive', 'intelligence', 'business', 'planning', 'business', 'problem', 'analysis', 'assists', 'business', 'case', 'development', 'including', 'gathering', 'requirements', 'analyzing', 'business', 'trends', 'researching', 'historical', 'data', 'reviewing', 'industry', 'standards', 'recommending', 'presenting', 'solutions', 'completes', 'assigned', 'project', 'develop', 'executive', 'level', 'presentation', 'deliver', 'senior', 'leaders', 'performs', 'tasks', 'assigned', 'job', 'requirements', 'qualifications', 'familiarity', 'use', 'microsoft', 'office', 'products', 'software', 'used', 'develop', 'analysis', 'charts', 'learning', 'modules', 'supporting', 'documentation', 'completed', 'first', 'semester', 'junior', 'year', 'first', 'semester', 'master', 'program', 'may', '15', '2017', 'actively', 'pursuing', 'bachelor', 'master', 'degree', 'business', 'marketing', 'finance', 'statistics', 'information', 'systems', 'related', 'field', 'study', 'overall', 'gpa', 'ability', 'conduct', 'industry', 'research', 'define', 'market', 'trends', 'interpret', 'financial', 'data', 'solid', 'understanding', 'business', 'market', 'analysis', 'financial', 'acumen', 'marketing', 'strong', 'analytical', 'skills', 'excellent', 'oral', 'written', 'communication', 'skills', 'experience', 'making', 'presentations', 'communicating', 'ideas', 'plans', 'management', 'education', 'college', 'coursework', 'completed']
# 15 : ['please', 'apply', 'interested', 'order', 'considered', 'position', 'must', '1', 'apply', 'job', 'portal', 'including', 'resume', 'transcript', '2', 'apply', 'grant', 'thornton', 'job', 'portal', 'including', 'resume', 'transcript', 'grant', 'thornton', 'grant', 'thornton', 'collaborative', 'entrepreneurial', 'firm', 'move', 'part', 'dynamic', 'global', 'organization', 'people', 'serving', 'clients', '120', 'countries', 'agility', 'focus', 'takes', 'leader', 'founded', 'chicago', '1924', 'grant', 'thornton', 'llp', 'grant', 'thornton', 'member', 'firm', 'grant', 'thornton', 'international', 'ltd', 'one', 'world', 'leading', 'organizations', 'independent', 'audit', 'tax', 'advisory', 'firms', 'grant', 'thornton', 'revenue', 'excess', 'billion', 'operates', '58', 'offices', 'across', 'united', 'states', '565', 'partners', 'employees', 'grant', 'thornton', 'works', 'broad', 'range', 'publicly', 'privately', 'held', 'companies', 'government', 'agencies', 'financial', 'institutions', 'civic', 'religious', 'organizations', 'core', 'industries', 'served', 'include', 'consumer', 'industrial', 'products', 'financial', 'services', 'private', 'equity', 'technology', 'grant', 'thornton', 'focuses', 'serving', 'dynamic', 'organizations', 'pursue', 'growth', 'holistically', 'whether', 'revenue', 'improvement', 'leadership', 'mission', 'fulfillment', 'innovation', 'committed', 'capitalizing', 'strengths', 'serving', 'dynamic', 'organizations', 'share', 'values', 'drive', 'global', 'values', 'collaboration', 'leadership', 'excellence', 'agility', 'respect', 'responsibility', 'clearr', 'guide', 'behaviors', 'fuel', 'ambition', 'firm', 'makes', 'difference', 'every', 'day', 'provide', 'companies', 'guidance', 'need', 'help', 'run', 'businesses', 'establish', 'robust', 'internal', 'controls', 'use', 'information', 'effectively', 'improve', 'performance', 'services', 'include', 'compliance', 'consulting', 'services', 'information', 'technology', 'solutions', 'forensic', 'accounting', 'investigative', 'services', 'recovery', 'reorganization', 'tax', 'preparation', 'valuation', 'name', 'risk', 'advisory', 'services', 'ras', 'digitization', 'currencies', 'transactions', 'relationships', 'experiences', 'assets', 'transformed', 'entire', 'industries', 'cyber', 'capabilities', 'extend', 'borders', 'reach', 'creating', 'new', 'customers', 'business', 'partners', 'avenues', 'access', 'methods', 'innovation', 'forms', 'value', 'time', 'ongoing', 'disruption', 'marketplace', 'competitive', 'regulatory', 'landscape', 'presents', 'continually', 'evolving', 'strategic', 'operational', 'financial', 'risks', 'move', 'forward', 'challenging', 'environment', 'many', 'management', 'teams', 'turning', 'advisers', 'like', 'grant', 'thornton', 'llp', 'broader', 'industry', 'business', 'perspectives', 'proven', 'experience', 'assist', 'developing', 'implementing', 'risk', 'management', 'programs', 'dynamic', 'organizations', 'embrace', 'risk', 'grant', 'thornton', 'risk', 'advisory', 'services', 'professionals', 'ready', 'help', 'identify', 'protect', 'key', 'assets', 'transforming', 'risk', 'driver', 'growth', 'organization', 'management', 'teams', 'effectively', 'predict', 'deploying', 'advanced', 'analytic', 'tools', 'technologies', 'processes', 'anticipate', 'address', 'risks', 'become', 'embracing', 'broader', 'deeper', 'holistic', 'approaches', 'place', 'risks', 'strategic', 'context', 'empower', 'improved', 'decision', 'establishing', 'sustainable', 'lines', 'defense', 'firmly', 'linked', 'business', 'optimizing', 'compliance', 'function', 'people', 'processes', 'technologies', 'incorporate', 'risk', 'management', 'best', 'practices', 'industry', 'respond', 'preparing', 'unexpected', 'finely', 'tuned', 'frequently', 'tested', 'external', 'response', 'mechanisms', 'become', 'ras', 'intern', 'ras', 'interns', 'gain', 'exposure', 'various', 'areas', 'practice', 'participating', 'active', 'member', 'risk', 'consulting', 'compliance', 'projects', 'becoming', ' ...
# ...
# 154 : ['analytical', 'thinker', 'passion', 'actuarial', 'sciences', 'interest', 'helping', 'organizations', 'solve', 'complex', 'actuarial', 'business', 'problems', 'interpreting', 'large', 'data', 'sets', 'looking', 'business', 'analyst', 'intern', 'work', 'human', 'capital', 'actuarial', 'team', 'help', 'build', 'financial', 'mathematical', 'models', 'improve', 'organizational', 'performance', 'start', 'involved', 'multiple', 'project', 'teams', 'clients', 'may', 'include', 'insurance', 'companies', 'employers', 'governments', 'work', 'work', 'interesting', 'complex', 'quantifying', 'risk', 'via', 'statistical', 'methods', 'part', 'wo', 'way', 'add', 'value', 'clients', 'businesses', 'opportunity', 'serve', 'clients', 'strategic', 'operational', 'capacities', 'based', 'extensive', 'exposure', 'clients', 'deep', 'analytical', 'strengths', 'team', 'human', 'capital', 'professionals', 'specialize', 'actuarial', 'services', 'apply', 'advanced', 'quantitative', 'analysis', 'wide', 'range', 'business', 'challenges', 'use', 'statistical', 'methods', 'quantify', 'risk', 'health', 'life', 'p', 'c', 'retirement', 'plans', 'clients', 'learn', 'human', 'capital', 'actuarial', 'practice', 'qualifications', 'required', 'enrollment', 'bachelor', 'master', 'degree', 'program', 'related', 'field', 'study', 'strong', 'academic', 'track', 'record', 'minimum', 'gpa', 'proficiency', 'word', 'processing', 'spreadsheet', 'presentation', 'creation', 'tools', 'well', 'internet', 'research', 'tools', 'demonstrable', 'interest', 'taking', 'soa', 'cas', 'actuarial', 'exams', 'least', 'one', 'exam', 'passed', 'excellent', 'communication', 'skills', 'willingness', 'travel', 'grow', 'two', 'important', 'tools', 'today', 'business', 'world', 'experience', 'resources', 'deloitte', 'find', 'plenty', 'week', 'long', 'learning', 'experience', 'gain', 'insights', 'technical', 'skills', 'critical', 'professional', 'behaviors', 'standards', 'mindsets', 'needed', 'effective', 'actuarial', 'consultant', 'work', 'wide', 'variety', 'talented', 'strategic', 'leaders', 'learn', 'leverage', 'data', 'statistics', 'tackle', 'business', 'challenges', 'experience', 'responsibilities', 'opportunities', 'exciting', 'career', 'tailored', 'training', 'program', 'start', 'day', '1', 'supplemented', 'learning', 'opportunities', 'throughout', 'summer', 'whether', 'job', 'virtual', 'office', 'fridays', 'summer', 'also', 'feature', 'networking', 'opportunities', 'firm', 'leadership', 'interns', 'across', 'organization', 'national', 'summer', 'intern', 'conference', 'deloitte', 'university', 'explore', 'deloitte', 'university', 'leadership', 'center', 'deloitte', 'culture', 'positive', 'supportive', 'culture', 'encourages', 'people', 'best', 'work', 'every', 'day', 'celebrate', 'individuals', 'recognizing', 'uniqueness', 'offering', 'flexibility', 'make', 'daily', 'choices', 'help', 'healthy', 'centered', 'confident', 'aware', 'offer', 'programs', 'continuously', 'looking', 'new', 'ways', 'maintain', 'culture', 'people', 'excel', 'lead', 'healthy', 'happy', 'lives', 'learn', 'life', 'deloitte', 'corporate', 'citizenship', 'deloitte', 'led', 'purpose', 'make', 'impact', 'matters', 'purpose', 'defines', 'extends', 'relationships', 'clients', 'people', 'communities', 'believe', 'business', 'power', 'inspire', 'transform', 'focus', 'education', 'giving', 'volunteerism', 'leadership', 'help', 'drive', 'positive', 'social', 'impact', 'communities', 'learn', 'deloitte', 'impact', 'world', 'recruiter', 'tips', 'want', 'job', 'seekers', 'exploring', 'opportunities', 'deloitte', 'feel', 'prepared', 'confident', 'help', 'interview', 'suggest', 'research', 'know', 'background', 'organization', 'business', 'area', 'applying', 'also', 'suggest', 'brush', 'behavioral', 'case', 'interviewing', 'skills', 'practice', 'discussing', 'experience', 'job', 'history', 'family', 'member', 'friend', 'mentor', 'check', 'recruiting', 'tips', 'deloitte', 'professionals', 'requisition', 'code', 'startwireapply']
# 155 : ['internship', 'program', 'paid', 'internship', 'program', 'designed', 'educational', 'engaging', 'opportunity', 'students', 'work', 'challenging', 'projects', 'help', 'us', 'achieve', 'mission', 'goals', 'students', 'experience', 'emersion', 'corporate', 'life', 'training', 'access', 'leaders', 'social', 'events', 'mentoring', 'capstone', 'project', 'presented', 'senior', 'management', 'position', 'information', 'title', 'turf', 'marketing', 'intern', 'flsa', 'hourly', 'temporary', 'division', 'name', 'location', 'grapevine', 'tx', 'department', 'name', 'ag', 'turf', 'hours', 'flexible', 'hours', 'week', 'supervisor', 'title', 'director', 'turf', 'principal', 'activities', 'position', 'following', 'accordance', 'applicable', 'federal', 'state', 'local', 'laws', 'regulations', 'companys', 'policies', 'procedures', 'guidelines', 'assist', 'ag', 'turf', 'department', 'special', 'projects', 'research', 'compiling', 'data', 'creating', 'training', 'materials', 'analysis', 'generate', 'reports', 'regarding', 'sales', 'incentive', 'programs', 'learn', 'margin', 'reports', 'support', 'decision', 'making', 'learn', 'analyzing', 'marketing', 'proposals', 'programs', 'enable', 'sales', 'executive', 'management', 'evaluate', 'programs', 'effectiveness', 'perform', 'programs', 'provide', 'information', 'determining', 'best', 'cost', 'effective', 'programs', 'prior', 'implementation', 'exposure', 'roi', 'reports', 'advertising', 'direct', 'mail', 'promotional', 'campaigns', 'well', 'sponsorship', 'participation', 'merchandising', 'industry', 'trade', 'shows', 'lead', 'generation', 'exposure', 'crm', 'database', 'program', 'including', 'direct', 'mail', 'customer', 'newsletter', 'mailing', 'lists', 'learn', 'ongoing', 'crm', 'recommendations', 'promotional', 'programs', 'learn', 'effectiveness', 'communications', 'create', 'monthly', 'reporting', 'system', 'results', 'analyze', 'plan', 'execute', 'database', 'marketing', 'strategies', 'customer', 'campaigns', 'including', 'research', 'documentation', 'scope', 'analysis', 'business', 'case', 'creation', 'coordinate', 'customer', 'satisfaction', 'manager', 'development', 'management', 'customer', 'profiling', 'data', 'modeling', 'crm', 'programs', 'work', 'telemarketing', 'firms', 'call', 'centers', 'print', 'direct', 'mail', 'houses', 'apply', 'assimilate', 'data', 'including', 'response', 'analysis', 'ensuring', 'adherence', 'state', 'federal', 'regulations', 'partake', 'strategy', 'planning', 'implementation', 'develop', 'turf', 'equipment', 'dealerships', 'se', 'division', 'market', 'help', 'facilitate', 'turf', 'department', 'preparation', 'dealer', 'marketing', 'events', 'include', 'open', 'houses', 'events', 'take', 'active', 'role', 'preparing', 'attending', 'representing', 'kubota', 'industry', 'trade', 'shows', 'local', 'area', 'mentor', 'turf', 'sales', 'field', 'staff', 'accompanying', 'visits', 'dealer', 'principals', 'dealership', 'personnel', 'respective', 'territories', 'assist', 'department', 'streamlining', 'improving', 'development', 'training', 'activities', 'tools', 'interact', 'dealer', 'network', 'conducting', 'phone', 'calls', 'sales', 'service', 'parts', 'promotional', 'purposes', 'conduct', 'product', 'service', 'surveys', 'etc', 'assist', 'participate', 'division', 'events', 'provide', 'administrative', 'support', 'turf', 'department', 'complete', 'special', 'projects', 'needed', 'duties', 'assigned', 'minimum', 'qualifications', 'must', 'actively', 'enrolled', 'undergraduate', 'program', 'accredited', 'local', 'university', 'junior', 'senior', 'working', 'toward', 'bachelors', 'degree', 'business', 'general', 'agriculture', 'agribusiness', 'ag', 'communications', 'ag', 'mechanization', 'english', 'marketing', 'communications', 'advertising', 'degree', 'demonstrated', 'relevant', 'experience', 'perform', 'job', 'duties', 'skills', 'background', 'strong', 'capability', 'microsoft', 'office', 'suite', 'include', 'power', 'point', 'excel', 'word', 'access', 'skil ...
# 156 : ['want', 'jump', 'start', 'career', 'take', 'business', 'skills', 'next', 'level', 'joining', 'deloitte', 'team', 'chance', 'get', 'head', 'start', 'graduate', 'join', 'group', 'interns', 'get', 'inside', 'look', 'really', 'like', 'work', 'professional', 'services', 'organization', 'work', 'position', 'assigned', 'group', 'within', 'one', 'internal', 'services', 'group', 'gain', 'experience', 'working', 'meaningful', 'projects', 'opportunity', 'collaborate', 'consult', 'deloitte', 'professionals', 'use', 'exceptional', 'organizational', 'skills', 'meet', 'deadlines', 'work', 'diverse', 'groups', 'locally', 'nationally', 'based', 'professionals', 'responsibilities', 'role', 'could', 'include', 'following', 'manage', 'potential', 'list', 'invites', 'annual', 'corporate', 'finance', 'conference', 'including', 'broader', 'deloitte', 'network', 'private', 'equity', 'firms', 'sought', 'participants', 'refine', 'conference', 'invite', 'list', 'looking', 'key', 'information', 'database', 'track', 'referred', 'companies', 'deloitte', 'professionals', 'part', 'roll', 'onedeloitte', 'referral', 'program', 'partner', 'business', 'development', 'committee', 'commence', 'database', 'mining', 'project', 'designed', 'assign', 'classification', 'naic', 'codes', 'prospective', 'companies', 'grow', 'throughout', 'course', 'internship', 'program', 'receive', 'formal', 'informal', 'mentorship', 'training', 'access', 'learning', 'opportunities', 'help', 'foster', 'accelerate', 'development', 'new', 'skills', 'capabilities', 'beyond', 'formal', 'training', 'work', 'talented', 'professionals', 'chance', 'ask', 'questions', 'gain', 'valuable', 'experience', 'working', 'client', 'engagements', 'qualifications', 'required', 'open', 'students', 'interested', 'field', 'study', 'keen', 'interest', 'professional', 'services', 'professional', 'demeanor', 'strong', 'communication', 'skills', 'written', 'oral', 'demonstrated', 'leadership', 'qualities', 'leadership', 'potential', 'ability', 'work', 'independently', 'within', 'team', 'culture', 'ability', 'quickly', 'concisely', 'collect', 'report', 'data', 'preferred', 'cumulative', 'gpa', 'strongly', 'preferred', 'team', 'corporate', 'finance', 'team', 'assists', 'clients', 'financial', 'strategic', 'advisory', 'include', 'sellside', 'buyside', 'capital', 'raising', 'evaluation', 'corporate', 'finance', 'alternatives', 'including', 'employee', 'stock', 'ownership', 'plans', 'esops', 'interns', 'work', 'collaborative', 'environment', 'performance', 'feedback', 'encouraged', 'given', 'responsibilities', 'based', 'performance', 'capability', 'opportunities', 'positions', 'may', 'available', 'high', 'performers', 'learn', 'corporate', 'finance', 'practice', 'deloitte', 'culture', 'positive', 'supportive', 'culture', 'encourages', 'people', 'best', 'work', 'every', 'day', 'celebrate', 'individuals', 'recognizing', 'uniqueness', 'offering', 'flexibility', 'make', 'daily', 'choices', 'help', 'healthy', 'centered', 'confident', 'aware', 'offer', 'programs', 'continuously', 'looking', 'new', 'ways', 'maintain', 'culture', 'people', 'excel', 'lead', 'healthy', 'happy', 'lives', 'learn', 'life', 'deloitte', 'corporate', 'citizenship', 'deloitte', 'led', 'purpose', 'make', 'impact', 'matters', 'purpose', 'defines', 'extends', 'relationships', 'clients', 'people', 'communities', 'believe', 'business', 'power', 'inspire', 'transform', 'focus', 'education', 'giving', 'volunteerism', 'leadership', 'help', 'drive', 'positive', 'social', 'impact', 'communities', 'learn', 'deloitte', 'impact', 'world', 'recruiter', 'tips', 'want', 'job', 'seekers', 'exploring', 'opportunities', 'deloitte', 'feel', 'prepared', 'confident', 'help', 'interview', 'suggest', 'research', 'know', 'background', 'organization', 'business', 'area', 'applying', 'also', 'suggest', 'brush', 'interviewing', 'skills', 'practice', 'discussing', 'experience', 'job', 'history', 'family', 'member', 'friend', 'mentor', 'check', 'recruiting', 'tips', 'deloitt ...

# %% [markdown]
# ### Step 3: Extract Skills Using Named Entity Recognition (NER)
# #### 📌 Goal: Use spaCy’s built-in NER to detect and extract skills from job descriptions.
#
# 1. Load spaCy’s English model.
# 2. Use NER to identify important keywords.
# 3. Extract words related to technical skills, tools, and expertise.

# %%
import spacy

# Load spaCy's pre-trained NER model
nlp = spacy.load("en_core_web_sm")

job_des = {}  # Store processed job descriptions
job_desc_entities = {}  # Store extracted entities
size = df.shape[0]  # Get the number of rows in the dataframe

# Loop through job descriptions and extract named entities
for i in range(size):
    doc = nlp(df['Job Description'][i])  # Process the text with spaCy
    job_desc_entities[i] = [
        [ent.text, ent.label_]  # Store entity text and label
        for ent in doc.ents  # Extract named entities
        if ent.label_ in ['ORG', 'PERSON', 'PRODUCT']  # Filter relevant entities
    ]

# Print the extracted entities
for key, value in job_desc_entities.items():
    print(key, ":", value)
# Out:
# 0 : [['TX', 'ORG'], ['Graduate Interns', 'PERSON'], ['Big Data & Analytics Solutions', 'ORG'], ['SAP', 'ORG'], ['Oracle / MS SQL EDW / PL/SQL / BODS / SAS / Big Data / Visualization Tools', 'ORG'], ['College Recruiting Hiring Program', 'ORG'], ['Analytics & Big Data Solutions', 'ORG'], ['ETL', 'ORG'], ['Data Modeling', 'ORG'], ['Data Warehousing, Visualization, Reporting, Advanced Analytics', 'ORG'], ['SAP BI & Analytics - Visual BI', 'ORG'], ['GPA Scores', 'ORG'], ['BI & Analytics', 'ORG'], ['BI', 'ORG'], ['EDW', 'ORG'], ['Big Data', 'ORG'], ['Relevant Work BI', 'ORG'], ['Preferred -Visual BI', 'ORG'], ['SAP BW', 'ORG'], ['SAP BODS', 'ORG'], ['Big Data Frameworks (', 'ORG'], ['CSS/JavaScript/UI5/Fiori', 'ORG'], ['Visual BI Labs', 'ORG'], ['Internship', 'ORG'], ['Paid Internship  Opportunities', 'ORG'], ['BI & Analytics', 'ORG']]
# 1 : [['Digital Marketing', 'ORG'], ['EyeCare Services Partners', 'ORG'], ['Digital Marketing', 'ORG'], ['Functions Own', 'PERSON'], ['Leverage', 'ORG'], ['Oversee', 'ORG'], ['Introduce Patient Communication Software', 'ORG'], ['Manage', 'ORG'], ['Create Marketing Collateral', 'ORG'], ['Lasik', 'PERSON'], ['Kamra', 'ORG'], ['Flex Spending', 'PERSON']]
# 2 : [['MIS', 'ORG'], ['the Pricing & Strategy', 'ORG'], ['Profitability Teams within Decision Sciences', 'ORG'], ['Pricing MIS', 'PERSON'], ['Pricing & Strategy', 'ORG'], ['Decision Sciences', 'ORG'], ['Decision Sciences', 'ORG'], ['Information Technology', 'ORG'], ['Data Visualization', 'ORG'], ['SharePoint', 'ORG'], ['MIS', 'ORG'], ['MIS', 'ORG'], ['SQL', 'ORG'], ['SAS', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['DashboardsExperience', 'ORG'], ['Extraction, Transformation and Loading', 'ORG'], ['Data Management', 'ORG'], ['Credit Policy', 'ORG']]
# 3 : [['the Federal Reserve Bank', 'ORG'], ['Fed', 'ORG'], ['Treasury', 'ORG'], ['the Federal Reserve Bank', 'ORG'], ['Dallas Treasury Services Department', 'ORG'], ['Examine', 'ORG'], ['Analyze', 'PRODUCT'], ['Ability', 'ORG'], ['MS SharePoint', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Bachelor', 'ORG'], ['Business Administration', 'ORG'], ['CONDITIONS', 'ORG']]
# 4 : [['‚', 'PERSON'], ['Corporate Headquarters', 'ORG'], ['TX', 'ORG'], ['Aviall', 'PERSON'], ['Education', 'ORG']]
# 5 : [['the Federal Reserve Bank', 'ORG'], ['Fed', 'ORG'], ['the HR Department', 'ORG'], ['Human Resources', 'ORG'], ['Compensation, Payroll', 'ORG'], ['HRIS', 'ORG'], ['KPI', 'ORG'], ['HRIS', 'ORG'], ['MS Excel', 'ORG'], ['V-Lookup', 'ORG'], ['Concatenating', 'PERSON'], ['Conditional', 'ORG'], ['Pivot Tables', 'PERSON'], ['CONDITIONS', 'ORG']]
# 6 : [['Atos', 'PERSON'], ['Atos offers Consulting & Systems Integration, Managed Services & BPO', 'ORG'], ['Cloud, Big Data & Cyber', 'ORG'], ['Atos', 'PERSON'], ['Defense, Financial Services', 'ORG'], ['Health, Manufacturing', 'ORG'], ['Media', 'ORG'], ['Utilities', 'ORG'], ['Transportation', 'ORG'], ['Atos', 'PERSON'], ['the Worldwide Information Technology Partner', 'ORG'], ['the Olympic & Paralympic Games', 'ORG'], ['Atos, Bull, Canopy,', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['needs.- Translate', 'ORG'], ['reports.- Closely', 'ORG'], ['Microsoft Office', 'ORG'], ['Excel', 'PRODUCT'], ['Microsoft Access', 'ORG'], ['SQL', 'ORG'], ['Business Objects', 'ORG'], ['College or Technical Institute', 'ORG'], ['Internships', 'PERSON'], ['max', 'PERSON']]
# 7 : [['USA  Apply', 'ORG'], ['Atos offers Consulting & Systems Integration, Managed Services & BPO', 'ORG'], ['Cloud, Big Data & Cyber', 'ORG'], ['Atos', 'PERSON'], ['Defense, Financial Services', 'ORG'], ['Health, Manufacturing', 'ORG'], ['Media', 'ORG'], ['Utilities', 'ORG'], ['Transportation', 'ORG'], ['Atos', 'PERSON'], ['the Worldwide Information Technology Partner', 'ORG'], ['the Olympic & Paralympic Games', 'ORG'], ['Atos, Bull, Canopy,', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['needs.- Translate', 'ORG'], ['reports.- Closely', 'ORG'], ['Microsoft Office', 'ORG'], ['Excel', 'PRODUCT'], ['Microsoft Access', 'ORG'], ['SQL', 'ORG'], ['Business Objects', 'ORG'], ['College or Technical Institute', 'ORG'], ['Internships', 'PERSON'], ['max', 'PERSON']]
# 8 : [['Digital Marketing Intern', 'ORG'], ['Digital Marketing', 'ORG'], ['keyword research', 'ORG'], ['SEO & PPC', 'ORG'], ['Digital Marketing', 'ORG'], ['SEO', 'ORG'], ['PPC', 'ORG'], ['Social Media', 'ORG'], ['PPC', 'ORG'], ['HTML', 'ORG'], ['CSS', 'ORG'], ['Java Script', 'PERSON'], ['CMS', 'ORG'], ['CRM', 'PRODUCT'], ['Keyword', 'PERSON'], ['Digital', 'ORG']]
# 9 : [['Data', 'ORG'], ['Excel', 'PRODUCT'], ['Mortgage Call Report', 'ORG'], ['State', 'ORG'], ['Excel', 'PRODUCT'], ['MS SQLBachelor’s Degree', 'ORG'], ['IBM Cognos', 'ORG'], ['Microsoft Access', 'ORG']]
# 10 : [['Business Technology', 'ORG'], ['Summer Scholar Program', 'ORG'], ['Business Technology', 'ORG'], ['Summer Scholar', 'PERSON'], ['our Technology Service Offerings', 'ORG'], ['BTA', 'ORG'], ['BTA', 'ORG'], ['Business Technology', 'ORG'], ['Summer Scholars', 'PERSON'], ['Technology Design & Development', 'ORG'], ['Computer Science, Software Engineering', 'ORG'], ['MIS', 'ORG'], ['Basis/ABAP', 'ORG'], ['QA tester.• Data and Analytics', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Technology Consulting', 'ORG'], ['Computer Information Systems', 'ORG'], ['Management Information Systems', 'ORG'], ['IT Network Administration/Security', 'ORG'], ['Data Analytics', 'ORG'], ['Matho Business: Accounting, Analytics, Business, Economics, Finance, Marketing, Operations, Statistics', 'ORG'], ['Computer Engineering', 'ORG'], ['Electrical Engineering', 'ORG'], ['Engineering Management', 'ORG'], ['Industrial Engineering', 'ORG'], ['Software Engineering', 'ORG'], ['GPA', 'ORG'], ['Business Technology', 'ORG'], ['Summer Scholar', 'PERSON'], ['Deloitte University', 'ORG'], ['The Leadership Center', 'ORG'], ['BenefitsAt Deloitte', 'PERSON'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Recruiter', 'PERSON'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte Consulting LLP', 'ORG'], ['Deloitte LLP', 'ORG'], ['Deloitte LLP', 'ORG'], ['Deloitte', 'ORG'], ['the San Francisco Fair Chance Ordinance', 'ORG']]
# 11 : [['The Data Scientist Intern', 'ORG'], ['the Data & Analytics', 'ORG'], ['Information Technology', 'ORG'], ['Computer Engineering', 'ORG'], ['Computer Science', 'PERSON'], ['Data Science', 'ORG']]
# 12 : [['Post Date 4/13/2017', 'ORG'], ['State', 'ORG'], ['TX  Job Group Marketing  Description Marketing Internships-', 'ORG'], ['Dex Media', 'PERSON'], ['Marketing Interns', 'PERSON'], ['Dex Media’s', 'PERSON'], ['TX', 'ORG'], ['• Corporate Communications o Corporate/Employee Communications', 'ORG'], ['• Marketing Communications', 'ORG'], ['Email Development - HTML', 'PERSON'], ['Graphic Design (', 'ORG'], ['Photoshop', 'PRODUCT'], ['• Customer Relationship Management', 'ORG'], ['AB Testing', 'ORG'], ['• Digital Marketing', 'ORG'], ['Content Writer', 'ORG'], ['• Marketing', 'ORG'], ['Summarize', 'ORG'], ['• Junior', 'ORG'], ['Graduate', 'PERSON'], ['TX', 'ORG'], ['Digital Marketing, Marketing Analytics', 'ORG'], ['MS Access', 'ORG'], ['Oracle', 'PERSON'], ['SQL Server', 'ORG'], ['SQL', 'ORG'], ['• Must', 'ORG'], ['Social Media', 'ORG'], ['Microsoft Office Suite', 'ORG'], ['Knowledge', 'PERSON'], ['Adobe Suite', 'PERSON'], ['• Video', 'ORG'], ['• Excellent', 'ORG'], ['• Must', 'ORG'], ['Dex Media', 'PERSON']]
# 13 : [['BRINKS – COPPELL', 'ORG'], ['Responsibilities:• Interns', 'PERSON'], ['Data Entry and System Files • Compose', 'ORG'], ['facilities• Prepare', 'ORG'], ['assignedQualifications:• Candidate', 'ORG'], ['Business Marketing• Student', 'ORG'], ['GPA', 'ORG'], ['better• Prior', 'ORG'], ['Builds', 'PERSON'], ['Microsoft Outlook', 'ORG'], ['Excel', 'PRODUCT'], ['Brink’s Proud', 'PERSON']]
# 14 : [['‚', 'PERSON'], ['Corporate Headquarters', 'ORG'], ['TX', 'ORG'], ['The Business Strategy Intern', 'ORG'], ['Microsoft Office', 'ORG'], ['Bachelor', 'ORG'], ['Business, Marketing, Finance', 'ORG'], ['Information Systems', 'ORG'], ['GPA', 'ORG']]
# 15 : [['the Grant Thornton Job', 'ORG'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton LLP', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton International Ltd', 'ORG'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['RAS', 'ORG'], ['Grant Thornton LLP', 'PERSON'], ['Grant Thornton Risk Advisory', 'PERSON'], ['Respond', 'PERSON'], ['RAS Intern', 'ORG'], ['RAS Interns', 'ORG'], ['RAS Intern', 'ORG'], ['RAS', 'ORG'], ['RAS', 'ORG'], ['RAS Intern', 'ORG'], ['RAS Intern', 'ORG'], ['RAS', 'ORG'], ['RAS', 'ORG'], ['Intern', 'ORG'], ['RAS', 'ORG'], ['Grant Thornton’s', 'PERSON'], ['Agility', 'ORG'], ['Respect and Responsibility', 'ORG'], ['Business, Computer Science, Engineering', 'ORG'], ['Business Administration, Economics,', 'ORG'], ['Operations', 'ORG'], ['International Business, Management Information Systems Computer and Information Systems', 'ORG'], ['GPA', 'ORG'], ['Skill Requirements Strong', 'PERSON'], ['CIA', 'ORG'], ['CFE', 'ORG'], ['PMP', 'ORG'], ['RAS Interns', 'ORG'], ['RAS', 'ORG'], ['Interns', 'ORG'], ['RAS', 'ORG'], ['Grant Thornton', 'PERSON'], ['Grant Thornton LLP', 'PERSON'], ['Grant Thornton LLP', 'PERSON'], ['Grant Thornton’s', 'PERSON']]
# 16 : [['Information Technology Services', 'ORG'], ['DBA Associate', 'ORG'], ['SQL', 'ORG'], ['SSRS', 'ORG'], ['Clients:• Design', 'ORG'], ['modules• Assess', 'ORG'], ['Demonstrating Business Operations Capability:• Create', 'ORG'], ['Calendar', 'PERSON'], ['iTracker', 'ORG'], ['Mobility Management• Create ETL', 'ORG'], ['Informatica', 'ORG'], ['POC', 'ORG'], ['Information Technology Services', 'ORG'], ['Deloitte Applications Studios', 'ORG'], ['DAS', 'ORG'], ['T&I', 'ORG'], ['CyberSecurity', 'ORG'], ['Technology Management Operations', 'ORG'], ['• Proficient', 'ORG'], ['Microsoft Office• Manage', 'ORG'], ['deliverables• Assigned', 'PERSON'], ['Seeks', 'PERSON'], ['SQL Server•', 'ORG'], ['Management Systems• Configuration Management', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Recruiter', 'PERSON'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte Services LP', 'ORG'], ['Deloitte LLP', 'ORG'], ['Deloitte LLP', 'ORG'], ['S17PSCSI18JUNTB-GS', 'ORG']]
# 17 : [['MedeAnalytics', 'ORG'], ['Money Ball', 'PERSON'], ['Software', 'ORG'], ['Modern Healthcare’s', 'ORG'], ['Healthcare', 'ORG'], ['Data Quality', 'ORG'], ['Business Analysts', 'ORG'], ['Create and Execute', 'ORG'], ['Quality Assurance/Testing Proficient', 'ORG'], ['Excel', 'PRODUCT'], ['Strong Communication', 'ORG'], ['Pursuing Associates/Bachelors/Masters Degree', 'ORG'], ['MIS', 'ORG'], ['Healthcare Degree', 'ORG'], ['Project Tracking Software Knowledge', 'ORG'], ['SQL', 'ORG'], ['Special Requirements  Based', 'ORG'], ['TX     Working Environment', 'ORG']]
# 18 : [['Intern, Research & Development Tracking Code 7366-415 Job Description', 'ORG'], ['the American Heart Association', 'ORG'], ['American Stroke Association', 'ORG'], ['The American Heart Association', 'ORG'], ['The American Heart Association', 'ORG'], ['AHA', 'ORG'], ['Research and Development', 'ORG'], ['National Center', 'ORG'], ['TX', 'ORG'], ['the Quality and Health IT Research and Development', 'ORG'], ['BA/BS', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['AHA', 'ORG'], ['the American Heart Association', 'ORG'], ['Twitter', 'PERSON'], ['the American Heart Association', 'ORG'], ['United States Position Type Temporary Job Category: Health Quality EOE Minorities/Females/Protected Veterans/Disabled  ', 'ORG']]
# 19 : [['Strategy & Operations', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Our Strategy & Operations', 'ORG'], ['Product Development', 'ORG'], ['Supply Chain Strategy and Planning', 'ORG'], ['Lean Operations', 'ORG'], ['GPA', 'ORG'], ['Supply Chain Strategy/Planning,', 'ORG'], ['Sourcing & Procurement, Product Development, Logistics & Distribution', 'ORG'], ['Lean OperationsExperience', 'ORG'], ['MS Excel', 'ORG'], ['MS Access Willingness', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Recruiter', 'PERSON'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte Consulting LLP', 'ORG'], ['Deloitte LLP', 'ORG'], ['Deloitte LLP', 'ORG'], ['Deloitte', 'ORG'], ['the San Francisco Fair Chance Ordinance', 'ORG']]
# 20 : [['Oracle', 'PERSON'], ['BA', 'ORG'], ['Oracle', 'PERSON'], ['Oracle', 'ORG'], ['Cloud', 'PERSON'], ['Oracle’s North America Marketing', 'ORG'], ['The Campaigns Strategist', 'ORG'], ['the Human Capital Management', 'ORG'], ['Oracle', 'ORG'], ['Product Marketing', 'ORG'], ['Digital Marketing, Marketing Operations', 'ORG'], ['Partner Marketing', 'ORG'], ['Strategist', 'ORG'], ['Ongoing Campaign Management and Execution', 'ORG'], ['Lead Management and Reporting', 'ORG'], ['Sirius Decision', 'ORG'], ['TX', 'ORG'], ['Austin', 'PERSON'], ['TX', 'ORG']]
# 21 : [['Turbomachinery', 'ORG'], ['GE', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Turbomachinery', 'ORG']]
# 22 : [['Protiviti', 'ORG'], ['Protiviti', 'ORG'], ['Internal Audit and Financial Advisory', 'ORG'], ['Technology Consulting and Risk and Compliance', 'ORG'], ['Accounting, Finance, Economics', 'ORG'], ['MIS', 'ORG'], ['Computer Science', 'ORG'], ['GPA', 'ORG'], ['US & Canada Postings', 'ORG']]
# 23 : [['EMR', 'PERSON'], ['Digital Marketing', 'ORG'], ['EyeCare Services Partners', 'ORG'], ['Digital Marketing', 'ORG'], ['Patient Communication Software', 'ORG'], ['Marketing Collateral', 'ORG'], ['Lasik', 'PERSON'], ['Kamra', 'ORG'], ['Flex Spending', 'PERSON'], ['Twitter', 'PERSON'], ['Google Adwords', 'ORG'], ['brands)Provide', 'ORG'], ['media)Community involvementMedia', 'ORG'], ['digital)Develop', 'ORG'], ['NewsletterManage', 'ORG'], ['& Confirmations', 'ORG']]
# 24 : [['EMR', 'PERSON'], ['Digital Marketing', 'ORG'], ['EyeCare Services Partners', 'ORG'], ['Digital Marketing', 'ORG'], ['Patient Communication Software', 'ORG'], ['Marketing Collateral', 'ORG'], ['Lasik', 'PERSON'], ['Kamra', 'ORG'], ['Flex Spending', 'PERSON'], ['Twitter', 'PERSON'], ['Google Adwords', 'ORG'], ['brands)Provide', 'ORG'], ['media)Community involvementMedia', 'ORG'], ['digital)Develop', 'ORG'], ['NewsletterManage', 'ORG'], ['& Confirmations', 'ORG']]
# 25 : [['DESCRIPTION', 'PERSON'], ['University Recruiting and Relations', 'ORG'], ['Execute University', 'ORG'], ['the University Recruiting', 'ORG'], ['University Recruiting and Relations', 'ORG'], ['Supports', 'PERSON'], ['University Recruiting', 'ORG'], ['SharePoint', 'ORG'], ['Talent Acquisition', 'ORG'], ['SharePoint', 'ORG'], ['HireVue', 'PERSON'], ['SAP', 'ORG'], ['Twitter', 'PERSON']]
# 26 : [['AlixPartners', 'ORG'], ['the Lead Management Intern', 'ORG'], ['Lead Management', 'ORG'], ['The Lead Management Intern', 'ORG'], ['Lead Management', 'ORG'], ['Lead Management', 'ORG'], ['Pipeline', 'ORG'], ['TRS', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Bloomberg', 'ORG'], ['Capital IQ', 'ORG'], ['AlixPartners', 'ORG'], ['AlixPartners', 'ORG'], ['Bronze', 'PERSON'], ['Veteran Friendly Employer', 'ORG']]
# 27 : [['IBM', 'ORG']]
# 28 : [['Atos', 'PERSON'], ['Atos offers Consulting & Systems Integration, Managed Services & BPO', 'ORG'], ['Cloud, Big Data & Cyber', 'ORG'], ['Atos', 'PERSON'], ['Defense, Financial Services', 'ORG'], ['Health, Manufacturing', 'ORG'], ['Media', 'ORG'], ['Utilities', 'ORG'], ['Transportation', 'ORG'], ['Atos', 'PERSON'], ['the Worldwide Information Technology Partner', 'ORG'], ['the Olympic & Paralympic Games', 'ORG'], ['Atos, Bull, Canopy,', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Data Engineer Intern – Automatic Report', 'ORG'], ['Computer ScienceExperience', 'ORG'], ['Big Data', 'ORG'], ['Data Management', 'ORG'], ['Metadata Management, Data Integration Technologies – Hadoop', 'ORG'], ['ElasticSearch', 'ORG'], ['Jaspersoft', 'PERSON'], ['Java', 'PERSON']]
# 29 : [['USA  Apply', 'ORG'], ['Atos offers Consulting & Systems Integration, Managed Services & BPO', 'ORG'], ['Cloud, Big Data & Cyber', 'ORG'], ['Atos', 'PERSON'], ['Defense, Financial Services', 'ORG'], ['Health, Manufacturing', 'ORG'], ['Media', 'ORG'], ['Utilities', 'ORG'], ['Transportation', 'ORG'], ['Atos', 'PERSON'], ['the Worldwide Information Technology Partner', 'ORG'], ['the Olympic & Paralympic Games', 'ORG'], ['Atos, Bull, Canopy,', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Graduate Program', 'ORG'], ['Senior Leadership Community', 'ORG'], ['Mainframe Disk', 'PERSON'], ['Mainframe', 'PERSON'], ['Mainframe', 'PERSON'], ['Microsoft Office', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Project', 'ORG'], ['ITIL', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON']]
# 30 : [['USA  Apply', 'ORG'], ['Atos offers Consulting & Systems Integration, Managed Services & BPO', 'ORG'], ['Cloud, Big Data & Cyber', 'ORG'], ['Atos', 'PERSON'], ['Defense, Financial Services', 'ORG'], ['Health, Manufacturing', 'ORG'], ['Media', 'ORG'], ['Utilities', 'ORG'], ['Transportation', 'ORG'], ['Atos', 'PERSON'], ['the Worldwide Information Technology Partner', 'ORG'], ['the Olympic & Paralympic Games', 'ORG'], ['Atos, Bull, Canopy,', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Graduate Program', 'ORG'], ['Senior Leadership Community', 'ORG'], ['Mainframe Disk', 'PERSON'], ['Mainframe', 'PERSON'], ['Mainframe', 'PERSON'], ['Microsoft Office', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Project', 'ORG'], ['ITIL', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON']]
# 31 : [['Atos', 'PERSON'], ['Atos offers Consulting & Systems Integration, Managed Services & BPO', 'ORG'], ['Cloud, Big Data & Cyber', 'ORG'], ['Atos', 'PERSON'], ['Defense, Financial Services', 'ORG'], ['Health, Manufacturing', 'ORG'], ['Media', 'ORG'], ['Utilities', 'ORG'], ['Transportation', 'ORG'], ['Atos', 'PERSON'], ['the Worldwide Information Technology Partner', 'ORG'], ['the Olympic & Paralympic Games', 'ORG'], ['Atos, Bull, Canopy,', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Predictive Maintenance of Equipment for Asset-intensive Industries', 'ORG'], ['Data Mining Methods', 'ORG'], ['Big Data Analytics', 'ORG'], ['Cloud Computing', 'PERSON'], ['Quality & Reliability Engineering Some Experience', 'ORG']]
# 32 : [['Spread Monthly Profit', 'ORG'], ['Company Financials', 'ORG'], ['SOX', 'ORG'], ['Nationstar Senior and Executive Management         ', 'ORG']]
# 33 : [['CONSULTING INTERNPosition DescriptionInterns', 'ORG'], ['Consulting Interns', 'ORG'], ['Finance', 'ORG'], ['Math, Business Administration', 'ORG'], ['Computer Science, Information Systems', 'ORG'], ['GPA', 'ORG'], ['RSM', 'PERSON'], ['RSM US', 'PERSON'], ['RSM', 'PERSON'], ['Location Street Address', 'ORG'], ['Noel Road', 'PERSON'], ['YesSponsor', 'ORG']]
# 34 : [['Invesco Ltd.', 'ORG'], ['Invesco', 'ORG'], ['the New York Stock Exchange', 'ORG'], ['IVZ', 'ORG'], ['Job Purpose', 'PERSON'], ['Invesco Real Estate', 'ORG'], ['IRE', 'ORG'], ['IRE', 'ORG'], ['IRE’s Application Support Team', 'ORG'], ['Application Support Team', 'ORG'], ['Intern', 'ORG'], ['the Applications Support Team Intern', 'ORG'], ['The Applications Support Team', 'ORG'], ['Key Responsibilities / Duties', 'ORG'], ['IRE', 'ORG'], ['Develop', 'ORG'], ['the Applications Support Team Intern', 'ORG'], ['Project & Global Lease Abstract Automation Project  Work Experience / Knowledge', 'ORG'], ['Microsoft Office', 'ORG'], ['Knowledge', 'PERSON'], ['Microsoft Visio', 'ORG'], ['Skills / Other Personal Attributes Required', 'ORG'], ['Anticipates', 'PRODUCT'], ['Seeks', 'PERSON'], ['Listens', 'PERSON'], ['Formal Education', 'ORG'], ['Computer Science, Information Systems', 'ORG'], ['FLSA', 'ORG'], ['Invesco', 'PERSON']]
# 35 : [['Business Risk', 'ORG'], ['Deloitte', 'ORG'], ['Advisory', 'ORG'], ['Interns', 'ORG'], ['an Advisory Internship Conference', 'ORG'], ['Deloitte University', 'ORG'], ['Deloitte University', 'ORG'], ['The Leadership Center', 'ORG'], ['Business Administration, Accounting, Finance, Economics', 'ORG'], ['Computer Science or Information Systems', 'ORG'], ['GPA', 'ORG'], ['Microsoft Excel', 'ORG'], ['Business Risk', 'ORG'], ['Advisory', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['CultureOur', 'ORG'], ['Deloitte', 'ORG'], ['CitizenshipDeloitte', 'ORG'], ['Deloitte', 'ORG'], ['Recruiter', 'PERSON'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte Advisory', 'ORG'], ['Deloitte & Touche LLP', 'ORG'], ['Deloitte Financial Advisory Services LLP', 'ORG'], ['Deloitte Transactions and', 'ORG'], ['Deloitte Transactions and', 'ORG'], ['Deloitte LLP', 'ORG'], ['Deloitte LLP', 'ORG'], ['S17UTXEI19JUNKW-BR', 'ORG']]
# 36 : [['CRI InternStudent', 'ORG'], ['Microsoft Office', 'ORG'], ['Word, Access, Excel', 'ORG'], ['informationADDITIONAL', 'ORG']]
# 37 : [['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton LLP', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton International Ltd', 'ORG'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ["Grant Thornton's", 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Partners', 'ORG'], ['Grant Thornton', 'PERSON'], ['Meeting', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Giving', 'PERSON'], ['IRS', 'ORG'], ['GPA', 'ORG'], ['Skill Requirements', 'PERSON'], ['Grant Thornton LLP', 'PERSON'], ['Grant Thornton’s', 'PERSON']]
# 38 : [['a Business Intelligence/SQL Developer', 'ORG'], ['Computer Science', 'ORG'], ['Business Admin', 'ORG'], ['BI/SQL', 'ORG'], ['SQL Server', 'ORG'], ['SQL', 'ORG'], ['Ideal Candidate', 'ORG'], ['Microsoft SQL Server', 'ORG'], ['Microsoft Power BI', 'ORG'], ['Candidate’s Aspiration', 'ORG'], ['Project Management, Leadership and Management Skill', 'ORG'], ['Disciplined', 'ORG'], ['Aspirational', 'ORG'], ['Task Master', 'PRODUCT'], ['Microsoft', 'ORG'], ['Microsoft Power BI', 'ORG'], ['Microsoft SharePoint Online', 'ORG'], ['Microsoft InfoPath', 'ORG'], ['Microsoft Office', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'PERSON'], ['Templates', 'PERSON'], ['OneNote', 'ORG'], ['Microsoft Skype for Business', 'ORG']]
# 39 : [['Description  Financial Planning & Analysis InternJ.C. Penney Company,', 'ORG'], ['JCPenney', 'PRODUCT'], ['Finance', 'ORG'], ['the JCPenney Financial Planning & Analysis', 'ORG'], ['Home Office', 'ORG'], ['TX', 'ORG'], ['Collect', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Core Competencies & Accomplishments: • Current', 'ORG'], ['Advanced', 'ORG'], ['notice• Strong', 'ORG'], ['Advanced Microsoft Excel', 'ORG'], ['PowerPoint', 'ORG'], ['Microsoft Access', 'ORG'], ['Ability', 'ORG'], ['Start Date', 'PERSON'], ['JCPenney', 'PRODUCT'], ['JCPenney', 'ORG'], ['Home Office', 'ORG'], ['Walgreens', 'PERSON'], ['Starbucks', 'ORG']]
# 40 : [['SAP Academy for Presales - Dallas Job Apply', 'ORG'], ['LinkedIn     Start', 'ORG'], ['Facebook     Start', 'ORG'], ['Xing      Apply', 'PRODUCT'], ['TX', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['Objectives', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['SAP Academy for Presales', 'ORG'], ['SAP Presales', 'ORG'], ['Presales Specialist', 'ORG'], ['the SAP Account Executive', 'ORG'], ['AE', 'ORG'], ['SAP', 'ORG'], ['Knows', 'PRODUCT'], ['the SAP Academy for Presales', 'ORG'], ['The SAP Presales Academy', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['Role Plays', 'PERSON'], ['Case Studies', 'ORG'], ['Classroom Learning', 'ORG'], ['Academy', 'ORG'], ['Design Thinking,', 'ORG'], ['Financial Case', 'ORG'], ['Interpersonal Skills and', 'ORG'], ['Social Selling', 'ORG'], ['SAP Supporting', 'ORG'], ['Qualifications/Skills', 'ORG'], ['The SAP Academy for Presales', 'ORG'], ['Accounting, Finance, Information Systems', 'ORG'], ['Project Management', 'ORG'], ['Supply Chain Management, Travel and', 'ORG'], ['Logistics, Database Technology', 'ORG'], ['Technically', 'PERSON'], ['post academy', 'ORG'], ['the Lines of Business’s', 'ORG'], ['HR Practitioners', 'ORG'], ['Consumer Products, Oil & Gas', 'ORG'], ['Professional Services', 'ORG'], ['Consumer Products, Professional Services', 'ORG'], ['The Academy Program', 'ORG'], ['SAPACADEMYforPresales', 'PERSON'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['Recruiting Operations Team (Americas', 'ORG'], ['APJ', 'ORG'], ['EMEA', 'ORG'], ['EOE AA M/F/Vet/Disability', 'ORG'], ['Dallas Nearest Secondary Market', 'ORG'], ['SAP', 'ORG'], ['Intern', 'ORG'], ['ERP', 'ORG'], ['Outside Sales, Finance, Technology, Entry Level', 'ORG'], ['LinkedIn     Start', 'ORG'], ['Facebook     Start', 'ORG'], ['Xing      Apply', 'PRODUCT']]
# 41 : [['MIS', 'ORG'], ['the Pricing & Strategy', 'ORG'], ['Profitability Teams within Decision Sciences', 'ORG'], ['Pricing MIS', 'PERSON'], ['Pricing & Strategy', 'ORG'], ['Decision Sciences', 'ORG'], ['Decision Sciences', 'ORG'], ['Information Technology', 'ORG'], ['Data Visualization', 'ORG'], ['SharePoint', 'ORG'], ['Identify', 'PERSON'], ['Complete', 'PERSON'], ['MIS', 'ORG'], ['MIS', 'ORG'], ['SQL', 'ORG'], ['SAS', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Extraction, Transformation and Loading', 'ORG'], ['Data Management', 'ORG'], ['Credit Policy', 'ORG'], ['Ability', 'ORG'], ['Superior', 'PRODUCT'], ['Working Conditions', 'ORG'], ['Employer’s Rights', 'ORG']]
# 42 : [['The CoreLogic Summer Internship Program', 'ORG'], ['CoreLogic', 'ORG'], ['CoreLogic', 'ORG'], ['Spatial', 'ORG'], ['Follows department', 'ORG'], ['Participates in Internship Program', 'ORG'], ['Knowledge', 'PERSON'], ['Business, Economics', 'ORG'], ['Demonstrated', 'PRODUCT'], ['Skills  Ability', 'ORG'], ['Solid', 'ORG'], ['Proficiency', 'ORG'], ['Microsoft Office', 'ORG'], ['Word, Excel,', 'ORG'], ['PowerPoint', 'ORG'], ['CoreLogic', 'ORG'], ['CoreLogic', 'ORG']]
# 43 : [['the Federal Reserve Bank', 'ORG'], ['Fed', 'ORG'], ['Treasury', 'ORG'], ['the Federal Reserve Bank', 'ORG'], ['Dallas Treasury Services Department', 'ORG'], ['MS SharePoint', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Bachelor', 'ORG'], ['Business Administration', 'ORG'], ['CONDITIONS', 'ORG']]
# 44 : [['The CoreLogic Summer Internship Program', 'ORG'], ['CoreLogic', 'ORG'], ['CoreLogic', 'ORG'], ['the Pricing Operations', 'ORG'], ['Pricing and', 'ORG'], ['Internship Program', 'ORG'], ['KnowledgeCurrently', 'PERSON'], ['Microsoft Office', 'ORG'], ['Word, Excel,', 'ORG'], ['CoreLogic', 'ORG']]
# 45 : [['The Data Scientist Intern', 'ORG'], ['Information Technology', 'ORG'], ['Computer Engineering', 'ORG'], ['Computer Science, Engineering Technology', 'ORG'], ['MIS', 'ORG'], ['HMS', 'ORG'], ['State', 'ORG'], ['HMS', 'ORG'], ['Application', 'PRODUCT'], ['ETL', 'ORG'], ['MDM', 'ORG'], ['Pattern Recognition', 'ORG'], ['Identity Matching', 'ORG'], ['Machine Learning', 'PERSON'], ['Big Data', 'ORG'], ['Languages', 'PERSON'], ['Java', 'PERSON'], ['SQL', 'ORG']]
# 46 : [['IBM', 'ORG'], ['Technical Solution Specialist Internship', 'ORG'], ['IBM', 'ORG'], ['IBM', 'ORG'], ['Computer Engineering', 'ORG'], ['Computer Science, Data Science, Electrical Engineering', 'ORG'], ['Information Technology', 'ORG'], ['IBM', 'ORG'], ['IBM', 'ORG'], ['IBM Technical Solution', 'ORG'], ['IBM', 'ORG'], ['IBM', 'ORG'], ['IBM', 'ORG'], ['IBM', 'ORG'], ['Cloud, Commerce', 'ORG'], ['Summit', 'ORG']]
# 47 : [['USA  Apply', 'ORG'], ['Atos offers Consulting & Systems Integration, Managed Services & BPO', 'ORG'], ['Cloud, Big Data & Cyber', 'ORG'], ['Atos', 'PERSON'], ['Defense, Financial Services', 'ORG'], ['Health, Manufacturing', 'ORG'], ['Media', 'ORG'], ['Utilities', 'ORG'], ['Transportation', 'ORG'], ['Atos', 'PERSON'], ['the Worldwide Information Technology Partner', 'ORG'], ['the Olympic & Paralympic Games', 'ORG'], ['Atos, Bull, Canopy,', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Computer ScienceExperience', 'ORG'], ['Big Data', 'ORG'], ['Data Management', 'ORG'], ['Metadata Management, Data Integration Technologies – Hadoop', 'ORG'], ['ElasticSearch', 'ORG'], ['Jaspersoft', 'PERSON'], ['Java', 'PERSON']]
# 48 : [['Intern/Co-Op Work Location', 'ORG'], ['TX Posted Date', 'ORG'], ['Unlock Your Career Potential', 'ORG'], ['CORE', 'ORG'], ['Insightful Expertise,', 'ORG'], ['Everything, Service Excellence, Inspiring Innovation', 'ORG'], ['GPA', 'ORG'], ['Knowledge', 'PERSON'], ['Microsoft Office', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Project', 'ORG'], ['Information Technology', 'ORG'], ['Management Information Systems', 'ORG'], ['Business Management Knowledge', 'ORG'], ['Opportunity, University', 'ORG'], ['Software', 'ORG'], ['FORTUNE® Magazine', 'ORG'], ['Forbes®', 'ORG']]
# 49 : [['Microsoft Office', 'ORG'], ['Outlook and Excel', 'ORG'], ['ExactTarget', 'ORG'], ['SurveyMonkey', 'ORG'], ['Google Analytics', 'ORG'], ['HTML', 'ORG'], ['SQL', 'ORG'], ['Quantitative Marketing Research of', 'ORG'], ['•Provide', 'ORG'], ['The 5 Dysfunctions of a Team', 'ORG'], ['Multi-Channel Experience', 'ORG'], ['DRTV', 'ORG']]
# 50 : [['The CoreLogic Summer Internship Program', 'ORG'], ['CoreLogic', 'ORG'], ['CoreLogic', 'ORG'], ['Internship Program', 'ORG'], ['KnowledgeCurrently', 'PERSON'], ['Microsoft Office', 'ORG'], ['Word, Excel,', 'ORG'], ['CoreLogic', 'ORG']]
# 51 : [['USA  Apply', 'ORG'], ['Atos offers Consulting & Systems Integration, Managed Services & BPO', 'ORG'], ['Cloud, Big Data & Cyber', 'ORG'], ['Atos', 'PERSON'], ['Defense, Financial Services', 'ORG'], ['Health, Manufacturing', 'ORG'], ['Media', 'ORG'], ['Utilities', 'ORG'], ['Transportation', 'ORG'], ['Atos', 'PERSON'], ['the Worldwide Information Technology Partner', 'ORG'], ['the Olympic & Paralympic Games', 'ORG'], ['Atos, Bull, Canopy,', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Predictive Maintenance of Equipment for Asset-intensive Industries', 'ORG'], ['Data Mining Methods', 'ORG'], ['Big Data Analytics', 'ORG'], ['Cloud Computing', 'PERSON'], ['Quality & Reliability Engineering Some Experience', 'ORG']]
# 52 : [['‚', 'PERSON'], ['Corporate Headquarters', 'ORG'], ['TX', 'ORG'], ['The Accounting/Finance Intern', 'ORG'], ['inter-CoSA', 'ORG'], ['Microsoft Office', 'ORG'], ['Bachelor', 'ORG'], ['Mathematics, Risk Management, Statistics', 'ORG'], ['Data/Analytics', 'ORG'], ['GPA', 'ORG']]
# 53 : [['Performance and Programmatic Marketing Team', 'ORG'], ['Programmatic Marketing', 'ORG'], ['IBM', 'ORG'], ['IBM', 'ORG'], ['the IBM Performance and Programmatic Marketing Leaders', 'ORG']]
# 54 : [['• Create', 'ORG'], ['NPV', 'ORG'], ['Model Design, Data Exploration', 'ORG'], ['SAS', 'ORG']]
# 55 : [['‚', 'PERSON'], ['Corporate Headquarters', 'ORG'], ['TX', 'ORG'], ['The Marketing Intern', 'ORG'], ['Corporate Marketing', 'ORG'], ['Media Relations Successfully', 'ORG'], ['Aviall', 'PERSON'], ['Event Management Coordinate', 'ORG'], ['Microsoft Office', 'ORG'], ['Bachelor', 'ORG'], ['Business, Marketing, Communications', 'ORG'], ['GPA', 'ORG']]
# 56 : [['Strategy& Operations', 'ORG'], ['S&O', 'ORG'], ['SummerAssociate', 'ORG'], ['Our Strategy & Operations', 'ORG'], ['ourStrategy & Operations', 'ORG'], ['U.S. Citizenship', 'ORG'], ['Security Clearance', 'ORG'], ['Federal Practice', 'ORG'], ['Deloitte’scultureOur', 'PRODUCT'], ['Deloitte', 'ORG'], ['CorporatecitizenshipDeloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitteprofessionals', 'ORG'], ['John Doe Resume', 'PERSON'], ['onDeloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte Consulting LLP', 'ORG'], ['Deloitte LLP', 'ORG'], ['Deloitte LLP', 'ORG']]
# 57 : [['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton LLP', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton International Ltd', 'ORG'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton’s Audit', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Partners', 'ORG'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Giving', 'PERSON'], ['treasury', 'ORG'], ['Working', 'ORG'], ['Bachelor’s', 'ORG'], ['GPA', 'ORG'], ['Skill Requirements', 'PERSON'], ['Demonstrated', 'PRODUCT'], ['Grant Thornton LLP', 'PERSON'], ['Grant Thornton’s', 'PERSON']]
# 58 : [['Business Title Water Engineer Intern  HR Job Title Technical Intern  ', 'ORG'], ['Business Line WR Water  Employment Type As Needed  Time Type Part-Time  Visa Sponsorship', 'ORG'], ['Arcadis Arcadis', 'PERSON'], ['Arcadis', 'PERSON'], ['Arcadis', 'PERSON'], ['Arcadis', 'PERSON'], ['Engineering Intern/ Co-op', 'ORG'], ['TX', 'ORG'], ['Professional Engineers', 'ORG'], ['Intern', 'ORG'], ['Environmental Engineering', 'ORG'], ['Intern', 'ORG'], ['Required Qualifications', 'PERSON'], ['Background/Drug Screen Statement Arcadis', 'ORG']]
# 59 : [['Description  ', 'PERSON'], ['Digital Technology/E-Commerce InternshipJ.C. Penney Company,', 'ORG'], ['JCPenney', 'PRODUCT'], ['Omni Channel', 'ORG'], ['Digital Platform', 'ORG'], ['the JCPenney Home Office', 'ORG'], ['TX', 'ORG'], ['JCPenney', 'PRODUCT'], ['Core Competencies & Accomplishments: •', 'ORG'], ['Android', 'ORG'], ['Computer Science', 'ORG'], ['MIS', 'ORG'], ['Information Security', 'ORG'], ['Cyber Forensics or Data Analytics', 'ORG'], ['Cumulative 3.0', 'ORG'], ['GPA', 'ORG'], ['JCPenney', 'PRODUCT'], ['JCPenney', 'ORG'], ['Home Office', 'ORG'], ['Walgreens', 'PERSON'], ['Starbucks', 'ORG']]
# 60 : [['Learn', 'PERSON'], ['SQL', 'ORG'], ['MS Excel', 'ORG'], ['Microsoft Excel', 'ORG'], ['Access', 'ORG'], ['Cummins', 'PERSON'], ['Cummins', 'PERSON'], ['Cummins', 'PERSON'], ['E-Verify', 'PRODUCT'], ['www.dhs.gov/E-Verify', 'ORG']]
# 61 : [['Deloitte Consulting LLP', 'ORG'], ['The Strategy & Operations', 'ORG'], ['Deloitte Consulting', 'ORG'], ['Strategy & Operations', 'ORG'], ['Deloitte Consulting', 'ORG'], ['Summer Associates', 'ORG'], ['Deloitte Consulting', 'ORG'], ['Summer Associates', 'ORG'], ['Placement Office', 'ORG'], ['the Business Schools', 'ORG'], ['Leadership', 'PRODUCT'], ['Deloitte', 'ORG'], ['Deloitte Consulting LLP', 'ORG'], ['Deloitte LLP', 'ORG'], ['Deloitte LLP', 'ORG'], ['Deloitte', 'ORG'], ['the San Francisco Fair Chance Ordinance', 'ORG']]
# 62 : [['Atos', 'PERSON'], ['Atos offers Consulting & Systems Integration, Managed Services & BPO', 'ORG'], ['Cloud, Big Data & Cyber', 'ORG'], ['Atos', 'PERSON'], ['Defense, Financial Services', 'ORG'], ['Health, Manufacturing', 'ORG'], ['Media', 'ORG'], ['Utilities', 'ORG'], ['Transportation', 'ORG'], ['Atos', 'PERSON'], ['the Worldwide Information Technology Partner', 'ORG'], ['the Olympic & Paralympic Games', 'ORG'], ['Atos, Bull, Canopy,', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Predictive Maintenance of Equipment for Asset-intensive Industries', 'ORG'], ['Data Mining Methods', 'ORG'], ['Big Data Analytics', 'ORG'], ['Cloud Computing', 'PERSON'], ['Quality & Reliability Engineering Some Experience', 'ORG']]
# 63 : [['Spread Monthly Profit', 'ORG'], ['Company Financials', 'ORG'], ['SOX', 'ORG'], ['Nationstar Senior and Executive Management         ', 'ORG']]
# 64 : [['CONSULTING INTERNPosition DescriptionInterns', 'ORG'], ['Consulting Interns', 'ORG'], ['Finance', 'ORG'], ['Math, Business Administration', 'ORG'], ['Computer Science, Information Systems', 'ORG'], ['GPA', 'ORG'], ['RSM', 'PERSON'], ['RSM US', 'PERSON'], ['RSM', 'PERSON'], ['Location Street Address', 'ORG'], ['Noel Road', 'PERSON'], ['YesSponsor', 'ORG']]
# 65 : [['Invesco Ltd.', 'ORG'], ['Invesco', 'ORG'], ['the New York Stock Exchange', 'ORG'], ['IVZ', 'ORG'], ['Job Purpose', 'PERSON'], ['Invesco Real Estate', 'ORG'], ['IRE', 'ORG'], ['IRE', 'ORG'], ['IRE’s Application Support Team', 'ORG'], ['Application Support Team', 'ORG'], ['Intern', 'ORG'], ['the Applications Support Team Intern', 'ORG'], ['The Applications Support Team', 'ORG'], ['Key Responsibilities / Duties', 'ORG'], ['IRE', 'ORG'], ['Develop', 'ORG'], ['the Applications Support Team Intern', 'ORG'], ['Project & Global Lease Abstract Automation Project  Work Experience / Knowledge', 'ORG'], ['Microsoft Office', 'ORG'], ['Knowledge', 'PERSON'], ['Microsoft Visio', 'ORG'], ['Skills / Other Personal Attributes Required', 'ORG'], ['Anticipates', 'PRODUCT'], ['Seeks', 'PERSON'], ['Listens', 'PERSON'], ['Formal Education', 'ORG'], ['Computer Science, Information Systems', 'ORG'], ['FLSA', 'ORG'], ['Invesco', 'PERSON']]
# 66 : [['Business Risk', 'ORG'], ['Deloitte', 'ORG'], ['Advisory', 'ORG'], ['Interns', 'ORG'], ['an Advisory Internship Conference', 'ORG'], ['Deloitte University', 'ORG'], ['Deloitte University', 'ORG'], ['The Leadership Center', 'ORG'], ['Business Administration, Accounting, Finance, Economics', 'ORG'], ['Computer Science or Information Systems', 'ORG'], ['GPA', 'ORG'], ['Microsoft Excel', 'ORG'], ['Business Risk', 'ORG'], ['Advisory', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['CultureOur', 'ORG'], ['Deloitte', 'ORG'], ['CitizenshipDeloitte', 'ORG'], ['Deloitte', 'ORG'], ['Recruiter', 'PERSON'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte Advisory', 'ORG'], ['Deloitte & Touche LLP', 'ORG'], ['Deloitte Financial Advisory Services LLP', 'ORG'], ['Deloitte Transactions and', 'ORG'], ['Deloitte Transactions and', 'ORG'], ['Deloitte LLP', 'ORG'], ['Deloitte LLP', 'ORG'], ['S17UTXEI19JUNKW-BR', 'ORG']]
# 67 : [['CRI InternStudent', 'ORG'], ['Microsoft Office', 'ORG'], ['Word, Access, Excel', 'ORG'], ['informationADDITIONAL', 'ORG']]
# 68 : [['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton LLP', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton International Ltd', 'ORG'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ["Grant Thornton's", 'PERSON'], ['Grant Thornton', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Partners', 'ORG'], ['Grant Thornton', 'PERSON'], ['Meeting', 'PERSON'], ['Grant Thornton', 'PERSON'], ['Giving', 'PERSON'], ['IRS', 'ORG'], ['GPA', 'ORG'], ['Skill Requirements', 'PERSON'], ['Grant Thornton LLP', 'PERSON'], ['Grant Thornton’s', 'PERSON']]
# 69 : [['a Business Intelligence/SQL Developer', 'ORG'], ['Computer Science', 'ORG'], ['Business Admin', 'ORG'], ['BI/SQL', 'ORG'], ['SQL Server', 'ORG'], ['SQL', 'ORG'], ['Ideal Candidate', 'ORG'], ['Microsoft SQL Server', 'ORG'], ['Microsoft Power BI', 'ORG'], ['Candidate’s Aspiration', 'ORG'], ['Project Management, Leadership and Management Skill', 'ORG'], ['Disciplined', 'ORG'], ['Aspirational', 'ORG'], ['Task Master', 'PRODUCT'], ['Microsoft', 'ORG'], ['Microsoft Power BI', 'ORG'], ['Microsoft SharePoint Online', 'ORG'], ['Microsoft InfoPath', 'ORG'], ['Microsoft Office', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'PERSON'], ['Templates', 'PERSON'], ['OneNote', 'ORG'], ['Microsoft Skype for Business', 'ORG']]
# 70 : [['Description  Financial Planning & Analysis InternJ.C. Penney Company,', 'ORG'], ['JCPenney', 'PRODUCT'], ['Finance', 'ORG'], ['the JCPenney Financial Planning & Analysis', 'ORG'], ['Home Office', 'ORG'], ['TX', 'ORG'], ['Collect', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Core Competencies & Accomplishments: • Current', 'ORG'], ['Advanced', 'ORG'], ['notice• Strong', 'ORG'], ['Advanced Microsoft Excel', 'ORG'], ['PowerPoint', 'ORG'], ['Microsoft Access', 'ORG'], ['Ability', 'ORG'], ['Start Date', 'PERSON'], ['JCPenney', 'PRODUCT'], ['JCPenney', 'ORG'], ['Home Office', 'ORG'], ['Walgreens', 'PERSON'], ['Starbucks', 'ORG']]
# 71 : [['SAP Academy for Presales - Dallas Job Apply', 'ORG'], ['LinkedIn     Start', 'ORG'], ['Facebook     Start', 'ORG'], ['Xing      Apply', 'PRODUCT'], ['TX', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['Objectives', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['SAP Academy for Presales', 'ORG'], ['SAP Presales', 'ORG'], ['Presales Specialist', 'ORG'], ['the SAP Account Executive', 'ORG'], ['AE', 'ORG'], ['SAP', 'ORG'], ['Knows', 'PRODUCT'], ['the SAP Academy for Presales', 'ORG'], ['The SAP Presales Academy', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['Role Plays', 'PERSON'], ['Case Studies', 'ORG'], ['Classroom Learning', 'ORG'], ['Academy', 'ORG'], ['Design Thinking,', 'ORG'], ['Financial Case', 'ORG'], ['Interpersonal Skills and', 'ORG'], ['Social Selling', 'ORG'], ['SAP Supporting', 'ORG'], ['Qualifications/Skills', 'ORG'], ['The SAP Academy for Presales', 'ORG'], ['Accounting, Finance, Information Systems', 'ORG'], ['Project Management', 'ORG'], ['Supply Chain Management, Travel and', 'ORG'], ['Logistics, Database Technology', 'ORG'], ['Technically', 'PERSON'], ['post academy', 'ORG'], ['the Lines of Business’s', 'ORG'], ['HR Practitioners', 'ORG'], ['Consumer Products, Oil & Gas', 'ORG'], ['Professional Services', 'ORG'], ['Consumer Products, Professional Services', 'ORG'], ['The Academy Program', 'ORG'], ['SAPACADEMYforPresales', 'PERSON'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['SAP', 'ORG'], ['Recruiting Operations Team (Americas', 'ORG'], ['APJ', 'ORG'], ['EMEA', 'ORG'], ['EOE AA M/F/Vet/Disability', 'ORG'], ['Dallas Nearest Secondary Market', 'ORG'], ['SAP', 'ORG'], ['Intern', 'ORG'], ['ERP', 'ORG'], ['Outside Sales, Finance, Technology, Entry Level', 'ORG'], ['LinkedIn     Start', 'ORG'], ['Facebook     Start', 'ORG'], ['Xing      Apply', 'PRODUCT']]
# 72 : [['MIS', 'ORG'], ['the Pricing & Strategy', 'ORG'], ['Profitability Teams within Decision Sciences', 'ORG'], ['Pricing MIS', 'PERSON'], ['Pricing & Strategy', 'ORG'], ['Decision Sciences', 'ORG'], ['Decision Sciences', 'ORG'], ['Information Technology', 'ORG'], ['Data Visualization', 'ORG'], ['SharePoint', 'ORG'], ['Identify', 'PERSON'], ['Complete', 'PERSON'], ['MIS', 'ORG'], ['MIS', 'ORG'], ['SQL', 'ORG'], ['SAS', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Extraction, Transformation and Loading', 'ORG'], ['Data Management', 'ORG'], ['Credit Policy', 'ORG'], ['Ability', 'ORG'], ['Superior', 'PRODUCT'], ['Working Conditions', 'ORG'], ['Employer’s Rights', 'ORG']]
# 73 : [['The CoreLogic Summer Internship Program', 'ORG'], ['CoreLogic', 'ORG'], ['CoreLogic', 'ORG'], ['Spatial', 'ORG'], ['Follows department', 'ORG'], ['Participates in Internship Program', 'ORG'], ['Knowledge', 'PERSON'], ['Business, Economics', 'ORG'], ['Demonstrated', 'PRODUCT'], ['Skills  Ability', 'ORG'], ['Solid', 'ORG'], ['Proficiency', 'ORG'], ['Microsoft Office', 'ORG'], ['Word, Excel,', 'ORG'], ['PowerPoint', 'ORG'], ['CoreLogic', 'ORG'], ['CoreLogic', 'ORG']]
# 74 : [['the Federal Reserve Bank', 'ORG'], ['Fed', 'ORG'], ['Treasury', 'ORG'], ['the Federal Reserve Bank', 'ORG'], ['Dallas Treasury Services Department', 'ORG'], ['MS SharePoint', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Bachelor', 'ORG'], ['Business Administration', 'ORG'], ['CONDITIONS', 'ORG']]
# 75 : [['The CoreLogic Summer Internship Program', 'ORG'], ['CoreLogic', 'ORG'], ['CoreLogic', 'ORG'], ['the Pricing Operations', 'ORG'], ['Pricing and', 'ORG'], ['Internship Program', 'ORG'], ['KnowledgeCurrently', 'PERSON'], ['Microsoft Office', 'ORG'], ['Word, Excel,', 'ORG'], ['CoreLogic', 'ORG']]
# 76 : [['The Data Scientist Intern', 'ORG'], ['Information Technology', 'ORG'], ['Computer Engineering', 'ORG'], ['Computer Science, Engineering Technology', 'ORG'], ['MIS', 'ORG'], ['HMS', 'ORG'], ['State', 'ORG'], ['HMS', 'ORG'], ['Application', 'PRODUCT'], ['ETL', 'ORG'], ['MDM', 'ORG'], ['Pattern Recognition', 'ORG'], ['Identity Matching', 'ORG'], ['Machine Learning', 'PERSON'], ['Big Data', 'ORG'], ['Languages', 'PERSON'], ['Java', 'PERSON'], ['SQL', 'ORG']]
# 77 : [['IBM', 'ORG'], ['Technical Solution Specialist Internship', 'ORG'], ['IBM', 'ORG'], ['IBM', 'ORG'], ['Computer Engineering', 'ORG'], ['Computer Science, Data Science, Electrical Engineering', 'ORG'], ['Information Technology', 'ORG'], ['IBM', 'ORG'], ['IBM', 'ORG'], ['IBM Technical Solution', 'ORG'], ['IBM', 'ORG'], ['IBM', 'ORG'], ['IBM', 'ORG'], ['IBM', 'ORG'], ['Cloud, Commerce', 'ORG'], ['Summit', 'ORG']]
# 78 : [['USA  Apply', 'ORG'], ['Atos offers Consulting & Systems Integration, Managed Services & BPO', 'ORG'], ['Cloud, Big Data & Cyber', 'ORG'], ['Atos', 'PERSON'], ['Defense, Financial Services', 'ORG'], ['Health, Manufacturing', 'ORG'], ['Media', 'ORG'], ['Utilities', 'ORG'], ['Transportation', 'ORG'], ['Atos', 'PERSON'], ['the Worldwide Information Technology Partner', 'ORG'], ['the Olympic & Paralympic Games', 'ORG'], ['Atos, Bull, Canopy,', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Computer ScienceExperience', 'ORG'], ['Big Data', 'ORG'], ['Data Management', 'ORG'], ['Metadata Management, Data Integration Technologies – Hadoop', 'ORG'], ['ElasticSearch', 'ORG'], ['Jaspersoft', 'PERSON'], ['Java', 'PERSON']]
# 79 : [['Intern/Co-Op Work Location', 'ORG'], ['TX Posted Date', 'ORG'], ['Unlock Your Career Potential', 'ORG'], ['CORE', 'ORG'], ['Insightful Expertise,', 'ORG'], ['Everything, Service Excellence, Inspiring Innovation', 'ORG'], ['GPA', 'ORG'], ['Knowledge', 'PERSON'], ['Microsoft Office', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Project', 'ORG'], ['Information Technology', 'ORG'], ['Management Information Systems', 'ORG'], ['Business Management Knowledge', 'ORG'], ['Opportunity, University', 'ORG'], ['Software', 'ORG'], ['FORTUNE® Magazine', 'ORG'], ['Forbes®', 'ORG']]
# 80 : [['Microsoft Office', 'ORG'], ['Outlook and Excel', 'ORG'], ['ExactTarget', 'ORG'], ['SurveyMonkey', 'ORG'], ['Google Analytics', 'ORG'], ['HTML', 'ORG'], ['SQL', 'ORG'], ['Quantitative Marketing Research of', 'ORG'], ['•Provide', 'ORG'], ['The 5 Dysfunctions of a Team', 'ORG'], ['Multi-Channel Experience', 'ORG'], ['DRTV', 'ORG']]
# 81 : [['The CoreLogic Summer Internship Program', 'ORG'], ['CoreLogic', 'ORG'], ['CoreLogic', 'ORG'], ['Internship Program', 'ORG'], ['KnowledgeCurrently', 'PERSON'], ['Microsoft Office', 'ORG'], ['Word, Excel,', 'ORG'], ['CoreLogic', 'ORG']]
# 82 : [['USA  Apply', 'ORG'], ['Atos offers Consulting & Systems Integration, Managed Services & BPO', 'ORG'], ['Cloud, Big Data & Cyber', 'ORG'], ['Atos', 'PERSON'], ['Defense, Financial Services', 'ORG'], ['Health, Manufacturing', 'ORG'], ['Media', 'ORG'], ['Utilities', 'ORG'], ['Transportation', 'ORG'], ['Atos', 'PERSON'], ['the Worldwide Information Technology Partner', 'ORG'], ['the Olympic & Paralympic Games', 'ORG'], ['Atos, Bull, Canopy,', 'ORG'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Atos', 'PERSON'], ['Predictive Maintenance of Equipment for Asset-intensive Industries', 'ORG'], ['Data Mining Methods', 'ORG'], ['Big Data Analytics', 'ORG'], ['Cloud Computing', 'PERSON'], ['Quality & Reliability Engineering Some Experience', 'ORG']]
# 83 : [['‚', 'PERSON'], ['Corporate Headquarters', 'ORG'], ['TX', 'ORG'], ['The Accounting/Finance Intern', 'ORG'], ['inter-CoSA', 'ORG'], ['Microsoft Office', 'ORG'], ['Bachelor', 'ORG'], ['Mathematics, Risk Management, Statistics', 'ORG'], ['Data/Analytics', 'ORG'], ['GPA', 'ORG']]
# 84 : [['Performance and Programmatic Marketing Team', 'ORG'], ['Programmatic Marketing', 'ORG'], ['IBM', 'ORG'], ['IBM', 'ORG'], ['the IBM Performance and Programmatic Marketing Leaders', 'ORG']]
# 85 : [['• Create', 'ORG'], ['NPV', 'ORG'], ['Model Design, Data Exploration', 'ORG'], ['SAS', 'ORG']]
# 86 : [['‚', 'PERSON'], ['Corporate Headquarters', 'ORG'], ['TX', 'ORG'], ['The Marketing Intern', 'ORG'], ['Corporate Marketing', 'ORG'], ['Media Relations Successfully', 'ORG'], ['Aviall', 'PERSON'], ['Event Management Coordinate', 'ORG'], ['Microsoft Office', 'ORG'], ['Bachelor', 'ORG'], ['Business, Marketing, Communications', 'ORG'], ['GPA', 'ORG']]
# ...
# 131 : [['HCSC', 'ORG'], ['HCSC', 'ORG'], ['Career', 'PRODUCT'], ['HCSC', 'ORG'], ['Health Care Service Corporation', 'ORG'], ['HCSC', 'ORG'], ['Blue Cross', 'ORG'], ['Blue Shield', 'ORG'], ['THE DEPARTMENT', 'ORG'], ['HCSC', 'ORG'], ['FUNCTION Interns', 'PERSON'], ['HCSC', 'ORG'], ['Business Analytics', 'ORG'], ['Data Analytics', 'ORG'], ['Epidemiology', 'ORG'], ['GPA', 'ORG'], ['Practical', 'ORG'], ['SQL', 'ORG'], ['SAS', 'ORG'], ['PowerPoint', 'ORG'], ['Excel', 'PRODUCT'], ['SAS', 'ORG'], ['SQL', 'ORG'], ['Preferred Job Requirements', 'ORG'], ['GPA', 'ORG'], ['IL', 'ORG'], ['Richardson', 'PERSON'], ['TX', 'ORG'], ['Health Care Service Corporation Founded', 'ORG'], ['HCSC', 'ORG'], ['Blue Cross', 'ORG'], ['Blue Shield®', 'ORG'], ['Blue Cross', 'ORG'], ['Blue Shield', 'ORG'], ['Dearborn National', 'ORG'], ['Tier IV', 'PRODUCT'], ['LI-POST', 'ORG']]
# 132 : [['The Associate Project Specialist Intern', 'ORG'], ['QBO', 'ORG'], ['Information Technology', 'ORG'], ['Computer Engineering', 'ORG'], ['Computer Science, Engineering Technology', 'ORG'], ['MIS', 'ORG'], ['QBO', 'ORG'], ['Project Specialist', 'ORG'], ['QBO', 'ORG'], ['Project ManagementProcess ImprovementProblem SolvingRelationship', 'ORG']]
# 133 : [['Apple Leisure Group', 'ORG'], ['Apple Vacations, Travel Impressions', 'ORG'], ['CheapCaribbean.com', 'ORG'], ['Hire', 'PERSON'], ['Own', 'ORG'], ['Manage', 'ORG'], ['Business, Computer Science', 'ORG']]
# 134 : [['HCSC', 'ORG'], ['HCSC', 'ORG'], ['Career', 'PRODUCT'], ['HCSC', 'ORG'], ['Health Care Service Corporation', 'ORG'], ['HCSC', 'ORG'], ['Blue Cross', 'ORG'], ['Blue Shield', 'ORG'], ['THE DEPARTMENT', 'ORG'], ['HCSC', 'ORG'], ['FUNCTION Interns', 'PERSON'], ['HCSC', 'ORG'], ['Business Analytics', 'ORG'], ['Data Analytics', 'ORG'], ['Epidemiology', 'ORG'], ['GPA', 'ORG'], ['Practical', 'ORG'], ['SQL', 'ORG'], ['SAS', 'ORG'], ['PowerPoint', 'ORG'], ['Excel', 'PRODUCT'], ['SAS', 'ORG'], ['SQL', 'ORG'], ['Preferred Job Requirements', 'ORG'], ['GPA', 'ORG'], ['IL', 'ORG'], ['Richardson', 'PERSON'], ['TX', 'ORG'], ['Health Care Service Corporation Founded', 'ORG'], ['HCSC', 'ORG'], ['Blue Cross', 'ORG'], ['Blue Shield®', 'ORG'], ['Blue Cross', 'ORG'], ['Blue Shield', 'ORG'], ['Dearborn National', 'ORG'], ['Tier IV', 'PRODUCT'], ['LI-POST', 'ORG']]
# 135 : [['HCSC', 'ORG'], ['HCSC', 'ORG'], ['Career', 'PRODUCT'], ['Information Technology Intern', 'ORG'], ['HCSC', 'ORG'], ['Java', 'PERSON'], ['Jira', 'PERSON'], ['Extreme Programming', 'ORG'], ['Scrum', 'PERSON'], ['HCSC', 'ORG'], ['HCSC', 'ORG'], ['3.0', 'PRODUCT'], ['GPA', 'ORG'], ['un', 'ORG'], ['Strong Microsoft Excel,', 'ORG'], ['PowerPoint', 'ORG'], ['Java', 'PERSON'], ['Javascript', 'PERSON'], ['SQL', 'ORG'], ['HTML', 'ORG'], ['MVC', 'ORG'], ['Data Analytics', 'ORG']]
# 136 : [['TexasData', 'ORG'], ['Intern - The University of Texas', 'ORG'], ['AustinOur', 'ORG'], ['Capital Ones', 'ORG'], ['Data', 'ORG'], ['the Analyst Internship Program', 'ORG'], ['Capital One', 'ORG'], ['Capital Ones', 'ORG'], ['Capital One University.- Executive Speakers Learn', 'ORG'], ['the Analyst Internship Program', 'ORG'], ['Capital Ones', 'ORG'], ['ATM', 'ORG'], ['Diving', 'PERSON'], ['The University of Texas', 'ORG'], ['Austin-', 'PERSON'], ['Java', 'PERSON'], ['JavaScript', 'PERSON'], ['SQL', 'ORG'], ['C++', 'PERSON'], ['SAS', 'ORG'], ['Capital One', 'ORG']]
# 137 : [['the State of Texas', 'ORG'], ['NTTA', 'PERSON'], ['Information Technology', 'ORG'], ['NTTA', 'ORG'], ['Knowledge', 'PERSON'], ['Skills', 'ORG'], ['Microsoft Office Applications', 'ORG'], ['GPA', 'ORG'], ['Microsoft Excel', 'ORG'], ['PowerPoint', 'PRODUCT'], ['the United StatesProjects:Hardware/Software UpgradeInventory', 'ORG'], ['MigrationStudents', 'ORG'], ['GPA', 'ORG'], ['NTTA', 'PERSON'], ['the State of Texas', 'ORG'], ['NTTA', 'PERSON'], ['NTTA', 'ORG'], ['Authority', 'ORG']]
# 138 : [['HCSC', 'ORG'], ['HCSC', 'ORG'], ['Career', 'PRODUCT'], ['Information Technology Intern', 'ORG'], ['HCSC', 'ORG'], ['Java', 'PERSON'], ['Jira', 'PERSON'], ['Extreme Programming', 'ORG'], ['Scrum', 'PERSON'], ['HCSC', 'ORG'], ['HCSC', 'ORG'], ['3.0', 'PRODUCT'], ['GPA', 'ORG'], ['un', 'ORG'], ['Strong Microsoft Excel,', 'ORG'], ['PowerPoint', 'ORG'], ['Java', 'PERSON'], ['Javascript', 'PERSON'], ['SQL', 'ORG'], ['HTML', 'ORG'], ['MVC', 'ORG'], ['Data Analytics', 'ORG']]
# 139 : [['University Programs: Engineering Intern Raytheon Intelligence, Information and Services', 'ORG'], ['IRAD', 'ORG'], ['Skills & Experience', 'ORG'], ['Computer Science, Mathematics', 'ORG'], ['Statistics', 'ORG'], ['US Citizens', 'ORG'], ['Federal Government', 'ORG'], ['Skills & Experience', 'ORG'], ['Matlab', 'PERSON'], ['Hadoop', 'ORG'], ['Hive', 'PERSON'], ['Map Reduce', 'PERSON'], ['Bachelor', 'ORG'], ['Computer Science, Mathematics, Statistics', 'ORG'], ['Data Science', 'ORG'], ['US Citizens', 'ORG'], ['Federal Government', 'ORG']]
# 140 : [['Digital Marketing Coordinator', 'ORG'], ['Summit', 'ORG'], ['Summit Truck Group', 'ORG'], ['Digital Marketing Coordinator', 'ORG'], ['Summit Truck Group', 'ORG'], ['TX', 'ORG'], ['Digital Marketing Coordinator', 'ORG'], ['Manage', 'ORG'], ['Summits', 'ORG'], ['SEO', 'ORG'], ['Business Administration or Business of Science', 'ORG'], ['Summit Truck Group', 'ORG'], ['Summit Truck Group', 'ORG'], ['Summit Lease & Rental', 'ORG'], ['Summit Truck Group', 'ORG'], ['Volvo', 'ORG'], ['Mack', 'ORG'], ['Ford', 'ORG'], ['Isuzu', 'ORG'], ['Crane Carrier', 'PERSON'], ['Summit Truck Group', 'ORG'], ['Summit Truck Group', 'ORG']]
# 141 : [['The Internship Program Our', 'ORG'], ['Hourly / Temporary Division Name / Location: Corporate Office / Torrance', 'ORG'], ['DOE', 'ORG'], ['Principal Activities', 'PERSON'], ['Federal', 'ORG'], ['Analysis', 'ORG'], ['General Accounting', 'ORG'], ['Investigate', 'ORG'], ['Obtain', 'ORG'], ['Analyze', 'PRODUCT'], ['Bachelor', 'ORG'], ['Accounting, Economics', 'ORG'], ['GPA', 'ORG'], ['Background', 'PERSON'], ['Ledger', 'PERSON'], ['Visa', 'ORG'], ['Language Requirements', 'ORG'], ['Comprehensive Training  Access', 'PERSON'], ['Leaders Capstone Project', 'ORG'], ['Lunch & Learns', 'ORG']]
# 142 : [['Data Conversion Specialist', 'ORG'], ['EZLynx', 'ORG'], ['EZLynx', 'ORG'], ['Main', 'ORG'], ['Define', 'ORG'], ['Conflict management Communication skills Stress', 'ORG'], ['Strong Computer Skills Advanced', 'ORG'], ['Microsoft Excel  ', 'ORG']]
# 143 : [['Learfield', 'PERSON'], ['Learfield Map', 'PERSON'], ['Learfield', 'PERSON'], ['Learfield', 'PERSON'], ['Business Development', 'ORG'], ['Senior Management, Corporate Events', 'ORG'], ['Digital', 'ORG'], ['Sales Analytics, Research and Marketing', 'ORG'], ['General Administration', 'ORG'], ['Learfield', 'PERSON'], ['Learfield', 'PERSON'], ['Senior Management', 'ORG'], ['Digital', 'ORG'], ['Sales Analytics, Research and Marketing', 'ORG'], ['General Administration', 'ORG'], ['Scarborough', 'ORG'], ['Learfield Account Executives.- Support the Sales Innovation', 'ORG'], ['Learfield', 'PERSON'], ['the Learfield Sports’ blog.- Support the Events Team', 'ORG'], ['Twitter', 'PERSON'], ["the Learfield Sports Directors'", 'ORG'], ['entities.- Oversee', 'ORG'], ['Smart', 'PERSON'], ['Bachelor’s Degree', 'PERSON'], ['Timing & Compensation:Hiring', 'ORG']]
# 144 : [['Advantage Sales & Marketing', 'ORG'], ['LLC', 'ORG'], ['LLC', 'ORG'], ['ASM', 'ORG'], ['ASM', 'ORG'], ['Creative Directors', 'PERSON'], ['Art Directors', 'PERSON'], ['ManagementManage', 'ORG'], ['ASM', 'ORG'], ['LeadMentor', 'ORG'], ['Supervisor, Client Service', 'ORG'], ['Client RelationsBuild', 'PERSON'], ['Field Marketing, Account Services', 'ORG'], ['Responsibilities  Direct Reports', 'ORG'], ['Indirect Reports', 'ORG'], ['Bachelor', 'ORG'], ['Field of Study/Area of Experience', 'ORG'], ['Knowledge', 'PERSON'], ['AbilitiesStrong', 'ORG'], ['SkillsAbility', 'ORG'], ['SkillsConflict', 'ORG'], ['Microsoft Word', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Total Rewards', 'ORG'], ['Additional Information Regarding ASM Job Duties', 'ORG'], ['ASM', 'ORG'], ['Entrepreneurial Focus', 'PERSON'], ['Advantage Sales & Marketing LLC', 'ORG'], ['ASM', 'ORG'], ['the Los Angeles Fair Chance Initiative for Hiring', 'ORG']]
# 145 : [['Digital Technology/E-Commerce Internship J.C. Penney Company,', 'ORG'], ['JCPenney', 'PRODUCT'], ['Omni Channel', 'ORG'], ['Digital Platform', 'ORG'], ['the JCPenney Home Office', 'ORG'], ['TX', 'ORG'], ['JCPenneys', 'ORG'], ['• Expanding', 'PERSON'], ['Core Competencies & Accomplishments', 'ORG'], ['Android', 'ORG'], ['• Current', 'ORG'], ['Computer Science', 'ORG'], ['MIS', 'ORG'], ['Information Security', 'ORG'], ['Cyber Forensics or Data Analytics', 'ORG'], ['• Cumulative', 'ORG'], ['GPA', 'ORG'], ['• Outstanding', 'ORG'], ['• Ability', 'ORG'], ['• Excellent', 'ORG'], ['Start Date', 'ORG'], ['JCPenney', 'PRODUCT'], ['JCPenney', 'ORG'], ['Home Office', 'ORG'], ['Walgreens', 'PERSON'], ['Starbucks', 'ORG']]
# 146 : [['The Internship Program Our', 'ORG'], ['Hourly / Temporary Division Name / Location', 'ORG'], ['TX Department Name', 'ORG'], ['Ag & Turf Hours', 'ORG'], ['Turf     Principal Activities', 'ORG'], ['Federal', 'ORG'], ['Generate', 'PERSON'], ['Learn', 'PERSON'], ['CRM', 'PRODUCT'], ['CRM', 'PRODUCT'], ['Learn', 'PERSON'], ['CRM', 'PRODUCT'], ['State', 'ORG'], ['the Turf Department', 'ORG'], ['Division Events', 'ORG'], ['the Turf Department', 'ORG'], ['Complete', 'PERSON'], ['Bachelor', 'ORG'], ['Business, General Agriculture, Agribusiness, Ag Communications', 'ORG'], ['Ag Mechanization', 'ORG'], ['Marketing, Communications, Advertising', 'ORG'], ['Skills', 'ORG'], ['Background', 'PERSON'], ['Microsoft Office', 'ORG'], ['Power Point', 'ORG'], ['Excel', 'PRODUCT'], ['Facebook Updates', 'ORG'], ['Visa', 'ORG'], ['Language Requirements', 'ORG'], ['Comprehensive Training  Access', 'PERSON'], ['Leaders Capstone Project', 'ORG'], ['Social Events', 'ORG']]
# 147 : [['The Associate Project Specialist Intern', 'ORG'], ['QBO', 'ORG'], ['Information Technology', 'ORG'], ['Computer Engineering', 'ORG'], ['Computer Science, Engineering Technology', 'ORG'], ['MIS', 'ORG'], ['QBO', 'ORG'], ['Project Specialist', 'ORG'], ['QBO', 'ORG'], ['QBO', 'ORG'], ['Project Management  * Process', 'ORG']]
# 148 : [["GM FINANCIAL'S", 'ORG'], ['GM Financial', 'ORG'], ['General Motors', 'ORG'], ['GM Financial', 'ORG'], ['GM Financial', 'ORG'], ['Summer Internship Program', 'ORG'], ['the Credit Review', 'ORG'], ['Credit Review Must', 'ORG'], ['Bachelor', 'ORG'], ['Computer Science, Finance', 'ORG'], ['Mathematics, Statistics, Economics', 'ORG'], ['GMF', 'ORG']]
# 149 : [['Company', 'ORG'], ['LafargeHolcim', 'ORG'], ['Building Better Cities', 'ORG'], ['the Wildlife Habitat Council', 'ORG'], ['Habitat', 'ORG'], ['Cement or Aggregate', 'ORG'], ['ELECTIRCAL ENGINEERING PROJECTSParticipate', 'ORG'], ['SAP', 'ORG'], ['Process Area Teams', 'ORG'], ['SKILLS & ABILITIESRequired Education', 'ORG'], ['Required Field of Study: Electrical', 'ORG'], ['GPA', 'ORG'], ['Requirements / Working Conditions:Frequent', 'ORG'], ['Required Computer', 'ORG'], ['Software', 'ORG'], ['Microsoft Office', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Interns', 'ORG'], ['SAP', 'ORG'], ['Autocad', 'ORG'], ['Lafarge North America Inc.', 'ORG'], ['Holcim', 'PERSON'], ['Aggregate Industries Management, Inc.', 'ORG'], ['AJETR+02', 'ORG'], ['AJETR+03', 'ORG'], ['AJETR+07', 'ORG']]
# 150 : [['Company', 'ORG'], ['LafargeHolcim', 'ORG'], ['Building Better Cities', 'ORG'], ['the Wildlife Habitat Council', 'ORG'], ['Habitat', 'ORG'], ['Cement or Aggregate', 'ORG'], ['ELECTIRCAL ENGINEERING PROJECTSParticipate', 'ORG'], ['SAP', 'ORG'], ['Process Area Teams', 'ORG'], ['SKILLS & ABILITIESRequired Education', 'ORG'], ['Required Field of Study: Electrical', 'ORG'], ['GPA', 'ORG'], ['Requirements / Working Conditions:Frequent', 'ORG'], ['Required Computer', 'ORG'], ['Software', 'ORG'], ['Microsoft Office', 'ORG'], ['Excel', 'PRODUCT'], ['PowerPoint', 'ORG'], ['Interns', 'ORG'], ['SAP', 'ORG'], ['Autocad', 'ORG'], ['Lafarge North America Inc.', 'ORG'], ['Holcim', 'PERSON'], ['Aggregate Industries Management, Inc.', 'ORG'], ['AJETR+02', 'ORG'], ['AJETR+03', 'ORG'], ['AJETR+07', 'ORG']]
# 151 : [['The Internship Program Our', 'ORG'], ['Hourly / Temporary Division Name / Location:', 'ORG'], ['TX Department Name: Sales & Marketing Hours', 'ORG'], ['Sales & Marketing Operations Rate', 'ORG'], ['DOE', 'ORG'], ['Principal Activities', 'PERSON'], ['Federal', 'ORG'], ['Business Plan', 'ORG'], ['Regional Sales Management', 'ORG'], ['Complete', 'PERSON'], ['Bachelor', 'ORG'], ['Economics, Finance', 'ORG'], ['GPA', 'ORG'], ['Advanced Excel Skills', 'PRODUCT'], ['SAP', 'ORG'], ['Power Point', 'ORG'], ['Language Requirements', 'ORG'], ['Comprehensive Training  Access', 'PERSON'], ['Leaders Capstone Project', 'ORG'], ['Lunch & Learns', 'ORG']]
# 152 : [['MIS', 'ORG'], ['HMS.Review', 'ORG'], ['Good Communication SkillsProject Management SkillsGood', 'ORG']]
# 153 : [['The Internship Program  Our', 'ORG'], ['FLSA', 'ORG'], ['Hourly / Temporary  Division Name / Location:', 'ORG'], ['TX  Department Name: Sales & Marketing  Hours', 'ORG'], ['Sales & Marketing Operations  Rate', 'ORG'], ['DOE', 'ORG'], ['Principal Activities', 'PERSON'], ['Federal', 'ORG'], ['Business Plan', 'ORG'], ['Regional Sales Management', 'ORG'], ['Complete', 'PERSON'], ['Economics, Finance', 'ORG'], ['GPA', 'ORG'], ['Advanced Excel Skills', 'ORG'], ['SAP', 'ORG'], ['Power Point', 'ORG'], ['Language Requirements', 'PERSON'], ['Comprehensive Training  Access', 'PERSON'], ['Leaders  Capstone Project', 'ORG'], ['Lunch & Learns', 'ORG'], ['StartWire', 'ORG']]
# 154 : [['Human Capital Actuarial', 'ORG'], ['Human Capital', 'ORG'], ['Health, Life, P&C', 'ORG'], ['Human Capital Actuarial', 'ORG'], ['Qualifications  Required  * Enrollment', 'ORG'], ['Bachelor', 'ORG'], ['GPA', 'ORG'], ['CAS', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte University', 'ORG'], ['Deloitte University', 'ORG'], ['The Leadership Center', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Recruiter', 'PERSON'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG']]
# 155 : [['The Internship Program  Our', 'ORG'], ['FLSA', 'ORG'], ['Hourly / Temporary  Division Name / Location', 'ORG'], ['TX  Department Name:', 'ORG'], ['Ag & Turf  Hours', 'ORG'], ['Turf  Principal Activities', 'ORG'], ['Federal', 'ORG'], ['Assist the Ag & Turf Department', 'ORG'], ['Generate', 'PERSON'], ['Learn', 'PERSON'], ['CRM', 'PRODUCT'], ['CRM', 'PRODUCT'], ['Learn', 'PERSON'], ['CRM', 'PRODUCT'], ['State', 'ORG'], ['the Turf Department', 'ORG'], ['Assist', 'ORG'], ['Division Events', 'ORG'], ['the Turf Department', 'ORG'], ['Complete', 'PERSON'], ['Business, General Agriculture, Agribusiness, Ag Communications', 'ORG'], ['Ag Mechanization', 'ORG'], ['Marketing, Communications, Advertising', 'ORG'], ['Skills', 'ORG'], ['Background', 'PERSON'], ['Microsoft Office', 'ORG'], ['Power Point', 'ORG'], ['Excel', 'PRODUCT'], ['Facebook Updates', 'ORG'], ['Visa', 'ORG'], ['Language Requirements', 'ORG'], ['Comprehensive Training  Access', 'PERSON'], ['Leaders  Capstone Project', 'ORG'], ['Social Events', 'ORG']]
# 156 : [['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Corporate Finance', 'ORG'], ['Deloitte', 'ORG'], ['Private Equity', 'ORG'], ['Deloitte', 'ORG'], ['the Business Development committee', 'ORG'], ['Qualifications  Required  * Open', 'ORG'], ['GPA', 'ORG'], ['Employee Stock Ownership Plans', 'ORG'], ['Corporate Finance', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Corporate Citizenship', 'ORG'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['Recruiter Tips', 'PERSON'], ['Deloitte', 'ORG'], ['Deloitte', 'ORG'], ['CFPosted', 'ORG'], ['StartWire', 'ORG']]

# %%
ner_dict = {
    "Skills": [
        "Data Modeling", "Data Warehousing", "Data Management", "Data Visualization",
        "Data Analytics",  "ETL", "Extraction","Transformation", "Loading", "Reporting",
        "Data Science", "Business Intelligence", "BI", "Advanced Analytics",
        "Information Technology", "IT", "Cloud", "CyberSecurity", "Business Objects",
        "Quality Assurance","Testing", "Digital Marketing", "Marketing Analytics",
        "Social Media Analytics", "Marketing Communications", "Data Integration",
        "Cloud Computing", "Machine Learning", "Business Analytics", "Data Mining",
        "Predictive Analytics", "Problem Solving", "Project Management", "Leadership",
        "Task Master", "Analytical Thinking", "Strategic Thinking",
        "Quality & Reliability Engineering", "Data Mining Methods",
        "Predictive Maintenance of Equipment", "Data Warehouse",
        "Leadership and Management Skills", "Financial Planning & Analysis",
        "Risk Management", "Business Risk", "Interpersonal Skills", "Communication Skills",
        "Business Analysis", "Operations Management",
        "Analytics", "Visualization", "Statistical Analysis" ,
        "Risk Management" , "Workflow Ability", "Epidemiology", "Process Improvement",
        "Relationship Management", "Extreme Programming", "Feature Driven Development",
        "Dynamic Systems Development Method",
        "Data Conversion", "Project Management Skills", "Analytical Skills",
    ],
    "Tools": [
        "PL", "SQL", "BODS (BusinessObjects Data Services)", "SAS", "Hadoop", "Spark", "CSS",
        "JavaScript", "UI5", "Fiori", "SAP", "Tableau", "MS", "Oracle", "EDW"
        "Microsoft Office Suite", "Excel", "Word", "PowerPoint", "Access",
        "Microsoft SharePoint", "Microsoft Access", "IBM Cognos", "SQL Server", "Oracle",
        "CMS","Content Management Systems", "CRM", "Customer Relationship Management",
        "Google AdWords", "Adobe Suite", "Microsoft Power BI", "QlikView", "Jaspersoft",
        "Text Mining Tools", "ElasticSearch", "Logstash", "Visual Analytics Tools", "InfoPath",
        "Microsoft Skype for Business", "Microsoft Visio", "Microsoft Outlook", "Yardi",
        "ERP systems", "Design Thinking", "Google Analytics", "SurveyMonkey", "ExactTarget",
        "Twitter", "Facebook", "Balsamiq", "Notepad++", "Macromedia Flash", "Java/J2EE",
        "Drools", "eViews", "MS Project", "ServiceNow","Windows","Linux", "Windows/Linux Environments", "SAN",
        "Avaya", "Polycom VC", "Acme Packet SBC’s & ECB", "QuickBooks", "TurboTax", "Mint.com",
        "SQL", "Map Reduce", "Autocad", "Facebook Updates", "Jira", "MVC", "Excel", "PowerPoint", "Word",
        "JavaScript", "PHP", "Microsoft Visio", "Java", "CSS", "HTML", "Visual BI", "MATLAB", "SPSS", "Scrum",
         "Software-as-a-Service", "SaaS"
    ],
    "Expertise": [
        "Big Data & Analytics Solutions", "Business Intelligence Solutions", "Visualization Tools",
        "Cloud & Big Data (specifically in relation to consulting and managed services)",
        "Cybersecurity Expertise", "Data Warehousing Expertise", "Software Engineering",
        "Cloud Computing Expertise", "Digital Product Marketing Expertise",
        "Marketing Strategy Expertise", "IT/Software Solutions & Consulting Expertise",
        "Project Tracking & Management Expertise", "Cloud, Big Data & Cyber", "Information Technology",
        "Business Intelligence", "Finance", "Health & Manufacturing", "Data Warehouse", "ERP",
        "Business Risk", "Business Strategy", "Financial Analysis", "Consulting & Systems Integration",
        "IT Support", "Tax Intern", "Financial Planning & Analysis", "Retail & Telecommunications",
        "Marketing & Consumer Branding", "Managed Services & BPO", "Marketing and Media Relations",
        "Operations and Strategy", "Health, Manufacturing, Retail, Telecommunications, Transportation",
        "Business Analytics", "Project Management and Finance", "Information Security and Cyber Forensics",
        "Environmental Engineering", "Audit and Tax", "Insurance and Spatial Product Development",
        "Treasury Services", "Data Integration Technologies", "Business & Marketing Strategy",
        "Marketing Research", "Financial Services", "Human Resources & Recruiting",
        "Risk Management & Treasury", "Consumer Brand Analytics", "Corporate Communications",
        "Operations & Logistics Management", "Project Management & Business Analysis",
        "Business Analysis", "Data Engineering", "Data Science Research", "Web Development",
        "Market Research", "Business Development", "Financial Auditing", "Risk Management",
        "Process Safety Management", "Voice Engineering", "E-commerce and IT Solutions",
        "Strategic Communications and PR", "Managed Services Providers", "Data Analytics", "Health Care",
        "General Administration", "Digital Marketing", "Marketing", "General Accounting", "Management",
        "Engineering Technology", "Computer Engineering", "Economics", "Mathematics", "Computer Science",
        "General Agriculture", "Marketing Communications", "Sales Operations"
    ]
}


'''
skills = {
    "skills": [
    "AB Testing", "ABAP", "Advanced Analytics", "Agile", "Adobe Suite",
    "Analytics", "Big Data", "Big Data Frameworks", "BI", "BODS",
    "Bloomberg", "Business Objects", "Capital IQ", "CIA", "CFE",
    "Cloud", "CMS", "Cognos", "Copywriting", "CRM",
    "CyberSecurity", "Data Analytics", "Data Management", "Data Modeling", "Data Science",
    "Data Visualization", "Data Warehousing", "DBA", "Decision Sciences", "Digital Marketing",
    "EDW", "ETL", "ElasticSearch", "EMR", "Excel",
    "Fiori", "Facebook", "Google Adwords", "Graphic Design", "Hadoop",
    "HCM", "HireVue", "HRIS", "HTML", "H-Lookup",
    "IBM", "iTracker", "Informatica", "Information Systems", "Information Technology",
    "Indexing", "Java", "JavaScript", "Jaspersoft", "Logstash",
    "Mainframe", "Mainframe Disk", "MedeAnalytics", "Metadata Management", "Microsoft Access",
    "Microsoft Office", "Microsoft Outlook", "MS SQL", "NewsletterManage", "Patient Communication Software",
    "Pivot Tables", "PL/SQL", "PMP", "PPC", "PowerPoint",
    "Proof Reading", "Product Marketing", "Project Tracking Software", "QA/Testing", "QlikView",
    "Query", "Reporting", "SAS", "SAP", "SAP BI & Analytics",
    "SAP BW", "SEO", "SharePoint", "Social Media", "Spark",
    "SQL", "SQL Server", "SSRS", "Tableau", "Twitter",
    "UI5", "V-Lookup", "Visual Analytics Tools", "Visual BI", "Visualization",
    "Visualization Tools", "Video Production", "Web Development", "Word", "Android",
    "Big Data Management", "Capital Management", "Cloud Computing", "Cognitive Solutions", "Cyber",
    "Cyber Forensics", "Data Exploration", "Data Mining Methods", "Database Technology", "Design Thinking",
    "Digital Technologies", "ERP", "Environmental Engineering", "ExactTarget", "Google Analytics",
    "Identity Matching", "InfoPath", "IoT", "Jaspersoft", "Logistics & Supply Chain",
    "Machine Learning", "Marketing Analytics", "MDM", "Microsoft Power BI", "Microsoft SharePoint Online",
    "Microsoft Skype for Business", "Microsoft Visio", "MS SharePoint", "OneNote", "Outlook",
    "Pattern Recognition", "Predictive Analytics", "Predictive Maintenance of Equipment", "Project Management", "Quality & Reliability Engineering",
    "QC", "Risk Management", "SAP", "Scala", "SOX",
    "Statistics", "SurveyMonkey", "Text Mining", "Visual Analytics Tools", "Yardi",
    "Aptitude", "Business Analytics", "Business Intelligence", "Digital Platform", "Digital Technology",
    "ETL", "Extraction, Transformation and Loading", "EIT Certification", "Google Analytics", "Languages",
    "Linear", "Microsoft Excel", "Microsoft Office Suite", "Microsoft Projects", "MS Project",
    "Notepad++", "Photoshop", "Process Hazard Analysis", "Process Safety Management", "Risk Management & Workflow",
    "ServiceNow", "StaffTrak", "StartWire", "Task Master", "Access",
    "Balsamiq", "CSS", "CSS3", "Drools", "eBusiness",
    "eCommerce", "eViews", "Hive", "IBM Security", "Installation",
    "Java/J2EE", "Linux", "Macromedia Flash", "Map Reduce", "Matlab",
    "MedeAnalytics", "MSCI IPD", "PowerShell", "Product Development", "QA",
    "QBO", "QuickBooks", "Random Forests", "Scrum", "SPSS",
    "Supply Chain Management", "Systems Hardware", "TurboTax", "User Experience Design", "User Research and Interaction Design",
    "VB.NET", "VB6", "Voice", "Voice Engineering", "VoIP",
    "Windows", "Windows & Network", "XML", "XPath", "XQuery",
    "XSLT"]
}
'''
# Out:
# '\nskills = {\n    "skills": [\n    "AB Testing", "ABAP", "Advanced Analytics", "Agile", "Adobe Suite",\n    "Analytics", "Big Data", "Big Data Frameworks", "BI", "BODS",\n    "Bloomberg", "Business Objects", "Capital IQ", "CIA", "CFE",\n    "Cloud", "CMS", "Cognos", "Copywriting", "CRM",\n    "CyberSecurity", "Data Analytics", "Data Management", "Data Modeling", "Data Science",\n    "Data Visualization", "Data Warehousing", "DBA", "Decision Sciences", "Digital Marketing",\n    "EDW", "ETL", "ElasticSearch", "EMR", "Excel",\n    "Fiori", "Facebook", "Google Adwords", "Graphic Design", "Hadoop",\n    "HCM", "HireVue", "HRIS", "HTML", "H-Lookup",\n    "IBM", "iTracker", "Informatica", "Information Systems", "Information Technology",\n    "Indexing", "Java", "JavaScript", "Jaspersoft", "Logstash",\n    "Mainframe", "Mainframe Disk", "MedeAnalytics", "Metadata Management", "Microsoft Access",\n    "Microsoft Office", "Microsoft Outlook", "MS SQL", "NewsletterManage", "Patient Communication Software",\n    "Pivot Tables", "PL/SQL", "PMP", "PPC", "PowerPoint",\n    "Proof Reading", "Product Marketing", "Project Tracking Software", "QA/Testing", "QlikView",\n    "Query", "Reporting", "SAS", "SAP", "SAP BI & Analytics",\n    "SAP BW", "SEO", "SharePoint", "Social Media", "Spark",\n    "SQL", "SQL Server", "SSRS", "Tableau", "Twitter",\n    "UI5", "V-Lookup", "Visual Analytics Tools", "Visual BI", "Visualization",\n    "Visualization Tools", "Video Production", "Web Development", "Word", "Android",\n    "Big Data Management", "Capital Management", "Cloud Computing", "Cognitive Solutions", "Cyber",\n    "Cyber Forensics", "Data Exploration", "Data Mining Methods", "Database Technology", "Design Thinking",\n    "Digital Technologies", "ERP", "Environmental Engineering", "ExactTarget", "Google Analytics",\n    "Identity Matching", "InfoPath", "IoT", "Jaspersoft", "Logistics & Supply Chain",\n    "Machine Learning", "Marketing Analytics", "MDM", "Microsoft Power BI", "Microsoft SharePoint Online",\n    "Microsoft Skype for Business", "Microsoft Visio", "MS SharePoint", "OneNote", "Outlook",\n    "Pattern Recognition", "Predictive Analytics", "Predictive Maintenance of Equipment", "Project Management", "Quality & Reliability Engineering",\n    "QC", "Risk Management", "SAP", "Scala", "SOX",\n    "Statistics", "SurveyMonkey", "Text Mining", "Visual Analytics Tools", "Yardi",\n    "Aptitude", "Business Analytics", "Business Intelligence", "Digital Platform", "Digital Technology",\n    "ETL", "Extraction, Transformation and Loading", "EIT Certification", "Google Analytics", "Languages",\n    "Linear", "Microsoft Excel", "Microsoft Office Suite", "Microsoft Projects", "MS Project",\n    "Notepad++", "Photoshop", "Process Hazard Analysis", "Process Safety Management", "Risk Management & Workflow",\n    "ServiceNow", "StaffTrak", "StartWire", "Task Master", "Access",\n    "Balsamiq", "CSS", "CSS3", "Drools", "eBusiness",\n    "eCommerce", "eViews", "Hive", "IBM Security", "Installation",\n    "Java/J2EE", "Linux", "Macromedia Flash", "Map Reduce", "Matlab",\n    "MedeAnalytics", "MSCI IPD", "PowerShell", "Product Development", "QA",\n    "QBO", "QuickBooks", "Random Forests", "Scrum", "SPSS",\n    "Supply Chain Management", "Systems Hardware", "TurboTax", "User Experience Design", "User Research and Interaction Design",\n    "VB.NET", "VB6", "Voice", "Voice Engineering", "VoIP",\n    "Windows", "Windows & Network", "XML", "XPath", "XQuery",\n    "XSLT"]\n}\n'

# %%
import spacy
import pandas as pd
from spacy.matcher import Matcher

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")

# Initialize Matcher with NLP vocab
matcher = Matcher(nlp.vocab)



# Convert words in ner_dict into SpaCy token patterns
for label, words in ner_dict.items():
    for word in words:
        pattern = [{"LOWER": word.lower()}]  # Match case-insensitive
        matcher.add(label, [pattern])



# Dictionary to store extracted entities
job_desc_entities= {}

# Apply Matcher on each job description
for i in range(size):
    doc = nlp(df["Job Description"][i].lower())
    matches = matcher(doc)

    # Extract matched entities
    extracted_entities = [[doc[start:end].text, nlp.vocab.strings[match_id]] for match_id, start, end in matches]

    # Store in dictionary
    job_desc_entities[i] = extracted_entities

# Print the results
for key, value in job_desc_entities.items():
    print(key, ":", value)
# Out:
# 0 : [['bi', 'Skills'], ['bi', 'Skills'], ['analytics', 'Skills'], ['sap', 'Tools'], ['sap', 'Tools'], ['oracle', 'Tools'], ['ms', 'Tools'], ['sql', 'Tools'], ['pl', 'Tools'], ['sql', 'Tools'], ['sas', 'Tools'], ['visualization', 'Skills'], ['bi', 'Skills'], ['analytics', 'Skills'], ['etl', 'Skills'], ['visualization', 'Skills'], ['reporting', 'Skills'], ['analytics', 'Skills'], ['sap', 'Tools'], ['bi', 'Skills'], ['analytics', 'Skills'], ['bi', 'Skills'], ['bi', 'Skills'], ['analytics', 'Skills'], ['bi', 'Skills'], ['it', 'Skills'], ['bi', 'Skills'], ['etl', 'Skills'], ['bi', 'Skills'], ['bi', 'Skills'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['hadoop', 'Tools'], ['spark', 'Tools'], ['reporting', 'Skills'], ['css', 'Tools'], ['javascript', 'Tools'], ['ui5', 'Tools'], ['fiori', 'Tools'], ['access', 'Tools'], ['bi', 'Skills'], ['bi', 'Skills'], ['bi', 'Skills'], ['analytics', 'Skills'], ['bi', 'Skills']]
# 1 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['analytics', 'Skills'], ['marketing', 'Expertise']]
# 2 : [['reporting', 'Skills'], ['reporting', 'Skills'], ['visualization', 'Skills'], ['leadership', 'Skills'], ['reporting', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['visualization', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['reporting', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['sql', 'Tools'], ['sas', 'Tools'], ['excel', 'Tools'], ['word', 'Tools'], ['powerpoint', 'Tools'], ['access', 'Tools'], ['tableau', 'Tools'], ['visualization', 'Skills'], ['reporting', 'Skills'], ['extraction', 'Skills'], ['transformation', 'Skills'], ['loading', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise']]
# 3 : [['it', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['marketing', 'Expertise'], ['ms', 'Tools'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['management', 'Expertise'], ['management', 'Expertise']]
# 4 : [['analytics', 'Skills'], ['reporting', 'Skills']]
# 5 : [['it', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['reporting', 'Skills'], ['ms', 'Tools'], ['excel', 'Tools'], ['management', 'Expertise']]
# 6 : [['cloud', 'Skills'], ['analytics', 'Skills'], ['reporting', 'Skills'], ['tableau', 'Tools'], ['testing', 'Skills'], ['tableau', 'Tools'], ['tableau', 'Tools'], ['excel', 'Tools'], ['access', 'Tools'], ['sql', 'Tools'], ['analytics', 'Skills'], ['tableau', 'Tools']]
# 7 : [['analytics', 'Skills'], ['cloud', 'Skills'], ['analytics', 'Skills'], ['reporting', 'Skills'], ['tableau', 'Tools'], ['testing', 'Skills'], ['tableau', 'Tools'], ['tableau', 'Tools'], ['excel', 'Tools'], ['access', 'Tools'], ['sql', 'Tools'], ['analytics', 'Skills'], ['tableau', 'Tools']]
# 8 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['reporting', 'Skills'], ['excel', 'Tools'], ['marketing', 'Expertise'], ['testing', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['excel', 'Tools'], ['html', 'Tools'], ['css', 'Tools'], ['java', 'Tools'], ['marketing', 'Expertise'], ['cms', 'Tools'], ['crm', 'Tools']]
# 9 : [['management', 'Expertise'], ['reporting', 'Skills'], ['excel', 'Tools'], ['access', 'Tools'], ['management', 'Expertise'], ['reporting', 'Skills'], ['excel', 'Tools'], ['ms', 'Tools'], ['access', 'Tools']]
# 10 : [['management', 'Expertise'], ['it', 'Skills'], ['windows', 'Tools'], ['linux', 'Tools'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['transformation', 'Skills'], ['management', 'Expertise'], ['visualization', 'Skills'], ['transformation', 'Skills'], ['analytics', 'Skills'], ['it', 'Skills'], ['management', 'Expertise'], ['it', 'Skills'], ['it', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['economics', 'Expertise'], ['finance', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['access', 'Tools'], ['leadership', 'Skills'], ['excel', 'Tools'], ['leadership', 'Skills'], ['san', 'Tools']]
# 11 : [['analytics', 'Skills'], ['visualization', 'Skills']]
# 12 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['html', 'Tools'], ['management', 'Expertise'], ['crm', 'Tools'], ['testing', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['analytics', 'Skills'], ['ms', 'Tools'], ['access', 'Tools'], ['oracle', 'Tools'], ['sql', 'Tools'], ['sql', 'Tools'], ['marketing', 'Expertise'], ['leadership', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise']]
# 13 : [['management', 'Expertise'], ['leadership', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['leadership', 'Skills'], ['excel', 'Tools'], ['it', 'Skills'], ['it', 'Skills'], ['it', 'Skills'], ['it', 'Skills']]
# 14 : [['marketing', 'Expertise'], ['finance', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise']]
# 15 : [['it', 'Skills'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['access', 'Tools'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['leadership', 'Skills'], ['finance', 'Expertise'], ['marketing', 'Expertise'], ['it', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['leadership', 'Skills'], ['economics', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['leadership', 'Skills'], ['it', 'Skills']]
# 16 : [['it', 'Skills'], ['it', 'Skills'], ['it', 'Skills'], ['testing', 'Skills'], ['sql', 'Tools'], ['management', 'Expertise'], ['reporting', 'Skills'], ['testing', 'Skills'], ['etl', 'Skills'], ['etl', 'Skills'], ['loading', 'Skills'], ['transformation', 'Skills'], ['cybersecurity', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['it', 'Skills'], ['management', 'Expertise'], ['sql', 'Tools'], ['etl', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['leadership', 'Skills'], ['excel', 'Tools'], ['leadership', 'Skills']]
# 17 : [['analytics', 'Skills'], ['cloud', 'Skills'], ['saas', 'Tools'], ['testing', 'Skills'], ['ms', 'Tools'], ['excel', 'Tools'], ['it', 'Skills'], ['jira', 'Tools'], ['sql', 'Tools']]
# 18 : [['it', 'Skills'], ['it', 'Skills'], ['access', 'Tools'], ['it', 'Skills'], ['management', 'Expertise'], ['analytics', 'Skills'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['twitter', 'Tools'], ['it', 'Skills']]
# 19 : [['access', 'Tools'], ['leadership', 'Skills'], ['it', 'Skills'], ['analytics', 'Skills'], ['ms', 'Tools'], ['ms', 'Tools'], ['excel', 'Tools'], ['ms', 'Tools'], ['access', 'Tools'], ['it', 'Skills'], ['excel', 'Tools'], ['leadership', 'Skills'], ['san', 'Tools']]
# 20 : [['marketing', 'Expertise'], ['oracle', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['analytics', 'Skills'], ['it', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['oracle', 'Tools'], ['cloud', 'Skills'], ['cloud', 'Skills'], ['oracle', 'Tools'], ['it', 'Skills'], ['oracle', 'Tools'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['oracle', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['reporting', 'Skills'], ['marketing', 'Expertise'], ['saas', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['san', 'Tools']]
# 21 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['leadership', 'Skills'], ['analytics', 'Skills'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['economics', 'Expertise']]
# 22 : [['it', 'Skills'], ['finance', 'Expertise'], ['economics', 'Expertise'], ['leadership', 'Skills'], ['finance', 'Expertise']]
# 23 : [['leadership', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['facebook', 'Tools'], ['twitter', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['analytics', 'Skills'], ['marketing', 'Expertise']]
# 24 : [['leadership', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['facebook', 'Tools'], ['twitter', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['analytics', 'Skills'], ['marketing', 'Expertise']]
# 25 : [['analytics', 'Skills'], ['it', 'Skills'], ['management', 'Expertise'], ['excel', 'Tools'], ['word', 'Tools'], ['sap', 'Tools'], ['twitter', 'Tools'], ['facebook', 'Tools']]
# 26 : [['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['reporting', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['reporting', 'Skills'], ['economics', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['it', 'Skills']]
# 27 : [['analytics', 'Skills']]
# 28 : [['cloud', 'Skills'], ['word', 'Tools'], ['excel', 'Tools'], ['cloud', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['hadoop', 'Tools'], ['elasticsearch', 'Tools'], ['logstash', 'Tools'], ['analytics', 'Skills'], ['jaspersoft', 'Tools'], ['qlikview', 'Tools'], ['java', 'Tools']]
# 29 : [['cloud', 'Skills'], ['leadership', 'Skills'], ['testing', 'Skills'], ['management', 'Expertise'], ['testing', 'Skills'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['it', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise']]
# 30 : [['cloud', 'Skills'], ['leadership', 'Skills'], ['testing', 'Skills'], ['management', 'Expertise'], ['testing', 'Skills'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['it', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise']]
# 31 : [['cloud', 'Skills'], ['analytics', 'Skills'], ['cloud', 'Skills']]
# 32 : [['analytics', 'Skills'], ['reporting', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['reporting', 'Skills'], ['management', 'Expertise']]
# 33 : [['testing', 'Skills'], ['finance', 'Expertise'], ['economics', 'Expertise'], ['access', 'Tools']]
# 34 : [['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['it', 'Skills'], ['it', 'Skills'], ['testing', 'Skills'], ['scrum', 'Tools'], ['yardi', 'Tools'], ['erp', 'Expertise'], ['sql', 'Tools'], ['sql', 'Tools'], ['it', 'Skills']]
# 35 : [['management', 'Expertise'], ['access', 'Tools'], ['leadership', 'Skills'], ['finance', 'Expertise'], ['economics', 'Expertise'], ['windows', 'Tools'], ['excel', 'Tools'], ['word', 'Tools'], ['management', 'Expertise'], ['excel', 'Tools'], ['leadership', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills']]
# 36 : [['word', 'Tools'], ['access', 'Tools'], ['excel', 'Tools']]
# 37 : [['it', 'Skills'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['it', 'Skills']]
# 38 : [['sql', 'Tools'], ['it', 'Skills'], ['sql', 'Tools'], ['it', 'Skills'], ['bi', 'Skills'], ['sql', 'Tools'], ['it', 'Skills'], ['it', 'Skills'], ['sql', 'Tools'], ['reporting', 'Skills'], ['sql', 'Tools'], ['sql', 'Tools'], ['bi', 'Skills'], ['tableau', 'Tools'], ['management', 'Expertise'], ['leadership', 'Skills'], ['management', 'Expertise'], ['sql', 'Tools'], ['bi', 'Skills'], ['infopath', 'Tools'], ['excel', 'Tools'], ['word', 'Tools'], ['powerpoint', 'Tools'], ['it', 'Skills'], ['it', 'Skills'], ['it', 'Skills'], ['it', 'Skills']]
# 39 : [['finance', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['reporting', 'Skills'], ['management', 'Expertise'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['finance', 'Expertise'], ['reporting', 'Skills'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['access', 'Tools'], ['leadership', 'Skills'], ['management', 'Expertise'], ['access', 'Tools']]
# 40 : [['sap', 'Tools'], ['facebook', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['cloud', 'Skills'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['san', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['marketing', 'Expertise'], ['sap', 'Tools'], ['finance', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['leadership', 'Skills'], ['excel', 'Tools'], ['san', 'Tools'], ['analytics', 'Skills'], ['management', 'Expertise'], ['finance', 'Expertise'], ['management', 'Expertise'], ['finance', 'Expertise'], ['san', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['erp', 'Expertise'], ['finance', 'Expertise'], ['facebook', 'Tools']]
# 41 : [['reporting', 'Skills'], ['reporting', 'Skills'], ['visualization', 'Skills'], ['leadership', 'Skills'], ['reporting', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['visualization', 'Skills'], ['reporting', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['reporting', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['sql', 'Tools'], ['sas', 'Tools'], ['excel', 'Tools'], ['word', 'Tools'], ['powerpoint', 'Tools'], ['access', 'Tools'], ['tableau', 'Tools'], ['visualization', 'Skills'], ['reporting', 'Skills'], ['extraction', 'Skills'], ['transformation', 'Skills'], ['loading', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['management', 'Expertise'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise']]
# 42 : [['analytics', 'Skills'], ['analytics', 'Skills'], ['management', 'Expertise'], ['economics', 'Expertise'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['access', 'Tools'], ['powerpoint', 'Tools']]
# 43 : [['it', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['marketing', 'Expertise'], ['ms', 'Tools'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['management', 'Expertise'], ['management', 'Expertise']]
# 44 : [['analytics', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['access', 'Tools']]
# 45 : [['it', 'Skills'], ['management', 'Expertise'], ['testing', 'Skills'], ['etl', 'Skills'], ['saas', 'Tools'], ['it', 'Skills'], ['java', 'Tools'], ['sql', 'Tools']]
# 46 : [['access', 'Tools'], ['cloud', 'Skills'], ['analytics', 'Skills'], ['cloud', 'Skills']]
# 47 : [['it', 'Skills'], ['cloud', 'Skills'], ['word', 'Tools'], ['excel', 'Tools'], ['cloud', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['hadoop', 'Tools'], ['elasticsearch', 'Tools'], ['logstash', 'Tools'], ['analytics', 'Skills'], ['jaspersoft', 'Tools'], ['qlikview', 'Tools'], ['java', 'Tools']]
# 48 : [['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['reporting', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['cloud', 'Skills'], ['management', 'Expertise'], ['excel', 'Tools']]
# 49 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['excel', 'Tools'], ['exacttarget', 'Tools'], ['surveymonkey', 'Tools'], ['analytics', 'Skills'], ['html', 'Tools'], ['sql', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['analytics', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['word', 'Tools']]
# 50 : [['analytics', 'Skills'], ['analytics', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['access', 'Tools']]
# 51 : [['it', 'Skills'], ['cloud', 'Skills'], ['analytics', 'Skills'], ['cloud', 'Skills']]
# 52 : [['finance', 'Expertise'], ['finance', 'Expertise'], ['management', 'Expertise'], ['reporting', 'Skills'], ['finance', 'Expertise'], ['economics', 'Expertise'], ['finance', 'Expertise'], ['mathematics', 'Expertise'], ['management', 'Expertise'], ['analytics', 'Skills']]
# 53 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['transformation', 'Skills'], ['marketing', 'Expertise'], ['analytics', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise']]
# 54 : [['management', 'Expertise'], ['analytics', 'Skills'], ['marketing', 'Expertise'], ['sas', 'Tools']]
# 55 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise']]
# 56 : [['management', 'Expertise'], ['management', 'Expertise'], ['it', 'Skills'], ['leadership', 'Skills']]
# 57 : [['it', 'Skills'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['reporting', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['it', 'Skills']]
# 58 : [['management', 'Expertise']]
# 59 : [['testing', 'Skills'], ['leadership', 'Skills'], ['testing', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['access', 'Tools']]
# 60 : [['analytics', 'Skills'], ['sql', 'Tools'], ['ms', 'Tools'], ['excel', 'Tools'], ['analytics', 'Skills'], ['excel', 'Tools'], ['access', 'Tools'], ['sql', 'Tools']]
# 61 : [['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['access', 'Tools'], ['leadership', 'Skills'], ['san', 'Tools']]
# 62 : [['cloud', 'Skills'], ['analytics', 'Skills'], ['cloud', 'Skills']]
# 63 : [['analytics', 'Skills'], ['reporting', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['reporting', 'Skills'], ['management', 'Expertise']]
# 64 : [['testing', 'Skills'], ['finance', 'Expertise'], ['economics', 'Expertise'], ['access', 'Tools']]
# 65 : [['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['it', 'Skills'], ['it', 'Skills'], ['testing', 'Skills'], ['scrum', 'Tools'], ['yardi', 'Tools'], ['erp', 'Expertise'], ['sql', 'Tools'], ['sql', 'Tools'], ['it', 'Skills']]
# 66 : [['management', 'Expertise'], ['access', 'Tools'], ['leadership', 'Skills'], ['finance', 'Expertise'], ['economics', 'Expertise'], ['windows', 'Tools'], ['excel', 'Tools'], ['word', 'Tools'], ['management', 'Expertise'], ['excel', 'Tools'], ['leadership', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills']]
# 67 : [['word', 'Tools'], ['access', 'Tools'], ['excel', 'Tools']]
# 68 : [['it', 'Skills'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['it', 'Skills']]
# 69 : [['sql', 'Tools'], ['it', 'Skills'], ['sql', 'Tools'], ['it', 'Skills'], ['bi', 'Skills'], ['sql', 'Tools'], ['it', 'Skills'], ['it', 'Skills'], ['sql', 'Tools'], ['reporting', 'Skills'], ['sql', 'Tools'], ['sql', 'Tools'], ['bi', 'Skills'], ['tableau', 'Tools'], ['management', 'Expertise'], ['leadership', 'Skills'], ['management', 'Expertise'], ['sql', 'Tools'], ['bi', 'Skills'], ['infopath', 'Tools'], ['excel', 'Tools'], ['word', 'Tools'], ['powerpoint', 'Tools'], ['it', 'Skills'], ['it', 'Skills'], ['it', 'Skills'], ['it', 'Skills']]
# 70 : [['finance', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['reporting', 'Skills'], ['management', 'Expertise'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['finance', 'Expertise'], ['reporting', 'Skills'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['access', 'Tools'], ['leadership', 'Skills'], ['management', 'Expertise'], ['access', 'Tools']]
# 71 : [['sap', 'Tools'], ['facebook', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['cloud', 'Skills'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['san', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['marketing', 'Expertise'], ['sap', 'Tools'], ['finance', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['leadership', 'Skills'], ['excel', 'Tools'], ['san', 'Tools'], ['analytics', 'Skills'], ['management', 'Expertise'], ['finance', 'Expertise'], ['management', 'Expertise'], ['finance', 'Expertise'], ['san', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['sap', 'Tools'], ['erp', 'Expertise'], ['finance', 'Expertise'], ['facebook', 'Tools']]
# 72 : [['reporting', 'Skills'], ['reporting', 'Skills'], ['visualization', 'Skills'], ['leadership', 'Skills'], ['reporting', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['visualization', 'Skills'], ['reporting', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['reporting', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['sql', 'Tools'], ['sas', 'Tools'], ['excel', 'Tools'], ['word', 'Tools'], ['powerpoint', 'Tools'], ['access', 'Tools'], ['tableau', 'Tools'], ['visualization', 'Skills'], ['reporting', 'Skills'], ['extraction', 'Skills'], ['transformation', 'Skills'], ['loading', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['management', 'Expertise'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise']]
# 73 : [['analytics', 'Skills'], ['analytics', 'Skills'], ['management', 'Expertise'], ['economics', 'Expertise'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['access', 'Tools'], ['powerpoint', 'Tools']]
# 74 : [['it', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['marketing', 'Expertise'], ['ms', 'Tools'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['management', 'Expertise'], ['management', 'Expertise']]
# 75 : [['analytics', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['access', 'Tools']]
# 76 : [['it', 'Skills'], ['management', 'Expertise'], ['testing', 'Skills'], ['etl', 'Skills'], ['saas', 'Tools'], ['it', 'Skills'], ['java', 'Tools'], ['sql', 'Tools']]
# 77 : [['access', 'Tools'], ['cloud', 'Skills'], ['analytics', 'Skills'], ['cloud', 'Skills']]
# 78 : [['it', 'Skills'], ['cloud', 'Skills'], ['word', 'Tools'], ['excel', 'Tools'], ['cloud', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['hadoop', 'Tools'], ['elasticsearch', 'Tools'], ['logstash', 'Tools'], ['analytics', 'Skills'], ['jaspersoft', 'Tools'], ['qlikview', 'Tools'], ['java', 'Tools']]
# 79 : [['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['reporting', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['cloud', 'Skills'], ['management', 'Expertise'], ['excel', 'Tools']]
# 80 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['excel', 'Tools'], ['exacttarget', 'Tools'], ['surveymonkey', 'Tools'], ['analytics', 'Skills'], ['html', 'Tools'], ['sql', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['analytics', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['word', 'Tools']]
# 81 : [['analytics', 'Skills'], ['analytics', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['access', 'Tools']]
# 82 : [['it', 'Skills'], ['cloud', 'Skills'], ['analytics', 'Skills'], ['cloud', 'Skills']]
# 83 : [['finance', 'Expertise'], ['finance', 'Expertise'], ['management', 'Expertise'], ['reporting', 'Skills'], ['finance', 'Expertise'], ['economics', 'Expertise'], ['finance', 'Expertise'], ['mathematics', 'Expertise'], ['management', 'Expertise'], ['analytics', 'Skills']]
# 84 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['transformation', 'Skills'], ['marketing', 'Expertise'], ['analytics', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise']]
# 85 : [['management', 'Expertise'], ['analytics', 'Skills'], ['marketing', 'Expertise'], ['sas', 'Tools']]
# 86 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise']]
# 87 : [['management', 'Expertise'], ['management', 'Expertise'], ['it', 'Skills'], ['leadership', 'Skills']]
# 88 : [['it', 'Skills'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['reporting', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['it', 'Skills']]
# 89 : [['management', 'Expertise']]
# 90 : [['testing', 'Skills'], ['leadership', 'Skills'], ['testing', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['access', 'Tools']]
# 91 : [['analytics', 'Skills'], ['sql', 'Tools'], ['ms', 'Tools'], ['excel', 'Tools'], ['analytics', 'Skills'], ['excel', 'Tools'], ['access', 'Tools'], ['sql', 'Tools']]
# 92 : [['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['access', 'Tools'], ['leadership', 'Skills'], ['san', 'Tools']]
# 93 : [['management', 'Expertise'], ['it', 'Skills'], ['it', 'Skills'], ['saas', 'Tools'], ['cloud', 'Skills'], ['analytics', 'Skills'], ['twitter', 'Tools']]
# 94 : [['it', 'Skills'], ['autocad', 'Tools'], ['excel', 'Tools'], ['management', 'Expertise'], ['management', 'Expertise']]
# 95 : [['it', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['cms', 'Tools'], ['finance', 'Expertise'], ['excel', 'Tools'], ['word', 'Tools'], ['powerpoint', 'Tools'], ['management', 'Expertise'], ['analytics', 'Skills'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['it', 'Skills']]
# 96 : [['management', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['ms', 'Tools'], ['word', 'Tools'], ['excel', 'Tools'], ['access', 'Tools'], ['leadership', 'Skills']]
# 97 : [['word', 'Tools'], ['excel', 'Tools'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['excel', 'Tools'], ['reporting', 'Skills']]
# 98 : [['leadership', 'Skills'], ['testing', 'Skills'], ['management', 'Expertise']]
# 99 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['access', 'Tools'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['access', 'Tools'], ['it', 'Skills'], ['leadership', 'Skills'], ['marketing', 'Expertise'], ['it', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise']]
# 100 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['management', 'Expertise'], ['twitter', 'Tools'], ['facebook', 'Tools']]
# 101 : [['management', 'Expertise'], ['it', 'Skills'], ['ms', 'Tools'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['access', 'Tools']]
# 102 : [['analytics', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['mathematics', 'Expertise'], ['access', 'Tools'], ['analytics', 'Skills'], ['sql', 'Tools'], ['matlab', 'Tools'], ['hadoop', 'Tools'], ['management', 'Expertise'], ['mathematics', 'Expertise'], ['access', 'Tools']]
# 103 : [['management', 'Expertise']]
# 104 : [['it', 'Skills'], ['testing', 'Skills'], ['html', 'Tools'], ['css', 'Tools'], ['javascript', 'Tools'], ['java', 'Tools'], ['java', 'Tools'], ['management', 'Expertise']]
# 105 : [['finance', 'Expertise'], ['marketing', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['finance', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise']]
# 106 : [['management', 'Expertise'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['access', 'Tools']]
# 107 : [['analytics', 'Skills'], ['sql', 'Tools'], ['excel', 'Tools'], ['bi', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['testing', 'Skills'], ['analytics', 'Skills'], ['marketing', 'Expertise'], ['it', 'Skills'], ['testing', 'Skills'], ['balsamiq', 'Tools'], ['notepad++', 'Tools'], ['javascript', 'Tools'], ['cms', 'Tools'], ['java', 'Tools'], ['drools', 'Tools']]
# 108 : [['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['leadership', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['marketing', 'Expertise'], ['eviews', 'Tools'], ['sql', 'Tools'], ['finance', 'Expertise'], ['economics', 'Expertise'], ['it', 'Skills']]
# 109 : [['reporting', 'Skills'], ['analytics', 'Skills'], ['reporting', 'Skills'], ['it', 'Skills'], ['bi', 'Skills'], ['cloud', 'Skills'], ['visualization', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['marketing', 'Expertise'], ['analytics', 'Skills']]
# 110 : [['it', 'Skills'], ['it', 'Skills']]
# 111 : [['analytics', 'Skills'], ['it', 'Skills'], ['analytics', 'Skills'], ['it', 'Skills'], ['reporting', 'Skills'], ['tableau', 'Tools'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['excel', 'Tools'], ['access', 'Tools'], ['sql', 'Tools'], ['visualization', 'Skills'], ['reporting', 'Skills'], ['tableau', 'Tools'], ['marketing', 'Expertise'], ['excel', 'Tools'], ['access', 'Tools'], ['marketing', 'Expertise']]
# 112 : [['analytics', 'Skills'], ['analytics', 'Skills'], ['reporting', 'Skills'], ['management', 'Expertise'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['access', 'Tools'], ['powerpoint', 'Tools']]
# 113 : [['javascript', 'Tools'], ['php', 'Tools']]
# 114 : [['reporting', 'Skills'], ['management', 'Expertise'], ['excel', 'Tools'], ['word', 'Tools']]
# 115 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise']]
# 116 : [['analytics', 'Skills'], ['analytics', 'Skills'], ['management', 'Expertise'], ['it', 'Skills'], ['management', 'Expertise'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['access', 'Tools'], ['powerpoint', 'Tools']]
# 117 : [['analytics', 'Skills'], ['cloud', 'Skills'], ['saas', 'Tools'], ['analytics', 'Skills'], ['bi', 'Skills'], ['ms', 'Tools'], ['sql', 'Tools'], ['analytics', 'Skills'], ['sql', 'Tools'], ['linux', 'Tools'], ['ms', 'Tools'], ['scrum', 'Tools']]
# 118 : [['it', 'Skills'], ['it', 'Skills'], ['servicenow', 'Tools'], ['it', 'Skills'], ['management', 'Expertise'], ['it', 'Skills'], ['it', 'Skills'], ['it', 'Skills'], ['management', 'Expertise'], ['ms', 'Tools'], ['excel', 'Tools'], ['ms', 'Tools']]
# 119 : [['linux', 'Tools'], ['san', 'Tools'], ['it', 'Skills'], ['windows', 'Tools'], ['linux', 'Tools'], ['marketing', 'Expertise'], ['crm', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['crm', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['twitter', 'Tools'], ['san', 'Tools'], ['san', 'Tools'], ['san', 'Tools']]
# 120 : [['linux', 'Tools'], ['san', 'Tools'], ['it', 'Skills'], ['windows', 'Tools'], ['linux', 'Tools'], ['marketing', 'Expertise'], ['crm', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['crm', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['twitter', 'Tools'], ['san', 'Tools'], ['san', 'Tools'], ['san', 'Tools']]
# 121 : [['analytics', 'Skills'], ['analytics', 'Skills'], ['management', 'Expertise'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['access', 'Tools'], ['powerpoint', 'Tools']]
# 122 : [['analytics', 'Skills'], ['it', 'Skills'], ['it', 'Skills'], ['analytics', 'Skills'], ['java', 'Tools'], ['html', 'Tools'], ['javascript', 'Tools'], ['php', 'Tools'], ['sql', 'Tools'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['testing', 'Skills'], ['it', 'Skills'], ['management', 'Expertise']]
# 123 : [['analytics', 'Skills'], ['economics', 'Expertise'], ['management', 'Expertise'], ['mathematics', 'Expertise'], ['css', 'Tools'], ['html', 'Tools'], ['java', 'Tools'], ['javascript', 'Tools'], ['sql', 'Tools'], ['spss', 'Tools'], ['sas', 'Tools'], ['matlab', 'Tools'], ['sql', 'Tools'], ['oracle', 'Tools'], ['sql', 'Tools']]
# 124 : [['management', 'Expertise'], ['finance', 'Expertise'], ['analytics', 'Skills'], ['excel', 'Tools']]
# 125 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['bi', 'Skills'], ['bi', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['bi', 'Skills'], ['analytics', 'Skills'], ['visualization', 'Skills'], ['crm', 'Tools'], ['management', 'Expertise']]
# 126 : [['testing', 'Skills'], ['management', 'Expertise'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['it', 'Skills'], ['it', 'Skills'], ['it', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['reporting', 'Skills'], ['it', 'Skills'], ['management', 'Expertise'], ['it', 'Skills'], ['management', 'Expertise'], ['avaya', 'Tools'], ['avaya', 'Tools'], ['testing', 'Skills'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['quickbooks', 'Tools'], ['turbotax', 'Tools'], ['mint.com', 'Tools'], ['cloud', 'Skills'], ['saas', 'Tools'], ['it', 'Skills'], ['it', 'Skills']]
# 127 : [['finance', 'Expertise'], ['management', 'Expertise'], ['reporting', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['excel', 'Tools'], ['sql', 'Tools'], ['sql', 'Tools']]
# 128 : [['testing', 'Skills'], ['management', 'Expertise']]
# 129 : [['management', 'Expertise'], ['finance', 'Expertise'], ['economics', 'Expertise'], ['excel', 'Tools'], ['management', 'Expertise']]
# 130 : [['analytics', 'Skills'], ['analytics', 'Skills'], ['management', 'Expertise'], ['it', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['access', 'Tools']]
# 131 : [['it', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['transformation', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['testing', 'Skills'], ['analytics', 'Skills'], ['visualization', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['mathematics', 'Expertise'], ['epidemiology', 'Skills'], ['sql', 'Tools'], ['sas', 'Tools'], ['powerpoint', 'Tools'], ['excel', 'Tools'], ['word', 'Tools'], ['sas', 'Tools'], ['sql', 'Tools'], ['leadership', 'Skills']]
# 132 : [['management', 'Expertise'], ['reporting', 'Skills'], ['analytics', 'Skills']]
# 133 : [['management', 'Expertise'], ['management', 'Expertise']]
# 134 : [['it', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['transformation', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['testing', 'Skills'], ['analytics', 'Skills'], ['visualization', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['mathematics', 'Expertise'], ['epidemiology', 'Skills'], ['sql', 'Tools'], ['sas', 'Tools'], ['powerpoint', 'Tools'], ['excel', 'Tools'], ['word', 'Tools'], ['sas', 'Tools'], ['sql', 'Tools'], ['leadership', 'Skills']]
# 135 : [['it', 'Skills'], ['it', 'Skills'], ['java', 'Tools'], ['jira', 'Tools'], ['scrum', 'Tools'], ['it', 'Skills'], ['it', 'Skills'], ['excel', 'Tools'], ['access', 'Tools'], ['powerpoint', 'Tools'], ['java', 'Tools'], ['javascript', 'Tools'], ['sql', 'Tools'], ['html', 'Tools'], ['mvc', 'Tools'], ['analytics', 'Skills']]
# 136 : [['it', 'Skills'], ['leadership', 'Skills'], ['excel', 'Tools'], ['testing', 'Skills'], ['marketing', 'Expertise'], ['economics', 'Expertise'], ['mathematics', 'Expertise'], ['finance', 'Expertise'], ['java', 'Tools'], ['javascript', 'Tools'], ['sql', 'Tools'], ['sas', 'Tools'], ['spark', 'Tools'], ['cloud', 'Skills'], ['leadership', 'Skills']]
# 137 : [['it', 'Skills'], ['it', 'Skills'], ['windows', 'Tools'], ['it', 'Skills'], ['windows', 'Tools'], ['excel', 'Tools'], ['word', 'Tools'], ['powerpoint', 'Tools']]
# 138 : [['it', 'Skills'], ['it', 'Skills'], ['java', 'Tools'], ['jira', 'Tools'], ['scrum', 'Tools'], ['it', 'Skills'], ['it', 'Skills'], ['excel', 'Tools'], ['access', 'Tools'], ['powerpoint', 'Tools'], ['java', 'Tools'], ['javascript', 'Tools'], ['sql', 'Tools'], ['html', 'Tools'], ['mvc', 'Tools'], ['analytics', 'Skills']]
# 139 : [['analytics', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['mathematics', 'Expertise'], ['access', 'Tools'], ['analytics', 'Skills'], ['sql', 'Tools'], ['matlab', 'Tools'], ['hadoop', 'Tools'], ['management', 'Expertise'], ['mathematics', 'Expertise'], ['access', 'Tools']]
# 140 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['twitter', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['analytics', 'Skills'], ['marketing', 'Expertise'], ['testing', 'Skills']]
# 141 : [['access', 'Tools'], ['management', 'Expertise'], ['excel', 'Tools'], ['economics', 'Expertise'], ['excel', 'Tools'], ['management', 'Expertise'], ['analytics', 'Skills'], ['access', 'Tools'], ['management', 'Expertise'], ['management', 'Expertise']]
# 142 : [['management', 'Expertise'], ['management', 'Expertise'], ['leadership', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise'], ['management', 'Expertise'], ['excel', 'Tools']]
# 143 : [['it', 'Skills'], ['it', 'Skills'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['analytics', 'Skills'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['analytics', 'Skills'], ['marketing', 'Expertise'], ['facebook', 'Tools'], ['twitter', 'Tools']]
# 144 : [['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['access', 'Tools'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['access', 'Tools'], ['it', 'Skills'], ['leadership', 'Skills'], ['marketing', 'Expertise'], ['it', 'Skills'], ['marketing', 'Expertise'], ['marketing', 'Expertise']]
# 145 : [['testing', 'Skills'], ['leadership', 'Skills'], ['testing', 'Skills'], ['analytics', 'Skills'], ['analytics', 'Skills'], ['leadership', 'Skills'], ['management', 'Expertise'], ['access', 'Tools']]
# 146 : [['access', 'Tools'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['crm', 'Tools'], ['crm', 'Tools'], ['reporting', 'Skills'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['crm', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['excel', 'Tools'], ['word', 'Tools'], ['access', 'Tools'], ['facebook', 'Tools'], ['management', 'Expertise'], ['analytics', 'Skills'], ['access', 'Tools'], ['management', 'Expertise'], ['management', 'Expertise']]
# 147 : [['management', 'Expertise'], ['reporting', 'Skills'], ['management', 'Expertise'], ['analytics', 'Skills']]
# 148 : [['finance', 'Expertise'], ['finance', 'Expertise'], ['analytics', 'Skills'], ['reporting', 'Skills'], ['finance', 'Expertise'], ['mathematics', 'Expertise'], ['economics', 'Expertise']]
# 149 : [['leadership', 'Skills'], ['sap', 'Tools'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['sap', 'Tools'], ['autocad', 'Tools'], ['management', 'Expertise']]
# 150 : [['leadership', 'Skills'], ['sap', 'Tools'], ['management', 'Expertise'], ['word', 'Tools'], ['excel', 'Tools'], ['powerpoint', 'Tools'], ['sap', 'Tools'], ['autocad', 'Tools'], ['management', 'Expertise']]
# 151 : [['access', 'Tools'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['bi', 'Skills'], ['management', 'Expertise'], ['economics', 'Expertise'], ['finance', 'Expertise'], ['excel', 'Tools'], ['sap', 'Tools'], ['analytics', 'Skills'], ['access', 'Tools'], ['management', 'Expertise'], ['management', 'Expertise']]
# 152 : [['it', 'Skills'], ['management', 'Expertise'], ['testing', 'Skills'], ['management', 'Expertise'], ['management', 'Expertise']]
# 153 : [['access', 'Tools'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['bi', 'Skills'], ['management', 'Expertise'], ['economics', 'Expertise'], ['finance', 'Expertise'], ['excel', 'Tools'], ['sap', 'Tools'], ['analytics', 'Skills'], ['access', 'Tools'], ['management', 'Expertise'], ['management', 'Expertise']]
# 154 : [['word', 'Tools'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['excel', 'Tools'], ['leadership', 'Skills']]
# 155 : [['access', 'Tools'], ['management', 'Expertise'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['crm', 'Tools'], ['crm', 'Tools'], ['reporting', 'Skills'], ['marketing', 'Expertise'], ['management', 'Expertise'], ['crm', 'Tools'], ['marketing', 'Expertise'], ['marketing', 'Expertise'], ['excel', 'Tools'], ['word', 'Tools'], ['access', 'Tools'], ['facebook', 'Tools'], ['management', 'Expertise'], ['analytics', 'Skills'], ['access', 'Tools'], ['management', 'Expertise'], ['management', 'Expertise']]
# 156 : [['it', 'Skills'], ['finance', 'Expertise'], ['access', 'Tools'], ['leadership', 'Skills'], ['leadership', 'Skills'], ['finance', 'Expertise'], ['finance', 'Expertise'], ['finance', 'Expertise'], ['excel', 'Tools'], ['leadership', 'Skills']]

# %% [markdown]
# ### Step 4: Identify the Most In-Demand Skills
# #### 📌 Goal: Count the most frequently mentioned skills in job descriptions.
#
# 1. Create a word frequency distribution of extracted skills.
# 2. Identify the top 10 most required skills.

# %%
from collections import Counter

skills_list = []

# Iterate throughjob_desc_entities and extract only "SKILLS"
for key, value in  job_desc_entities.items():
    for item in value:
        if item[1] == "Skills":
            skills_list.append(item[0])

# Count the frequency of each skill
skill_freq = Counter(skills_list)

# Get the top 10 most frequent skills
top_10_skills = skill_freq.most_common(10)

# Print the results
print("\nTop 10 Most Required Skills:")
for skill, count in top_10_skills:
    print(f"{skill}: {count}")
# Out:
# Top 10 Most Required Skills:
# analytics: 152
# it: 130
# leadership: 101
# reporting: 74
# testing: 36
# cloud: 34
# bi: 28
# visualization: 18
# transformation: 10
# etl: 7

# %% [markdown]
# ### Step 5: Categorize Skills by Industry
# #### 📌 Goal: Compare the most in-demand skills across different industries.
#
# 1. Group job descriptions by industry.
# 2. Extract and analyze skills for each industry.
# 3. Compare IT vs. Marketing vs. Healthcare, etc..

# %%
# Group by industry and get the list of indices for each industry
industry_indices = df.groupby('industry').apply(lambda x: x.index.tolist()).to_dict()

# Print the dictionary to check
print(industry_indices)
# Out:
# {'$500 million to $1 billion (USD) per year': [41, 72], 'Accounting & Legal': [10, 15, 16, 19, 33, 35, 36, 37, 56, 57, 61, 64, 66, 67, 68, 87, 88, 95, 154, 156], 'Aerospace & Defense': [102, 123], 'Arts, Entertainment & Recreation': [39, 59, 70, 90], 'Business Services': [8, 22, 26, 27, 29, 46, 48, 53, 58, 77, 79, 84, 89, 98, 99, 114, 115, 119, 120, 122, 128, 143, 144], 'Company - Public': [148], 'Construction, Repair & Maintenance': [150], 'Finance': [2, 3, 5, 9, 32, 34, 43, 49, 54, 63, 65, 74, 80, 85, 108, 109, 136], 'Health Care': [11, 45, 76, 97, 113, 118, 127, 132, 147, 152], 'Information Technology': [0, 7, 17, 20, 21, 25, 30, 38, 40, 47, 51, 69, 71, 78, 82, 93, 100, 117, 125, 126, 142], 'Insurance': [101, 131, 134, 135, 138], 'Manufacturing': [60, 91, 96, 103, 110, 111, 141, 146, 151, 153, 155], 'Media': [12, 42, 44, 50, 73, 75, 81, 106, 112, 116, 121, 130], 'Mining & Metals': [149], 'Non-Profit': [18], 'Real Estate': [129], 'Retail': [124, 140, 145], 'Subsidiary or Business Segment': [4, 14, 52, 55, 83, 86, 104, 139], 'Transportation & Logistics': [137], 'Travel & Tourism': [94], 'Unknown': [1, 6, 24, 28, 31, 62, 105, 133], 'Unknown / Non-Applicable per year': [107]}
# <ipython-input-41-0a325edb98f1>:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   industry_indices = df.groupby('industry').apply(lambda x: x.index.tolist()).to_dict()

# %%
# Dictionary to store skills by industry
industry_skills = {}

# Iterate through each industry and its corresponding indices
for industry, indices in industry_indices.items():
    industry_skills[industry] = []

    # Get skills from job_desc_entities using the row indices
    for idx in indices:
        if idx in job_desc_entities:  # Ensure index exists in extracted skills
          skills = [skill[0] for skill in job_desc_entities[idx] if skill[1] == "Skills"]
          industry_skills[industry].extend(skills)


# Remove duplicate skills per industry
for industry in industry_skills:
    industry_skills[industry] = list(set(industry_skills[industry]))

# Print industry skills
for industry, skills in industry_skills.items():
    print(f"{industry}: {skills}", "\n")
# Out:
# $500 million to $1 billion (USD) per year: ['visualization', 'loading', 'extraction', 'reporting', 'leadership', 'transformation']
#
# Accounting & Legal: ['cybersecurity', 'etl', 'it', 'visualization', 'analytics', 'loading', 'reporting', 'testing', 'leadership', 'transformation']
#
# Aerospace & Defense: ['analytics']
#
# Arts, Entertainment & Recreation: ['testing', 'leadership', 'reporting', 'analytics']
#
# Business Services: ['it', 'cloud', 'analytics', 'reporting', 'testing', 'leadership', 'transformation']
#
# Company - Public: ['reporting', 'analytics']
#
# Construction, Repair & Maintenance: ['leadership']
#
# Finance: ['it', 'cloud', 'visualization', 'analytics', 'loading', 'extraction', 'reporting', 'bi', 'testing', 'leadership', 'transformation']
#
# Health Care: ['etl', 'it', 'visualization', 'analytics', 'reporting', 'testing', 'leadership']
#
# Information Technology: ['etl', 'it', 'cloud', 'visualization', 'analytics', 'bi', 'reporting', 'testing', 'leadership']
#
# Insurance: ['it', 'epidemiology', 'visualization', 'analytics', 'testing', 'leadership', 'transformation']
#
# Manufacturing: ['it', 'visualization', 'analytics', 'bi', 'reporting', 'leadership']
#
# Media: ['it', 'analytics', 'reporting', 'testing', 'leadership']
#
# Mining & Metals: ['leadership']
#
# Non-Profit: ['it', 'analytics']
#
# Real Estate: []
#
# Retail: ['testing', 'leadership', 'analytics']
#
# Subsidiary or Business Segment: ['testing', 'it', 'reporting', 'analytics']
#
# Transportation & Logistics: ['it']
#
# Travel & Tourism: ['it']
#
# Unknown: ['cloud', 'analytics', 'reporting', 'testing', 'leadership']
#
# Unknown / Non-Applicable per year: ['testing', 'bi', 'it', 'analytics']
